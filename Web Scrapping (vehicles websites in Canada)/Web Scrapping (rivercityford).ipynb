# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla =  "https://www.rivercityford.ca/vehicles/new/?st=price,asc&view=grid&sc=new"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class row grid-row
data=soup.findAll('div',{"class":"row grid-row"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
#       Save This Car  Get Price Alerts Buy Me!  2019 Ford FUSION SE  Located at River City Ford  VIN: 3FA6P0HD6KR278956Condition: NewStock #: 278956REngine: 1.5L I-4Body Style: Sedan   Initial Price  $30,640    Savings  $-5,000  Hover for details. 2019 Clearance  Savings
# 				$5,000    Sale Price  $25,640  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $155
# 										/bw
# 									  Click to open payment calculator
# 									5.99% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2020 Ford ECOSPORT S  Located at River City Ford  VIN: MAJ6S3FL2LC382550Condition: NewStock #: 382550REngine: 2.0L TI-VCT GDI I-4Body Style: SUV   Initial Price  $27,099    Savings  $-1,000  Hover for details.  Dealer Discount$1,000   Sale Price  $26,099  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $158
# 										/bw
# 									  Click to open payment calculator
# 									5% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2020 Ford ECOSPORT SE  Located at Carman Ford   VIN: MAJ3S2GE7LC360699Condition: NewStock #: 360699CEngine: 1.0L ECOBOOSTBody Style: FWD   Initial Price  $29,699    Savings  $-1,000  Hover for details.  Dealer Discount$1,000   Sale Price  $28,699  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $174
# 										/bw
# 									  Click to open payment calculator
# 									5% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2019 Ford TRANSIT CONNECT VAN XLT  Located at River City Ford  VIN: NM0LS7T29K1418872Condition: NewStock #: 418872REngine: 2.0L GDI I-4 GASBody Style: Van   Initial Price  $35,070    Savings  $-5,500  Hover for details. 2019 Clearance
# 				$4,500River City Savings
# 				$1,000    Sale Price  $29,570  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $179
# 										/bw
# 									  Click to open payment calculator
# 									5.99% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2019 Ford TRANSIT CONNECT VAN XLT  Located at River City Ford  VIN: NM0LS7T28K1421441Condition: NewStock #: 421441REngine: 2.0L Body Style: Van   Initial Price  $35,070    Savings  $-5,500  Hover for details. 2019 Clearance Special
# 				$4,500River City Savings
# 				$1,000    Sale Price  $29,570  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $179
# 										/bw
# 									  Click to open payment calculator
# 									5.99% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2019 Ford FLEX SE  Located at River City Ford  VIN: 2FMGK5B83KBA26470Condition: NewStock #: A26470REngine: 3.5L V6Body Style: SUV   Initial Price  $35,249    Savings  $-4,500  Hover for details. 2019 Clearance Special
# 				$4,500    Sale Price  $30,749  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $186
# 										/bw
# 									  Click to open payment calculator
# 									5.99% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2020 Ford ECOSPORT SE  Located at River City Ford  VIN: MAJ6S3GL9LC345509Condition: NewStock #: 345509REngine: 2.0L Body Style: SUV   Initial Price  $31,749    Savings  $-1,000  Hover for details. Dealership Discount
# 				$1,000    Sale Price  $30,749  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $186
# 										/bw
# 									  Click to open payment calculator
# 									5% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2020 Ford ECOSPORT SE  Located at River City Ford  VIN: MAJ6S3GL3LC357848Condition: NewStock #: 357848REngine: 2.0L Body Style: SUV   Initial Price  $31,749    Savings  $-1,000  Hover for details. Dealership Discount
# 				$1,000    Sale Price  $30,749  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $186
# 										/bw
# 									  Click to open payment calculator
# 									5% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2020 Ford ECOSPORT SE  Located at River City Ford  VIN: MAJ6S3GL0LC382738Condition: NewStock #: 382738REngine: 2.0L TI-VCT GDI I-4Body Style: SUV   Initial Price  $31,749    Savings  $-1,000  Hover for details.  Dealer Discount$1,000   Sale Price  $30,749  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $186
# 										/bw
# 									  Click to open payment calculator
# 									5% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2020 Ford ECOSPORT 4WD SES  Located at River City Ford  VIN: MAJ6S3JL6LC369548Condition: NewStock #: 369548REngine: 2.0L TI-VCT GDI I-4 ENGINEBody Style: SUV   Initial Price  $32,099    Savings  $-1,000  Hover for details.  Dealer Discount$1,000   Sale Price  $31,099  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $188
# 										/bw
# 									  Click to open payment calculator
# 									5% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2020 Ford ECOSPORT SES  Located at River City Ford  VIN: MAJ6S3JL1LC385169Condition: NewStock #: 385169REngine: 2.0L TI-VCT GDI I-4Body Style: SUV   Initial Price  $32,549    Savings  $-1,000  Hover for details.  Dealer Discount$1,000   Sale Price  $31,549  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $191
# 										/bw
# 									  Click to open payment calculator
# 									5% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2020 Ford FUSION SE  Located at River City Ford  VIN: 3FA6P0HD4LR157831Condition: NewStock #: 157831REngine: 1.5L Body Style: Sedan   Initial Price  $32,085    Savings  $-500  Hover for details. Dealership Discount
# 				$500    Sale Price  $31,585  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $191
# 										/bw
# 									  Click to open payment calculator
# 									5% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2020 Ford ESCAPE S  Located at River City Ford  VIN: 1FMCU9F64LUC30862Condition: NewStock #: C30862REngine: 1.5L ECOBOOSTBody Style: SUV      Sale Price  $32,049  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $194
# 										/bw
# 									  Click to open payment calculator
# 									5% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2020 Ford ECOSPORT TITANIUM  Located at River City Ford  VIN: MAJ6S3KLXLC377635Condition: NewStock #: 377635REngine: 2.0L TI-VCT GDI I-4Body Style: SUV   Initial Price  $33,599    Savings  $-1,000  Hover for details.  Dealer Discount$1,000   Sale Price  $32,599  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $197
# 										/bw
# 									  Click to open payment calculator
# 									5% for 96 Months
# 			View Details
# 		  Compare        Save This Car  Get Price Alerts Buy Me!  2020 Ford FUSION HYBRID SE  Located at Carman Ford   VIN: 3FA6P0LU1LR120856Condition: NewStock #: 120856CEngine: 2.0L Body Style: FWD   Initial Price  $34,325    Savings  $-1,000  Hover for details.  Dealer Discount$1,000   Sale Price  $33,325  Pricing excludes licensing and tax.
# 									+ Tax								   Est. Finance Payment  $202
# 										/bw
# 									  Click to open payment calculator
# 									5% for 96 Months
# 			View Details
# 		  Compare

# %%
#Finding the titles of cars using find_all
#All the titles are present in h3 class : vehicle-card__title mb-xs
car_titles = []
a=soup.findAll('h3',{"class":"vehicle-card__title mb-xs"})
for i in a :
    print(i.text)#printing titles
    car_titles.append(i.text)#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# 2019 Ford FUSION SE
# 2020 Ford ECOSPORT S
# 2020 Ford ECOSPORT SE
# 2019 Ford TRANSIT CONNECT VAN XLT
# 2019 Ford TRANSIT CONNECT VAN XLT
# 2019 Ford FLEX SE
# 2020 Ford ECOSPORT SE
# 2020 Ford ECOSPORT SE
# 2020 Ford ECOSPORT SE
# 2020 Ford ECOSPORT 4WD SES
# 2020 Ford ECOSPORT SES
# 2020 Ford FUSION SE
# 2020 Ford ESCAPE S
# 2020 Ford ECOSPORT TITANIUM
# 2020 Ford FUSION HYBRID SE
# ['2019 Ford FUSION SE', '2020 Ford ECOSPORT S', '2020 Ford ECOSPORT SE', '2019 Ford TRANSIT CONNECT VAN XLT', '2019 Ford TRANSIT CONNECT VAN XLT', '2019 Ford FLEX SE', '2020 Ford ECOSPORT SE', '2020 Ford ECOSPORT SE', '2020 Ford ECOSPORT SE', '2020 Ford ECOSPORT 4WD SES', '2020 Ford ECOSPORT SES', '2020 Ford FUSION SE', '2020 Ford ESCAPE S', '2020 Ford ECOSPORT TITANIUM', '2020 Ford FUSION HYBRID SE']
# 15

# %%
Vinlist = []
condition = []
engine = []
body_style = []
stock = []
# taking empty lists

#All the specifications are inside ul class: detailed-specs 
spec= soup.find_all("ul",{"class": "detailed-specs"})

for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('li')#finding all li inside ul
    for li in lis:
       
        if 'VIN' in li.text: # if present 
            Vinlist.append(li.text.replace("VIN:","")) # then append
        if 'Condition' in li.text:# if present
            condition.append(li.text.replace("Condition:",""))# then append
        if 'Body Style' in li.text:# if present
            body_style.append(li.text.replace("Body Style:",""))# then append
        if 'Engine' in li.text:# if present
            engine.append(li.text.replace("Engine:",""))# then append# then append
        if 'Stock' in li.text:# if present
            stock.append(li.text.replace("Stock #:",""))#then append
            
#priniting individual lists
print(Vinlist)
print(condition)
print(body_style)
print(engine)
print(stock)
# Out:
# [' 3FA6P0HD6KR278956', ' MAJ6S3FL2LC382550', ' MAJ3S2GE7LC360699', ' NM0LS7T29K1418872', ' NM0LS7T28K1421441', ' 2FMGK5B83KBA26470', ' MAJ6S3GL9LC345509', ' MAJ6S3GL3LC357848', ' MAJ6S3GL0LC382738', ' MAJ6S3JL6LC369548', ' MAJ6S3JL1LC385169', ' 3FA6P0HD4LR157831', ' 1FMCU9F64LUC30862', ' MAJ6S3KLXLC377635', ' 3FA6P0LU1LR120856']
# [' New', ' New', ' New', ' New', ' New', ' New', ' New', ' New', ' New', ' New', ' New', ' New', ' New', ' New', ' New']
# [' Sedan', ' SUV', ' FWD', ' Van', ' Van', ' SUV', ' SUV', ' SUV', ' SUV', ' SUV', ' SUV', ' Sedan', ' SUV', ' SUV', ' FWD']
# [' 1.5L I-4', ' 2.0L TI-VCT GDI I-4', ' 1.0L ECOBOOST', ' 2.0L GDI I-4 GAS', ' 2.0L ', ' 3.5L V6', ' 2.0L ', ' 2.0L ', ' 2.0L TI-VCT GDI I-4', ' 2.0L TI-VCT GDI I-4 ENGINE', ' 2.0L TI-VCT GDI I-4', ' 1.5L ', ' 1.5L ECOBOOST', ' 2.0L TI-VCT GDI I-4', ' 2.0L ']
# [' 278956R', ' 382550R', ' 360699C', ' 418872R', ' 421441R', ' A26470R', ' 345509R', ' 357848R', ' 382738R', ' 369548R', ' 385169R', ' 157831R', ' C30862R', ' 377635R', ' 120856C']

# %%
#Finding the msrp of cars using find_all
#All the msrp are present in div class : vehicle-card__price-wrap
msrp = []
c = soup.findAll('div',{"class":"vehicle-card__price-wrap"})
for i in c :
    sp=i.findAll('div',{"class":"price-block__price price-block__price--md price-block__price--grey"})#digging further
    for j in sp:
        s=j.find('span',{"class":"df aifs"}).text.split("df aifs")[0]#actual values are inside span class :df aifs
        print(s)#printing msrp
        msrp.append(s)#appending in a list
print(msrp)#printing list
len(msrp)#length oflist
# Out:
# $30,640
# $27,099
# $29,699
# $35,070
# $35,070
# $35,249
# $31,749
# $31,749
# $31,749
# $32,099
# $32,549
# $32,085
# $33,599
# $34,325
# ['$30,640', '$27,099', '$29,699', '$35,070', '$35,070', '$35,249', '$31,749', '$31,749', '$31,749', '$32,099', '$32,549', '$32,085', '$33,599', '$34,325']
# 14

# %%
#Finding the  discount on cars using find_all
#All the   discount  are present in div class :vehicle-card__price-wrap
discount = []
c = soup.findAll('div',{"class":"vehicle-card__price-wrap"})
for i in c :
    sp=i.findAll('div',{"class":"price-block__price price-block__price--sm price-block__price--primary"})#digging further
    for j in sp:
        s=j.find('span',{"class":"df aifs"}).text.split("df aifs")[0]#actual values are inside span class :df aifs
        print(s)#printing initial discount
        discount.append(s)#appending in a list
print(discount)#printing list
len(discount)#length oflist
# Out:
# $-5,000
# $-1,000
# $-1,000
# $-5,500
# $-5,500
# $-4,500
# $-1,000
# $-1,000
# $-1,000
# $-1,000
# $-1,000
# $-500
# $-1,000
# $-1,000
# ['$-5,000', '$-1,000', '$-1,000', '$-5,500', '$-5,500', '$-4,500', '$-1,000', '$-1,000', '$-1,000', '$-1,000', '$-1,000', '$-500', '$-1,000', '$-1,000']
# 14

# %%
#Finding the sales price on cars using find_all
#All the  sales price  are present in div class : price-block__single price-block--expanded
car_price = []
c = soup.findAll('div',{"class":"price-block__single price-block--expanded"})
for i in c :
    sp=i.findAll('div',{"class":"price-block__price price-block__price--lg price-block__price--dark"})#digging further
    for j in sp:
        s=j.find('span',{"class":"df aifs"}).text.split("df aifs")[0]#actual values are inside span class :df aifs
        print(s)#printing initial prices
        car_price.append(s)#appending in a list
print(car_price)#printing list
len(car_price)#length of list
# Out:
# $25,640
# $26,099
# $28,699
# $29,570
# $29,570
# $30,749
# $30,749
# $30,749
# $30,749
# $31,099
# $31,549
# $31,585
# $32,049
# $32,599
# $33,325
# ['$25,640', '$26,099', '$28,699', '$29,570', '$29,570', '$30,749', '$30,749', '$30,749', '$30,749', '$31,099', '$31,549', '$31,585', '$32,049', '$32,599', '$33,325']
# 15

# %%
#price on cars using find_all
#All the price  are present in div class : price-block__single price-block--expanded price-block__single--finance
price = []
c = soup.findAll('div',{"class":"price-block__single price-block--expanded price-block__single--finance"})
for i in c :
    sp=i.findAll('div',{"class":"price-block__price price-block__price--md price-block__price--dark"})#digging further
    for j in sp:
        s=j.find('span',{"class":"df aifs"}).text.split("df aifs")[0]#actual values are inside span class :df aifs
        print(s)#printing initial prices
        price.append(s)#appending in a list
print(price)#printing list
len(price)#length oflist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5bb84a7fd0ba> in <module>
#       2 #All the price  are present in div class : price-block__single price-block--expanded price-block__single--finance
#       3 price = []
# ----> 4 c = soup.findAll('div',{"class":"price-block__single price-block--expanded price-block__single--finance"})
#       5 for i in c :
#       6     sp=i.findAll('div',{"class":"price-block__price price-block__price--md price-block__price--dark"})#digging further
#
# NameError: name 'soup' is not defined

# %%
#Finding the duration using find_all
#All the duration are present in div class : vehicle-card__price-wrap
duration = []
c = soup.findAll('div',{"class":"vehicle-card__price-wrap"})
for i in c :
    sp=i.findAll('div',{"class":"price-block__single price-block--expanded price-block__single--finance"})#digging further
    for j in sp:
        s=j.find('span',{"class":"price-block__sub"}).text.replace("\t","")#actual values are inside span class :df aifs
        print(s)#printing prices
        duration.append(s.strip())#appending in a list
print(duration)#printing list
len(duration)#length oflist
# Out:
# 5.99% for 96 Months
#
# 5% for 96 Months
#
# 5% for 96 Months
#
# 5.99% for 96 Months
#
# 5.99% for 96 Months
#
# 5.99% for 96 Months
#
# 5% for 96 Months
#
# 5% for 96 Months
#
# 5% for 96 Months
#
# 5% for 96 Months
#
# 5% for 96 Months
#
# 5% for 96 Months
#
# 5% for 96 Months
#
# 5% for 96 Months
#
# 5% for 96 Months
# ['5.99% for 96 Months', '5% for 96 Months', '5% for 96 Months', '5.99% for 96 Months', '5.99% for 96 Months', '5.99% for 96 Months', '5% for 96 Months', '5% for 96 Months', '5% for 96 Months', '5% for 96 Months', '5% for 96 Months', '5% for 96 Months', '5% for 96 Months', '5% for 96 Months', '5% for 96 Months']
# 15

# %%
#creating dict of scrapped data
dict = {
    'Title' : car_titles ,
    'Condition' : condition, 
    'Body Style': body_style ,
    'VIN' : Vinlist ,
    'Stock' : stock ,
    'Engine' : engine ,
    'MSRP' : msrp,
    'Discount' : discount,
    'Price' : car_price,
    'Installment per week': price,
    'Duration':duration,
}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                                 Title Condition Body Style  \
# 0                 2019 Ford FUSION SE       New      Sedan
# 1                2020 Ford ECOSPORT S       New        SUV
# 2               2020 Ford ECOSPORT SE       New        FWD
# 3   2019 Ford TRANSIT CONNECT VAN XLT       New        Van
# 4   2019 Ford TRANSIT CONNECT VAN XLT       New        Van
# 5                   2019 Ford FLEX SE       New        SUV
# 6               2020 Ford ECOSPORT SE       New        SUV
# 7               2020 Ford ECOSPORT SE       New        SUV
# 8               2020 Ford ECOSPORT SE       New        SUV
# 9          2020 Ford ECOSPORT 4WD SES       New        SUV
# 10             2020 Ford ECOSPORT SES       New        SUV
# 11                2020 Ford FUSION SE       New      Sedan
# 12                 2020 Ford ESCAPE S       New        SUV
# 13        2020 Ford ECOSPORT TITANIUM       New        SUV
# 14         2020 Ford FUSION HYBRID SE       New        FWD
#
#                    VIN     Stock                       Engine     MSRP  \
# 0    3FA6P0HD6KR278956   278956R                     1.5L I-4  $30,640
# 1    MAJ6S3FL2LC382550   382550R          2.0L TI-VCT GDI I-4  $27,099
# 2    MAJ3S2GE7LC360699   360699C                1.0L ECOBOOST  $29,699
# 3    NM0LS7T29K1418872   418872R             2.0L GDI I-4 GAS  $35,070
# 4    NM0LS7T28K1421441   421441R                        2.0L   $35,070
# 5    2FMGK5B83KBA26470   A26470R                      3.5L V6  $35,249
# 6    MAJ6S3GL9LC345509   345509R                        2.0L   $31,749
# 7    MAJ6S3GL3LC357848   357848R                        2.0L   $31,749
# 8    MAJ6S3GL0LC382738   382738R          2.0L TI-VCT GDI I-4  $31,749
# 9    MAJ6S3JL6LC369548   369548R   2.0L TI-VCT GDI I-4 ENGINE  $32,099
# 10   MAJ6S3JL1LC385169   385169R          2.0L TI-VCT GDI I-4  $32,549
# 11   3FA6P0HD4LR157831   157831R                        1.5L   $32,085
# 12   1FMCU9F64LUC30862   C30862R                1.5L ECOBOOST  $33,599
# 13   MAJ6S3KLXLC377635   377635R          2.0L TI-VCT GDI I-4  $34,325
# 14   3FA6P0LU1LR120856   120856C                        2.0L      None
#
#    Discount    Price Installment per week             Duration
# 0   $-5,000  $25,640              $25,640  5.99% for 96 Months
# 1   $-1,000  $26,099              $26,099     5% for 96 Months
# 2   $-1,000  $28,699              $28,699     5% for 96 Months
# 3   $-5,500  $29,570              $29,570  5.99% for 96 Months
# 4   $-5,500  $29,570              $29,570  5.99% for 96 Months
# 5   $-4,500  $30,749              $30,749  5.99% for 96 Months
# 6   $-1,000  $30,749              $30,749     5% for 96 Months
# 7   $-1,000  $30,749              $30,749     5% for 96 Months
# 8   $-1,000  $30,749              $30,749     5% for 96 Months
# 9   $-1,000  $31,099              $31,099     5% for 96 Months
# 10  $-1,000  $31,549              $31,549     5% for 96 Months
# 11    $-500  $31,585              $31,585     5% for 96 Months
# 12  $-1,000  $32,049              $32,049     5% for 96 Months
# 13  $-1,000  $32,599              $32,599     5% for 96 Months
# 14     None  $33,325              $33,325     5% for 96 Months

# %%
#Dataframe to csv
df.to_csv('rivercityford.csv')
