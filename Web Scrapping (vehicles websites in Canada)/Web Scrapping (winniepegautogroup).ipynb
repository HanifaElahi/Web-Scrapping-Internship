# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = "https://www.winnipegautogroup.com/vehicles/?v1=all&st=make,asc"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class row 
data=soup.findAll('div',{"class":"row"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
#  Search Inventory:
# 				  Search
#  Search Inventory:
# 				  Search
# Advanced Filters Sort By Collapse All  Expand All  75 Available Reset Filters Keyword Search  Condition  All  New  Used  Certified Vehicle Class  Vehicle Class: all
# 				All (75)
#
# 				Heavy Trucks (2)
#
# 				Motorcycle (5)
#
# 				Passenger Vehicles (57)
#
# 				RV (11)
# 			  Type Filter By  Type
# 				Class A Motorhome (1)
#
# 				Cruiser (1)
#
# 				Fifth Wheel (4)
#
# 				Flatbed/Bed Trucks (2)
#
# 				Touring (4)
#
# 				Travel Trailer (6)
#
# 				Unspecified (57)
# 			   Make Filter By  Make
# 				BMW (1)
#
# 				Buick (1)
#
# 				Cadillac (4)
#
# 				Chevrolet (5)
#
# 				Chrysler (1)
#
# 				Crossroads RV (1)
#
# 				Dodge (9)
#
# 				Ford (21)
#
# 				Forest River (1)
#
# 				Freedom Express by Coachmen (1)
#
# 				GMC (2)
#
# 				Harley-Davidson (5)
#
# 				Heartland (1)
#
# 				Highland Ridge RV (1)
#
# 				Jayco (1)
#
# 				Keystone RV (1)
#
# 				MINI (1)
#
# 				Maple Country (1)
#
# 				Mercedes-Benz (2)
#
# 				Nissan (4)
#
# 				Prime Time (1)
#
# 				Ram (6)
#
# 				Road Warrior by Heartland RV (1)
#
# 				Toyota (2)
#
# 				Winnebago (1)
# 			 Model Filter By  Model   Please Select a Make.Year
# 			Year
# 		 1930 2020
#             1930 - 2020
#             1930 to 2020Price Filter by Price
# 			Filter by Payment
# 			 Pricing calculations are based on $0 down, 5.99% interest and monthly payments for a 72 month term.  1 89800
#             1 - 89800
#             $1 to $89,800  0 544
#             0 - 544
#             $0 to $544Fuel Type Filter By  Fuel Type
# 				Diesel (10)
#
# 				Gas (47)
#
# 				Unspecified (18)
# 			 Kilometres
# 			Kilometres
# 		 0 193000
#             0 - 193000
#             0KM to 193,000KMBody Style Filter By  Body Style
# 				Cargo Extended (2)
#
# 				Commercial (1)
#
# 				Convertible (1)
#
# 				Coupe (3)
#
# 				Hatchback (1)
#
# 				Minivan (2)
#
# 				Other (20)
#
# 				Roadster (2)
#
# 				SUV (25)
#
# 				Sedan (1)
#
# 				Truck (1)
#
# 				Truck Crew Cab (13)
#
# 				Truck Mega Cab (2)
#
# 				Truck Regular Cab (1)
#
# 						Reset Filters
# 					 Search Certified Used Cars, Trucks & SUVs for Sale in Winnipeg Manitoba  75 Items Matching   Sort Vehicles Price: Low to High Price: High to Low Year: Low to High Year: High to Low Make Name: A to Z Make Name: Z to A Model Name: A to Z Model Name: Z to A List View Grid View  12345  of 5  viewing 1-15 of 75 results        2009 BMW 535i xDrive  AWD LOADED *$175 B/W WITH 2 YR WARRANTY INCLUDED!   Original Price  $17,600
# 								+ Tax							   Reduced  $-2,700  Hover for details.  Dealer Discount$2,700   Cash Price  $14,900
# 									+ Tax								  Finance Discount  $-500  Hover for details.  Dealer Discount$500   Finance Price  $14,400  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: W3696Kilometres: 112,000
# 				View More Details
# 			  Compare       2017 Buick Encore ESSENCE AWD LEATHER, ROOF, NAV, BLIND SPOT & MORE!   Original Price  $23,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $22,800
# 									+ Tax								  Finance Discount  $-500  Hover for details.  Dealer Discount$500   Finance Price  $22,300  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5736Kilometres: 57,000
# 				View More Details
# 			  Compare       2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROOF, DRIVER AWARE PKG!   Original Price  $37,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $36,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $35,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5659Kilometres: 42,000
# 				View More Details
# 			  Compare       2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROOF, DRIVER AWARE PKG   Original Price  $37,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $36,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $35,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5653Kilometres: 51,000
# 				View More Details
# 			  Compare       2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROOF, DRIVER AWARE PKG   Original Price  $36,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $35,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $34,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5654Kilometres: 58,000
# 				View More Details
# 			  Compare       2018 Cadillac XT5 LUXURY AWD, PAN ROOF, LANE DEPART, BLIND SPOT!    Original Price  $36,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $35,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $34,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5652Kilometres: 53,000
# 				View More Details
# 			  Compare       2012 Chevrolet Traverse LT2 HTD LEATHER, 7 PASS, TWIN SUNROOFS, LIKE NEW!!   Original Price  $15,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $14,800
# 									+ Tax								  Finance Discount  $-500  Hover for details.  Dealer Discount$500   Finance Price  $14,300  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5637Kilometres: 148,000
# 				View More Details
# 			  Compare       1951 Chevrolet 3100 Pickup STUNNING PRO-STREET SHOW VEHICLE, 6 FIGURE BUILD    Original Price  $86,800
# 								+ Tax							   Reduced  $-7,000  Hover for details.  Dealer Discount$7,000   Cash Price  $79,800
# 									+ Tax								  Finance Discount  $-1  Hover for details.  Dealer Discount$1   Finance Price  $79,799  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GW5729Kilometres: 500
# 				View More Details
# 			  Compare       2012 Chevrolet Traverse LT AWD 8 PASSENGER, HTD SEATS, SUNROOF, MB SUV!   Original Price  $13,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $12,800
# 									+ Tax								  Finance Discount  $-500  Hover for details.  Dealer Discount$500   Finance Price  $12,300  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5673Kilometres: 157,000
# 				View More Details
# 			  Compare       2015 Chevrolet Suburban LT2 4X4, LEATHER, ROOF, 8 PASS, FLAWLESS & SHARP   Original Price  $38,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $37,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $36,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5694Kilometres: 141,000
# 				View More Details
# 			  Compare       2018 Chevrolet Silverado 1500 LT CREW 5.3L 4X4 MAX TOW PKG, HTD SEATS & MORE   Original Price  $35,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $34,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $33,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GW5696Kilometres: 131,000
# 				View More Details
# 			  Compare       2001 Chrysler Prowler MULHOLLAND EDITION, FLAWLESS 1 OWNER LOCAL HISTORY   Original Price  $40,600
# 								+ Tax							   Reduced  $-3,800  Hover for details.  Dealer Discount$3,800   Cash Price  $36,800
# 									+ Tax								  Finance Discount  $-1  Hover for details.  Dealer Discount$1   Finance Price  $36,799  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: W5116Kilometres: 26,500
# 				View More Details
# 			  Compare       2014 Crossroads RV Cruiser Aire CTL28FB REAR BUNK 2 ENTRANCE SUPER SLIDE, LIGHT WT   Original Price  $26,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $25,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $24,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: W5715Length: 32Sleeps: 8+Weight (lb): 5,698Water Tank Capacity: 40
# 				View More Details
# 			  Compare       2017 Dodge Ram 2500 POWER WAGON 6.4L HEMI 4X4, LEATHER, LOADED, SHARP!   Original Price  $43,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $42,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $41,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GW5657AKilometres: 119,000
# 				View More Details
# 			  Compare       2019 Dodge Sprinter 2500 DUAL REAR WHEELS, HIGH ROOF, EXTENDED 3.0L DIESEL   Original Price  $65,800
# 								+ Tax							   Reduced  $-1,000  Hover for details.  Dealer Discount$1,000   Cash Price  $64,800
# 									+ Tax								  Finance Discount  $-1,500  Hover for details.  Dealer Discount$1,500   Finance Price  $63,300  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: CON196AKilometres: 46Body Style: Cargo ExtendedFuel Type: DieselEngine:  3.0L Turbo Diesel with 325 lb-ft torque
# 				View More Details
# 			  Compare     12345  of 5   Please contact the dealership for verification of any information listed herein. Due to human error and other possible complications, we cannot guarantee the accuracy of the information included herein, despite all reasonable attempts being made to ensure its accuracy. The information may differ in specification, price, or any other listed characteristic herein.
#      2009 BMW 535i xDrive  AWD LOADED *$175 B/W WITH 2 YR WARRANTY INCLUDED!   Original Price  $17,600
# 								+ Tax							   Reduced  $-2,700  Hover for details.  Dealer Discount$2,700   Cash Price  $14,900
# 									+ Tax								  Finance Discount  $-500  Hover for details.  Dealer Discount$500   Finance Price  $14,400  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: W3696Kilometres: 112,000
# 				View More Details
# 			  Compare       2017 Buick Encore ESSENCE AWD LEATHER, ROOF, NAV, BLIND SPOT & MORE!   Original Price  $23,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $22,800
# 									+ Tax								  Finance Discount  $-500  Hover for details.  Dealer Discount$500   Finance Price  $22,300  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5736Kilometres: 57,000
# 				View More Details
# 			  Compare       2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROOF, DRIVER AWARE PKG!   Original Price  $37,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $36,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $35,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5659Kilometres: 42,000
# 				View More Details
# 			  Compare       2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROOF, DRIVER AWARE PKG   Original Price  $37,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $36,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $35,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5653Kilometres: 51,000
# 				View More Details
# 			  Compare       2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROOF, DRIVER AWARE PKG   Original Price  $36,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $35,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $34,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5654Kilometres: 58,000
# 				View More Details
# 			  Compare       2018 Cadillac XT5 LUXURY AWD, PAN ROOF, LANE DEPART, BLIND SPOT!    Original Price  $36,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $35,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $34,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5652Kilometres: 53,000
# 				View More Details
# 			  Compare       2012 Chevrolet Traverse LT2 HTD LEATHER, 7 PASS, TWIN SUNROOFS, LIKE NEW!!   Original Price  $15,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $14,800
# 									+ Tax								  Finance Discount  $-500  Hover for details.  Dealer Discount$500   Finance Price  $14,300  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5637Kilometres: 148,000
# 				View More Details
# 			  Compare       1951 Chevrolet 3100 Pickup STUNNING PRO-STREET SHOW VEHICLE, 6 FIGURE BUILD    Original Price  $86,800
# 								+ Tax							   Reduced  $-7,000  Hover for details.  Dealer Discount$7,000   Cash Price  $79,800
# 									+ Tax								  Finance Discount  $-1  Hover for details.  Dealer Discount$1   Finance Price  $79,799  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GW5729Kilometres: 500
# 				View More Details
# 			  Compare       2012 Chevrolet Traverse LT AWD 8 PASSENGER, HTD SEATS, SUNROOF, MB SUV!   Original Price  $13,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $12,800
# 									+ Tax								  Finance Discount  $-500  Hover for details.  Dealer Discount$500   Finance Price  $12,300  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5673Kilometres: 157,000
# 				View More Details
# 			  Compare       2015 Chevrolet Suburban LT2 4X4, LEATHER, ROOF, 8 PASS, FLAWLESS & SHARP   Original Price  $38,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $37,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $36,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GNW5694Kilometres: 141,000
# 				View More Details
# 			  Compare       2018 Chevrolet Silverado 1500 LT CREW 5.3L 4X4 MAX TOW PKG, HTD SEATS & MORE   Original Price  $35,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $34,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $33,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GW5696Kilometres: 131,000
# 				View More Details
# 			  Compare       2001 Chrysler Prowler MULHOLLAND EDITION, FLAWLESS 1 OWNER LOCAL HISTORY   Original Price  $40,600
# 								+ Tax							   Reduced  $-3,800  Hover for details.  Dealer Discount$3,800   Cash Price  $36,800
# 									+ Tax								  Finance Discount  $-1  Hover for details.  Dealer Discount$1   Finance Price  $36,799  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: W5116Kilometres: 26,500
# 				View More Details
# 			  Compare       2014 Crossroads RV Cruiser Aire CTL28FB REAR BUNK 2 ENTRANCE SUPER SLIDE, LIGHT WT   Original Price  $26,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $25,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $24,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: W5715Length: 32Sleeps: 8+Weight (lb): 5,698Water Tank Capacity: 40
# 				View More Details
# 			  Compare       2017 Dodge Ram 2500 POWER WAGON 6.4L HEMI 4X4, LEATHER, LOADED, SHARP!   Original Price  $43,600
# 								+ Tax							   Reduced  $-800  Hover for details.  Dealer Discount$800   Cash Price  $42,800
# 									+ Tax								  Finance Discount  $-1,000  Hover for details.  Dealer Discount$1,000   Finance Price  $41,800  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: GW5657AKilometres: 119,000
# 				View More Details
# 			  Compare       2019 Dodge Sprinter 2500 DUAL REAR WHEELS, HIGH ROOF, EXTENDED 3.0L DIESEL   Original Price  $65,800
# 								+ Tax							   Reduced  $-1,000  Hover for details.  Dealer Discount$1,000   Cash Price  $64,800
# 									+ Tax								  Finance Discount  $-1,500  Hover for details.  Dealer Discount$1,500   Finance Price  $63,300  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     Stock #: CON196AKilometres: 46Body Style: Cargo ExtendedFuel Type: DieselEngine:  3.0L Turbo Diesel with 325 lb-ft torque
# 				View More Details
# 			  Compare
# 1Personalize Your Options 2Apply For Financing Let’s Structure a Deal That Works For You We understand that purchasing a vehicle is a big decision, so we want you to be paying a price that you’re comfortable with. Let’s structure a deal that works for you below:  Apply Now                                         Please leave this field empty. Full Name* Email* Phone Number Preferred Contact Method---CallEmailText Message I agree to receive periodical offers, newsletter, safety and recall updates from the dealership. Consent can be withdrawn at any time.
#
#
#
# Visit Our Location
# 5195 Portage Ave., Headingley, MB, R4H 1E1
#
# Get Directions
#
#
#
# Contact Us
#
#
#
#
#
# Sales
#
#
# (888) 639-2619
#
#
#
# Toll Free
#
#
# (204) 896-7001
#
#
#
#
#
#
# Email Us
#
#
#
#
#
# Hours Of Operation
#
#
#
#
#
# Mon - Tue
# 9am - 7pm
#
#
# Wed - Sat
# 9am - 6pm
#
#
# Sun
# closed
#
#
#
#
#
#
#
# Connect With Us
#
# FacebookTwitterInstagram

# %%
#Finding the titles of cars using find_all
#All the titles are present in h4 class : vehicle-card__title 
car_titles = []
a=soup.findAll('h4',{"class":"vehicle-card__title"})
for i in a :
    print(i.text)#printing titles
    car_titles.append(i.text)#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# 2009 BMW 535i xDrive  AWD LOADED *$175 B/W WITH 2 YR WARRANTY INCLUDED!
# 2017 Buick Encore ESSENCE AWD LEATHER, ROOF, NAV, BLIND SPOT & MORE!
# 2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROOF, DRIVER AWARE PKG!
# 2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROOF, DRIVER AWARE PKG
# 2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROOF, DRIVER AWARE PKG
# 2018 Cadillac XT5 LUXURY AWD, PAN ROOF, LANE DEPART, BLIND SPOT!
# 2012 Chevrolet Traverse LT2 HTD LEATHER, 7 PASS, TWIN SUNROOFS, LIKE NEW!!
# 1951 Chevrolet 3100 Pickup STUNNING PRO-STREET SHOW VEHICLE, 6 FIGURE BUILD
# 2012 Chevrolet Traverse LT AWD 8 PASSENGER, HTD SEATS, SUNROOF, MB SUV!
# 2015 Chevrolet Suburban LT2 4X4, LEATHER, ROOF, 8 PASS, FLAWLESS & SHARP
# 2018 Chevrolet Silverado 1500 LT CREW 5.3L 4X4 MAX TOW PKG, HTD SEATS & MORE
# 2001 Chrysler Prowler MULHOLLAND EDITION, FLAWLESS 1 OWNER LOCAL HISTORY
# 2014 Crossroads RV Cruiser Aire CTL28FB REAR BUNK 2 ENTRANCE SUPER SLIDE, LIGHT WT
# 2017 Dodge Ram 2500 POWER WAGON 6.4L HEMI 4X4, LEATHER, LOADED, SHARP!
# 2019 Dodge Sprinter 2500 DUAL REAR WHEELS, HIGH ROOF, EXTENDED 3.0L DIESEL
# ['2009 BMW 535i xDrive  AWD LOADED *$175 B/W WITH 2 YR WARRANTY INCLUDED!', '2017 Buick Encore ESSENCE AWD LEATHER, ROOF, NAV, BLIND SPOT & MORE!', '2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROOF, DRIVER AWARE PKG!', '2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROOF, DRIVER AWARE PKG', '2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROOF, DRIVER AWARE PKG', '2018 Cadillac XT5 LUXURY AWD, PAN ROOF, LANE DEPART, BLIND SPOT! ', '2012 Chevrolet Traverse LT2 HTD LEATHER, 7 PASS, TWIN SUNROOFS, LIKE NEW!!', '1951 Chevrolet 3100 Pickup STUNNING PRO-STREET SHOW VEHICLE, 6 FIGURE BUILD ', '2012 Chevrolet Traverse LT AWD 8 PASSENGER, HTD SEATS, SUNROOF, MB SUV!', '2015 Chevrolet Suburban LT2 4X4, LEATHER, ROOF, 8 PASS, FLAWLESS & SHARP', '2018 Chevrolet Silverado 1500 LT CREW 5.3L 4X4 MAX TOW PKG, HTD SEATS & MORE', '2001 Chrysler Prowler MULHOLLAND EDITION, FLAWLESS 1 OWNER LOCAL HISTORY', '2014 Crossroads RV Cruiser Aire CTL28FB REAR BUNK 2 ENTRANCE SUPER SLIDE, LIGHT WT', '2017 Dodge Ram 2500 POWER WAGON 6.4L HEMI 4X4, LEATHER, LOADED, SHARP!', '2019 Dodge Sprinter 2500 DUAL REAR WHEELS, HIGH ROOF, EXTENDED 3.0L DIESEL']
# 15

# %%
mileage = []
stock = []
# taking empty lists

#All the specifications are inside ul class: detailed-specs 
spec= soup.find_all("ul",{"class": "detailed-specs"})

for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('li')#finding all li inside ul
    for li in lis:
        if 'Kilometres' in li.text:# if present
            mileage.append(li.text.replace("Kilometres: ",""))# then append
        if 'Stock' in li.text:# if present
            stock.append(li.text.replace("Stock #:",""))#then append
            
#priniting individual lists
print(mileage)
print(stock)
# Out:
# ['112,000', '57,000', '42,000', '51,000', '58,000', '53,000', '148,000', '500', '157,000', '141,000', '131,000', '26,500', '119,000', '46']
# [' W3696', ' GNW5736', ' GNW5659', ' GNW5653', ' GNW5654', ' GNW5652', ' GNW5637', ' GW5729', ' GNW5673', ' GNW5694', ' GW5696', ' W5116', ' W5715', ' GW5657A', ' CON196A']

# %%
#Finding the discounted price on cars using find_all
#All the  discounted price  are present in div class : price-block__single price-block--expanded price-block__single--finance
price = []
c = soup.findAll('div',{"class":"price-block__single price-block--expanded"})
for i in c :
    sp=i.findAll('div',{"class":"price-block__price price-block__price--lg price-block__price--primary"})#digging further
    for j in sp:
        s=j.find('span',{"class":"df aifs"}).text.split("df aifs")[0]#actual values are inside span class :df aifs
        print(s)#printing discounted prices
        price.append(s)#appending in a list
print(price)#printing list
len(price)#length oflist
# Out:
# $14,400
# $22,300
# $35,800
# $35,800
# $34,800
# $34,800
# $14,300
# $79,799
# $12,300
# $36,800
# $33,800
# $36,799
# $24,800
# $41,800
# $63,300
# ['$14,400', '$22,300', '$35,800', '$35,800', '$34,800', '$34,800', '$14,300', '$79,799', '$12,300', '$36,800', '$33,800', '$36,799', '$24,800', '$41,800', '$63,300']
# 15

# %%
#creating dict of scrapped data
dict = {
    'Title' : car_titles ,
    'Mileage' : mileage, 
    'Stock' : stock ,
    'Price' : price
}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                                                 Title  Mileage     Stock  \
# 0   2009 BMW 535i xDrive  AWD LOADED *$175 B/W WIT...  112,000     W3696
# 1   2017 Buick Encore ESSENCE AWD LEATHER, ROOF, N...   57,000   GNW5736
# 2   2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROO...   42,000   GNW5659
# 3   2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROO...   51,000   GNW5653
# 4   2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROO...   58,000   GNW5654
# 5   2018 Cadillac XT5 LUXURY AWD, PAN ROOF, LANE D...   53,000   GNW5652
# 6   2012 Chevrolet Traverse LT2 HTD LEATHER, 7 PAS...  148,000   GNW5637
# 7   1951 Chevrolet 3100 Pickup STUNNING PRO-STREET...      500    GW5729
# 8   2012 Chevrolet Traverse LT AWD 8 PASSENGER, HT...  157,000   GNW5673
# 9   2015 Chevrolet Suburban LT2 4X4, LEATHER, ROOF...  141,000   GNW5694
# 10  2018 Chevrolet Silverado 1500 LT CREW 5.3L 4X4...  131,000    GW5696
# 11  2001 Chrysler Prowler MULHOLLAND EDITION, FLAW...   26,500     W5116
# 12  2014 Crossroads RV Cruiser Aire CTL28FB REAR B...  119,000     W5715
# 13  2017 Dodge Ram 2500 POWER WAGON 6.4L HEMI 4X4,...       46   GW5657A
# 14  2019 Dodge Sprinter 2500 DUAL REAR WHEELS, HIG...     None   CON196A
#
#       Price
# 0   $14,400
# 1   $22,300
# 2   $35,800
# 3   $35,800
# 4   $34,800
# 5   $34,800
# 6   $14,300
# 7   $79,799
# 8   $12,300
# 9   $36,800
# 10  $33,800
# 11  $36,799
# 12  $24,800
# 13  $41,800
# 14  $63,300

# %%
df['Dealer'] = 'winnipegautogroup'
df['Condition'] = ''

# %%
split_title = df["Title"].str.split(" ", n = 3, expand = True) 
# splitting Tile column 
df["Make Year"]= split_title[0] 
df["Make"]= split_title[1] 
df["Model"]= split_title[2] 
df
# Out:
#                                                 Title  Mileage     Stock  \
# 0   2009 BMW 535i xDrive  AWD LOADED *$175 B/W WIT...  112,000     W3696
# 1   2017 Buick Encore ESSENCE AWD LEATHER, ROOF, N...   57,000   GNW5736
# 2   2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROO...   42,000   GNW5659
# 3   2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROO...   51,000   GNW5653
# 4   2018 Cadillac XT5 LUXURY AWD, LEATHER, PAN ROO...   58,000   GNW5654
# 5   2018 Cadillac XT5 LUXURY AWD, PAN ROOF, LANE D...   53,000   GNW5652
# 6   2012 Chevrolet Traverse LT2 HTD LEATHER, 7 PAS...  148,000   GNW5637
# 7   1951 Chevrolet 3100 Pickup STUNNING PRO-STREET...      500    GW5729
# 8   2012 Chevrolet Traverse LT AWD 8 PASSENGER, HT...  157,000   GNW5673
# 9   2015 Chevrolet Suburban LT2 4X4, LEATHER, ROOF...  141,000   GNW5694
# 10  2018 Chevrolet Silverado 1500 LT CREW 5.3L 4X4...  131,000    GW5696
# 11  2001 Chrysler Prowler MULHOLLAND EDITION, FLAW...   26,500     W5116
# 12  2014 Crossroads RV Cruiser Aire CTL28FB REAR B...  119,000     W5715
# 13  2017 Dodge Ram 2500 POWER WAGON 6.4L HEMI 4X4,...       46   GW5657A
# 14  2019 Dodge Sprinter 2500 DUAL REAR WHEELS, HIG...     None   CON196A
#
#       Price             Dealer Condition Make Year        Make      Model
# 0   $14,400  winnipegautogroup                2009         BMW       535i
# 1   $22,300  winnipegautogroup                2017       Buick     Encore
# 2   $35,800  winnipegautogroup                2018    Cadillac        XT5
# 3   $35,800  winnipegautogroup                2018    Cadillac        XT5
# 4   $34,800  winnipegautogroup                2018    Cadillac        XT5
# 5   $34,800  winnipegautogroup                2018    Cadillac        XT5
# 6   $14,300  winnipegautogroup                2012   Chevrolet   Traverse
# 7   $79,799  winnipegautogroup                1951   Chevrolet       3100
# 8   $12,300  winnipegautogroup                2012   Chevrolet   Traverse
# 9   $36,800  winnipegautogroup                2015   Chevrolet   Suburban
# 10  $33,800  winnipegautogroup                2018   Chevrolet  Silverado
# 11  $36,799  winnipegautogroup                2001    Chrysler    Prowler
# 12  $24,800  winnipegautogroup                2014  Crossroads         RV
# 13  $41,800  winnipegautogroup                2017       Dodge        Ram
# 14  $63,300  winnipegautogroup                2019       Dodge   Sprinter

# %%
df.drop(columns =["Title"], inplace = True)
df
# Out:
#     Mileage     Stock    Price             Dealer Condition Make Year  \
# 0   112,000     W3696  $14,400  winnipegautogroup                2009
# 1    57,000   GNW5736  $22,300  winnipegautogroup                2017
# 2    42,000   GNW5659  $35,800  winnipegautogroup                2018
# 3    51,000   GNW5653  $35,800  winnipegautogroup                2018
# 4    58,000   GNW5654  $34,800  winnipegautogroup                2018
# 5    53,000   GNW5652  $34,800  winnipegautogroup                2018
# 6   148,000   GNW5637  $14,300  winnipegautogroup                2012
# 7       500    GW5729  $79,799  winnipegautogroup                1951
# 8   157,000   GNW5673  $12,300  winnipegautogroup                2012
# 9   141,000   GNW5694  $36,800  winnipegautogroup                2015
# 10  131,000    GW5696  $33,800  winnipegautogroup                2018
# 11   26,500     W5116  $36,799  winnipegautogroup                2001
# 12  119,000     W5715  $24,800  winnipegautogroup                2014
# 13       46   GW5657A  $41,800  winnipegautogroup                2017
# 14     None   CON196A  $63,300  winnipegautogroup                2019
#
#           Make      Model
# 0          BMW       535i
# 1        Buick     Encore
# 2     Cadillac        XT5
# 3     Cadillac        XT5
# 4     Cadillac        XT5
# 5     Cadillac        XT5
# 6    Chevrolet   Traverse
# 7    Chevrolet       3100
# 8    Chevrolet   Traverse
# 9    Chevrolet   Suburban
# 10   Chevrolet  Silverado
# 11    Chrysler    Prowler
# 12  Crossroads         RV
# 13       Dodge        Ram
# 14       Dodge   Sprinter

# %%
#Dataframe to csv
df.to_csv('winniepegautogroup.csv')
