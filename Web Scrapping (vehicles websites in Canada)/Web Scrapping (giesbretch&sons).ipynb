# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = input(("Enter url : "))
# "http://www.giesbrechtandsons.com/VehicleSearchResults"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class deck
data=soup.findAll('div',{"class":"deck"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
# Search Inventory
#
#
# Submit
#
#
#
#
# Filter
# Clear All
# Category
#
#
#
#
#
# New
# 57
#
#
#
#
#
#
# Demo
# 2
#
#
#
#
#
#
# Used
# 8
#
#
#
#
#
#
# Certified
# 1
#
#
#
#
#
# Type
#
#
#
#
#
# Car
# 8
#
#
#
#
#
#
# SUV
# 38
#
#
#
#
#
#
# Truck
# 18
#
#
#
#
#
#
# Van
# 1
#
#
#
#
# Make
#
#
#
#
#
# Buick
# 12
#
#
#
#
#
#
# Chevrolet
# 40
#
#
#
#
#
#
# GMC
# 11
#
#
#
#
#
#
# Honda
# 1
#
#
#
#
#
#
# Hyundai
# 1
#
#
#
#
# Model
#
#
#
#
#
# Acadia
# 4
#
#
#
#
#
#
# Blazer
# 3
#
#
#
#
#
#
# Canyon
# 1
#
#
#
#
#
#
# Colorado
# 1
#
#
#
#
#
#
# Elantra
# 1
#
#
#
#
#
#
# Enclave
# 2
#
#
#
#
#
#
# Encore
# 1
#
#
#
#
#
#
# Encore GX
# 6
#
#
#
#
#
#
# Envision
# 3
#
#
#
#
#
#
# Equinox
# 8
#
#
#
#
#
#
# Impala
# 1
#
#
#
#
#
#
# Malibu
# 1
#
#
#
#
#
#
# Odyssey
# 1
#
#
#
#
#
#
# Sierra 1500
# 2
#
#
#
#
#
#
# Sierra 2500HD
# 1
#
#
#
#
#
#
# Silverado 1500
# 13
#
#
#
#
#
#
# Spark
# 5
#
#
#
#
#
#
# Terrain
# 3
#
#
#
#
#
#
# Traverse
# 3
#
#
#
#
#
#
# Trax
# 5
#
#
#
#
# Body Color
#
#
#
#
#
# Black
# ...

# %%
#Finding the titles of cars using find_all
#All the titles are present in h4 itemprop : name
car_titles = []#taking an empty list
a=soup.findAll('h4',{"itemprop":"name"})
for i in a :
    print(i.text.strip())#printing titles
    car_titles.append(i.text.replace("\n","").strip())#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# New
# 2019
#
#
# Chevrolet
# Impala
# LT
# New
# 2020
#
#
# Buick
# Enclave
# Premium
# New
# 2020
#
#
# Buick
# Encore
# Preferred
# New
# 2020
#
#
# Buick
# Encore GX
# Preferred
# New
# 2020
#
#
# Buick
# Envision
# Preferred
# New
# 2020
#
#
# Buick
# Envision
# Preferred
# New
# 2020
#
#
# Buick
# Envision
# Preferred
# New
# 2020
#
#
# Chevrolet
# Blazer
# LT
# New
# 2020
#
#
# Chevrolet
# Blazer
# LT
# New
# 2020
#
#
# Chevrolet
# Blazer
# True North
# New
# 2020
#
#
# Chevrolet
# Equinox
# LS
# New
# 2020
#
#
# Chevrolet
# Equinox
# LS
# New
# 2020
#
#
# Chevrolet
# Equinox
# LS
# New
# 2020
#
#
# Chevrolet
# Equinox
# LT
# New
# 2020
#
#
# Chevrolet
# Equinox
# LT
# New
# 2020
#
#
# Chevrolet
# Equinox
# LT
# New
# 2020
#
#
# Chevrolet
# Equinox
# LT
# New
# 2020
#
#
# Chevrolet
# Malibu
# LT
# New
# 2020
#
#
# Chevrolet
# Silverado 1500
# Custom
# New
# 2020
#
#
# Chevrolet
# Silverado 1500
# Custom
# New
# 2020
#
#
# Chevrolet
# Silverado 1500
# RST
# New
# 2020
#
#
# ...

# %%
#Finding the price of cars using find_all
#All the price are present in span class: value big-and-bold
car_price = [] #taking an empty list 
a=soup.findAll('span',{"class":"value big-and-bold"})
for i in a :
    print(i.text)#printing car price
    car_price.append(i.text)#appending values
print(car_price)#printing car price
len(car_price)#printing length of list
# Out:
# $39,335
# $62,283
# $29,643
# $31,088
# $38,398
# $38,893
# $40,478
# $40,488
# $42,888
# $45,488
# $32,588
# $32,648
# $33,303
# $34,488
# $36,583
# $36,583
# $38,778
# $34,178
# $52,428
# $53,478
# $56,698
# $59,713
# $59,988
# $61,868
# ['$39,335', '$62,283', '$29,643', '$31,088', '$38,398', '$38,893', '$40,478', '$40,488', '$42,888', '$45,488', '$32,588', '$32,648', '$33,303', '$34,488', '$36,583', '$36,583', '$38,778', '$34,178', '$52,428', '$53,478', '$56,698', '$59,713', '$59,988', '$61,868']
# 24

# %%
interior = [] #taking an empty  list
a =soup.find_all('span',{"itemprop":"vehicleInteriorColor"}) # scrapping details
for i in a:
    print(i.text)
    interior.append(i.text) #appending values in an empty list
print(interior) #printing list
len(interior) #length of list
# Out:
# Jet Black
# Dark Galvanized
# Ebony
# Ebony Ebony Accents
# Light Neutral
# Light Neutral
# Light Neutral
# Jet Black
# Jet Black
# Jet Black
# Medium Ash Gray
# Medium Ash Gray
# Medium Ash Gray
# Jet Black
# Jet Black
# Jet Black
# Jet Black
# Jet Black
# Jet Black
# Jet Black
# Jet Black
# Jet Black
# Jet Black
# Jet Black
# ['Jet Black', 'Dark Galvanized', 'Ebony', 'Ebony Ebony Accents', 'Light Neutral', 'Light Neutral', 'Light Neutral', 'Jet Black', 'Jet Black', 'Jet Black', 'Medium Ash Gray', 'Medium Ash Gray', 'Medium Ash Gray', 'Jet Black', 'Jet Black', 'Jet Black', 'Jet Black', 'Jet Black', 'Jet Black', 'Jet Black', 'Jet Black', 'Jet Black', 'Jet Black', 'Jet Black']
# 24

# %%
cylinders = []#taking an empty  list
a =soup.find_all('li',{"template":"vehicleIdentitySpecs-cylinders"})# scrapping details
for i in a:
    print(i.text)
    cylinders.append(i.text.replace("Cylinders\n",""))#appending values in an empty list
print(cylinders)#printing list
len(cylinders)#length of list
# Out:
# Cylinders
# 6
# Cylinders
# 6
# Cylinders
# 4
# Cylinders
# 3
# Cylinders
# 4
# Cylinders
# 4
# Cylinders
# 4
# Cylinders
# N/A
# Cylinders
# 4
# Cylinders
# 6
# Cylinders
# 4
# Cylinders
# 4
# Cylinders
# 4
# Cylinders
# 4
# Cylinders
# 4
# Cylinders
# 4
# Cylinders
# 4
# Cylinders
# 4
# Cylinders
# 8
# Cylinders
# 8
# Cylinders
# 8
# Cylinders
# 8
# Cylinders
# 8
# Cylinders
# 8
# ['6', '6', '4', '3', '4', '4', '4', 'N/A', '4', '6', '4', '4', '4', '4', '4', '4', '4', '4', '8', '8', '8', '8', '8', '8']
# 24

# %%
exterior = []#taking an empty  list
a =soup.find_all('li',{"template":"vehicleIdentitySpecs-exterior"})# scrapping details
for i in a:
    print(i.text)
    exterior.append(i.text.replace("Exterior\n",""))#appending values in an empty list
print(exterior)#printing list
len(exterior)#length of list
# Out:
# Exterior
# Summit White
# Exterior
# Ebony Twilight Metallic
# Exterior
# Ebony Twilight Metallic
# Exterior
# Ebony Twilight Metallic
# Exterior
# Summit White
# Exterior
# Espresso Metallic
# Exterior
# Ebony Twilight Metallic
# Exterior
# Silver Ice Metallic
# Exterior
# Summit White
# Exterior
# Black
# Exterior
# Summit White
# Exterior
# Summit White
# Exterior
# Nightfall Gray Metallic
# Exterior
# Pacific Blue Metallic
# Exterior
# Pacific Blue Metallic
# Exterior
# Midnight Blue Metallic
# Exterior
# Cajun Red Tintcoat
# Exterior
# Summit White
# Exterior
# Northsky Blue Metallic
# Exterior
# Cajun Red Tintcoat
# Exterior
# Shadow Gray Metallic
# Exterior
# Red Hot
# Exterior
# Satin Steel Metallic
# Exterior
# Summit White
# ...

# %%
stock = []#taking an empty  list
a =soup.find_all('li',{"template":"vehicleIdentitySpecs-stockNumber"})# scrapping details
for i in a:
    print(i.text)
    stock.append(i.text.replace("Stock Number\n",""))#appending values in an empty list
print(stock)#printing list
len(stock)#length of list
# Out:
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# Stock Number
# N/A
# ['N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A']
# 24

# %%
mileage = []#taking an empty  list
a =soup.find_all('li',{"template":"vehicleIdentitySpecs-miles"})# scrapping details
for i in a:
    print(i.text)
    mileage.append(i.text.replace("Kilometers\n\n",""))#appending values in an empty list
print(mileage)#printing list
len(mileage)#length of list
# Out:
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# Kilometers
#
# N/A
# ['N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A']
# 24

# %%
engine = []#taking an empty  list
a =soup.find_all('li',{"template":"vehicleIdentitySpecs-engine"})# scrapping details
for i in a:
    print(i.text)
    engine.append(i.text.replace("Engine\n\n\n",""))#appending values in an empty list
print(engine)#printing list
len(engine)#length of list
# Out:
# Engine
#
#
# 3.6L DOHC V6 DI, VVT, FLEXFUEL
#
# Engine
#
#
# 3.6L DOHC SIDI V6 W/VVT
#
# Engine
#
#
# 1.4L, 4 CYL, DOHC, TURBOCHARGED
#
# Engine
#
#
# ECOTEC 1.3L TURBO
#
# Engine
#
#
# 2.5L DOHC SIDI I4 W/VVT
#
# Engine
#
#
# 2.5L DOHC SIDI I4 W/VVT
#
# Engine
#
#
# 2.5L DOHC SIDI I4 W/VVT
#
# Engine
#
#
# ENGINE, 2.0L TURBO, 4-CYL, SIDI
#
# Engine
#
#
# ENGINE, 2.0L TURBO, 4-CYL, SIDI
#
# Engine
#
#
# 3.6L DOHC SIDI V6 W/VVT
#
# Engine
#
#
# 1.5L DOHC I4 TURBO, VVT
#
# Engine
#
#
# 1.5L DOHC I4 TURBO, VVT
#
# Engine
#
#
# 1.5L DOHC I4 TURBO, VVT
#
# Engine
#
#
# 1.5L DOHC I4 TURBO, VVT
#
# Engine
#
#
# 1.5L DOHC I4 TURBO, VVT
#
# Engine
#
#
# 1.5L DOHC I4 TURBO, VVT
#
# Engine
#
#
# 1.5L DOHC I4 TURBO, VVT
#
# Engine
#
#
# 1.5L TURBO, DOHC 4 CYLINDER DI
#
# Engine
#
#
# 5.3L ECOTEC3 V8 ENGINE
#
# Engine
#
#
# 5.3L ECOTEC3 V8 ENGINE
#
# Engine
#
#
# 5.3L ECOTEC3 V8 ENGINE
#
# Engine
#
#
# 5.3L ECOTEC3 V8 ENGINE
#
# Engine
#
#
# 5.3L ECOTEC3 V8 ENGINE
#
# Engine
#
#
# ...

# %%
transmission = []#taking an empty  list
a =soup.find_all('li',{"template":"vehicleIdentitySpecs-transmission"})# scrapping details
for i in a:
    print(i.text)
    transmission.append(i.text.replace("Transmission\n\n",""))#appending values in an empty list
print(transmission)#printing list
len(transmission)#length of list
# Out:
# Transmission
#
# 6-SPD AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# 9-SPEED AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# 6-SPEED AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# TRANSMISSION, 9-SPD AUTOMATIC
#
#
# Transmission
#
# 6-SPEED AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# 6-SPEED AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# 6-SPEED AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# TRANSMISSION, 9-SPD AUTOMATIC
#
#
# Transmission
#
# TRANSMISSION, 9-SPD AUTOMATIC
#
#
# Transmission
#
# 9-SPEED AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# 6-SPEED AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# 6-SPEED AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# 6-SPEED AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# 6-SPEED AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# 6-SPEED AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# 6-SPEED AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# 6-SPEED AUTOMATIC TRANSMISSION
#
#
# Transmission
#
# CONTINUOUSLY VARIABLE
#
#
# Transmission
#
# ...

# %%
vin = []#taking an empty  list
a =soup.find_all('li',{"template":"vehicleIdentitySpecs-vin"})# scrapping details
for i in a:
    print(i.text)
    vin.append(i.text.replace("VIN\n\n",""))#appending values in an empty list
print(vin)#printing list
len(vin)#length of list
# Out:
# VIN
#
# 2G11Z5S35K9149813
# VIN
#
# 5GAEVBKW5LJ262410
# VIN
#
# KL4CJESB9LB338621
# VIN
#
# KL4MMCSL0LB130426
# VIN
#
# LRBFX1SAXLD194937
# VIN
#
# LRBFX1SA6LD170389
# VIN
#
# LRBFX1SA4LD053913
# VIN
#
# 3GNKBCR45LS659321
# VIN
#
# 3GNKBHR45LS653905
# VIN
#
# 3GNKBJRS3LS635053
# VIN
#
# 2GNAXSEV2L6125343
# VIN
#
# 2GNAXSEV4L6229526
# VIN
#
# 2GNAXSEV2L6269958
# VIN
#
# 2GNAXUEV1L6263337
# VIN
#
# 2GNAXUEV4L6165175
# VIN
#
# 2GNAXUEVXL6143276
# VIN
#
# 2GNAXUEVXL6270240
# VIN
#
# 1G1ZD5ST7LF142274
# VIN
#
# 1GCUYBEF0LZ312239
# VIN
#
# 1GCUYBEF4LZ283537
# VIN
#
# 1GCRYEED3LZ378404
# VIN
#
# 1GCUYDED6LZ298129
# VIN
#
# 1GCUYDED3LZ309300
# VIN
#
# 1GCUYEED6LZ282082
# ...

# %%
location = []#taking an empty  list
a =soup.find_all('li',{"template":"vehicleIdentitySpecs-location"})# scrapping details
for i in a:
    print(i.text)
    location.append(i.text.replace("Location\n\n\n",""))#appending values in an empty list
print(location)#printing list
len(location)#length of list
# Out:
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# Location
#
#
# Giesbrecht & Sons Ltd
#
# ...

# %%
model_code = []#taking an empty  list
a =soup.find_all('li',{"template":"vehicleIdentitySpecs-modelCode"})# scrapping details
for i in a:
    print(i.text)
    model_code.append(i.text.replace("Model Code\n\n",""))#appending values in an empty list
print(model_code)#printing list
len(model_code)#length of list
# Out:
# Model Code
#
# 1GY69
#
# Model Code
#
# 4NJ56
#
# Model Code
#
# 4JM76
#
# Model Code
#
# 4TV06
#
# Model Code
#
# 4XY26
#
# Model Code
#
# 4XY26
#
# Model Code
#
# 4XY26
#
# Model Code
#
# 1NK26
#
# Model Code
#
# 1NR26
#
# Model Code
#
# 1NR26
#
# Model Code
#
# 1XX26
#
# Model Code
#
# 1XX26
#
# Model Code
#
# 1XX26
#
# Model Code
#
# 1XY26
#
# Model Code
#
# 1XY26
#
# Model Code
#
# 1XY26
#
# Model Code
#
# 1XY26
#
# Model Code
#
# 1ZD69
#
# Model Code
#
# CK10543
#
# Model Code
#
# CK10543
#
# Model Code
#
# CK10753
#
# Model Code
#
# CK10543
#
# Model Code
#
# CK10543
#
# Model Code
#
# CK10543
#
# ['1GY69\n', '4NJ56\n', '4JM76\n', '4TV06\n', '4XY26\n', '4XY26\n', '4XY26\n', '1NK26\n', '1NR26\n', '1NR26\n', '1XX26\n', '1XX26\n', '1XX26\n', '1XY26\n', '1XY26\n', '1XY26\n', '1XY26\n', '1ZD69\n', 'CK10543\n', 'CK10543\n', 'CK10753\n', 'CK10543\n', 'CK10543\n', 'CK10543\n']
# 24

# %%
#creating dict of scrapped data
dict = {
    'Title' : car_titles,
    'Price' : car_price,
    'Interior':interior,
    'Exterior':exterior,
    'Cylinders':cylinders,
    'Stock' : stock,
    'Mileage': mileage,
    'Engine':engine,
    'Transmission': transmission,
    'VIN':vin,
    'Transmission': transmission,
    'Location':location,
    'Model Code':model_code
    
}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                                    Title    Price             Interior  \
# 0               New2019ChevroletImpalaLT  $39,335            Jet Black
# 1             New2020BuickEnclavePremium  $62,283      Dark Galvanized
# 2            New2020BuickEncorePreferred  $29,643                Ebony
# 3         New2020BuickEncore GXPreferred  $31,088  Ebony Ebony Accents
# 4          New2020BuickEnvisionPreferred  $38,398        Light Neutral
# 5          New2020BuickEnvisionPreferred  $38,893        Light Neutral
# 6          New2020BuickEnvisionPreferred  $40,478        Light Neutral
# 7               New2020ChevroletBlazerLT  $40,488            Jet Black
# 8               New2020ChevroletBlazerLT  $42,888            Jet Black
# 9       New2020ChevroletBlazerTrue North  $45,488            Jet Black
# 10             New2020ChevroletEquinoxLS  $32,588      Medium Ash Gray
# 11             New2020ChevroletEquinoxLS  $32,648      Medium Ash Gray
# ...

# %%
#Dataframe to csv
df.to_csv('giesbretch&sons.csv')
