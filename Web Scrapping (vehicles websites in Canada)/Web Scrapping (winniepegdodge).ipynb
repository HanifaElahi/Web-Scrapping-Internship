# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = "https://www.winnipegdodge.com/vehicles/new/?view=grid&sc=new"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class row grid-row
data=soup.findAll('div',{"class":"row grid-row"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
#         2020 Jeep Cherokee Limited  - Luxury Interior - $239 B/W   Stock #: LD550251Condition: NewEngine: 3.2L Pentastar V-6 engineDrive Train: 4x4   Initial Price  $48,760    Initial Discount  $-5,626  Hover for details.  Dealer Discount$5,626   Dealer Price  $43,134  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare      Watch Video    2020 Jeep Cherokee Limited  - Luxury Interior - $240 B/W   Stock #: LD562287Condition: NewEngine: 3.2L Pentastar V-6 engineDrive Train: 4x4   Initial Price  $48,980    Initial Discount  $-5,648  Hover for details.  Dealer Discount$5,648   Dealer Price  $43,332  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare      Watch Video    2020 RAM 1500 Sport  -  Android Auto -  Apple CarPlay - $349 B/W   Stock #: LN228421Condition: NewEngine: 5.7L HEMI V-8 engineDrive Train: 4x4   Initial Price  $73,415    Initial Discount  $-10,000  Hover for details.  Dealer Discount$10,000   Dealer Price  $63,415  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare      Watch Video    2020 RAM 1500 Limited  - Limited -  Navigation - $416 B/W   Stock #: LN228339Condition: NewEngine: 5.7L HEMI V-8 engineDrive Train: 4x4   Initial Price  $88,675    Initial Discount  $-10,000  Hover for details.  Dealer Discount$10,000   Dealer Price  $78,675  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare      Watch Video    2020 RAM 1500 Longhorn  - Longhorn -  Texas Tough - $405 B/W   Stock #: LN211044Condition: NewEngine: 3.0L EcoDiesel V-6 intercooled turbo diesel engineDrive Train: 4x4   Initial Price  $89,830    Initial Discount  $-12,500  Hover for details.  Dealer Discount$12,500   Dealer Price  $77,330  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare      Watch Video    2020 RAM 1500 Longhorn  - Longhorn -  Texas Tough - $406 B/W   Stock #: LN258999Condition: NewEngine: 3.0L EcoDiesel V-6 intercooled turbo diesel engineDrive Train: 4x4   Initial Price  $90,025    Initial Discount  $-12,500  Hover for details.  Dealer Discount$12,500   Dealer Price  $77,525  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare          2020 Dodge Grand Caravan Crew  - Aluminum Wheels - $209 B/W   Stock #: LR159730Condition: NewEngine: 3.6L Pentastar VVT V-6 engineDrive Train: FWD   Initial Price  $51,305    Initial Discount  $-12,613  Hover for details.  Dealer Discount$12,613   Dealer Price  $38,692  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare          2020 RAM 1500 Classic Express  -  Power Windows - $234 B/W   Stock #: LS117280Condition: NewEngine: 3.6L Pentastar V-6 engineDrive Train: 4x4   Initial Price  $57,265    Initial Discount  $-14,316  Hover for details.  Dealer Discount$14,316   Dealer Price  $42,949  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare          2020 RAM 1500 Classic Express  -  Power Windows - $241 B/W   Stock #: LS114110Condition: NewEngine: 5.7L HEMI V-8 engineDrive Train: 4x4   Initial Price  $57,245    Initial Discount  $-14,311  Hover for details.  Dealer Discount$14,311   Dealer Price  $42,934  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare      Watch Video    2020 Dodge Grand Caravan SE CVP  - Dual Zone AC - $161 B/W   Stock #: LR167734Condition: NewEngine: 3.6L Pentastar VVT V-6 engineDrive Train: FWD   Initial Price  $36,660    Initial Discount  $-7,332  Hover for details.  Dealer Discount$7,332   Dealer Price  $29,328  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare          2020 RAM 1500 Classic Warlock  - Bluetooth -  SiriusXM - $266 B/W   Stock #: LS117288Condition: NewEngine: 3.6L Pentastar V-6 engineDrive Train: 4x4   Initial Price  $64,810    Initial Discount  $-16,202  Hover for details.  Dealer Discount$16,202   Dealer Price  $48,608  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare          2020 Jeep Cherokee Trailhawk Elite  - Off-Road Ready - $244 B/W   Stock #: LD601624Condition: NewEngine: 3.2L Pentastar V-6 engineDrive Train: 4x4   Initial Price  $50,405    Initial Discount  $-5,790  Hover for details.  Dealer Discount$5,790   Dealer Price  $44,615  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare      Watch Video    2020 Dodge Grand Caravan Premium Plus  - Leather Seats - $199 B/W   Stock #: LR167177Condition: NewEngine: 3.6L Pentastar VVT V-6 engineDrive Train: FWD   Initial Price  $48,380    Initial Discount  $-12,095  Hover for details.  Dealer Discount$12,095   Dealer Price  $36,285  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare      Watch Video    2020 Dodge Grand Caravan Premium Plus  - Leather Seats - $200 B/W   Stock #: LR180959Condition: NewEngine: 3.6L Pentastar VVT V-6 engineDrive Train: FWD   Initial Price  $48,625    Initial Discount  $-12,156  Hover for details.  Dealer Discount$12,156   Dealer Price  $36,469  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare      Watch Video    2020 Dodge Grand Caravan Premium Plus  - Leather Seats - $199 B/W   Stock #: LR180970Condition: NewEngine: 3.6L Pentastar VVT V-6 engineDrive Train: FWD   Initial Price  $48,380    Initial Discount  $-12,095  Hover for details.  Dealer Discount$12,095   Dealer Price  $36,285  Pricing excludes licensing and tax.
# 									+ Tax
# 			View Details
# 		  Compare

# %%
#Finding the titles of cars using find_all
#All the titles are present in h4 itemprop : name
car_titles = []
a=soup.findAll('h3',{"class":"vehicle-card__title mb-xs"})
for i in a :
    print(i.text)
    car_titles.append(i.text)#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# 2020 Jeep Cherokee Limited  - Luxury Interior - $239 B/W
# 2020 Jeep Cherokee Limited  - Luxury Interior - $240 B/W
# 2020 RAM 1500 Sport  -  Android Auto -  Apple CarPlay - $349 B/W
# 2020 RAM 1500 Limited  - Limited -  Navigation - $416 B/W
# 2020 RAM 1500 Longhorn  - Longhorn -  Texas Tough - $405 B/W
# 2020 RAM 1500 Longhorn  - Longhorn -  Texas Tough - $406 B/W
# 2020 Dodge Grand Caravan Crew  - Aluminum Wheels - $209 B/W
# 2020 RAM 1500 Classic Express  -  Power Windows - $234 B/W
# 2020 RAM 1500 Classic Express  -  Power Windows - $241 B/W
# 2020 Dodge Grand Caravan SE CVP  - Dual Zone AC - $161 B/W
# 2020 RAM 1500 Classic Warlock  - Bluetooth -  SiriusXM - $266 B/W
# 2020 Jeep Cherokee Trailhawk Elite  - Off-Road Ready - $244 B/W
# 2020 Dodge Grand Caravan Premium Plus  - Leather Seats - $199 B/W
# 2020 Dodge Grand Caravan Premium Plus  - Leather Seats - $200 B/W
# 2020 Dodge Grand Caravan Premium Plus  - Leather Seats - $199 B/W
# ['2020 Jeep Cherokee Limited  - Luxury Interior - $239 B/W', '2020 Jeep Cherokee Limited  - Luxury Interior - $240 B/W', '2020 RAM 1500 Sport  -  Android Auto -  Apple CarPlay - $349 B/W', '2020 RAM 1500 Limited  - Limited -  Navigation - $416 B/W', '2020 RAM 1500 Longhorn  - Longhorn -  Texas Tough - $405 B/W', '2020 RAM 1500 Longhorn  - Longhorn -  Texas Tough - $406 B/W', '2020 Dodge Grand Caravan Crew  - Aluminum Wheels - $209 B/W', '2020 RAM 1500 Classic Express  -  Power Windows - $234 B/W', '2020 RAM 1500 Classic Express  -  Power Windows - $241 B/W', '2020 Dodge Grand Caravan SE CVP  - Dual Zone AC - $161 B/W', '2020 RAM 1500 Classic Warlock  - Bluetooth -  SiriusXM - $266 B/W', '2020 Jeep Cherokee Trailhawk Elite  - Off-Road Ready - $244 B/W', '2020 Dodge Grand Caravan Premium Plus  - Leather Seats - $199 B/W', '2020 Dodge Grand Caravan Premium Plus  - Leather Seats - $200 B/W', '2020 Dodge Grand Caravan Premium Plus  - Leather Seats - $199 B/W']
# 15

# %%
stock = []
engine = []
condition = []
drive_train = []
# taking empty lists

spec= soup.findAll('ul',{"class":"detailed-specs"})#scrapping details

for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('li')#finding all li inside ul
    for li in lis:
        
        if 'Stock' in li.text: #if present
            stock.append(li.text.replace("Stock #: ",""))#then append
        if 'Engine' in li.text:#if present
            engine.append(li.text.replace("Engine: ",""))#then append
        if 'Condition' in li.text:#if present
            condition.append(li.text.replace("Condition: ",""))#then append
        if 'Drive Train' in li.text:#if present
            drive_train.append(li.text.replace("Drive Train: ",""))#then append
        
        
#printing individual lists        
print(stock)
print(engine)
print(condition)
print(drive_train)
# Out:
# ['LD550251', 'LD562287', 'LN228421', 'LN228339', 'LN211044', 'LN258999', 'LR159730', 'LS117280', 'LS114110', 'LR167734', 'LS117288', 'LD601624', 'LR167177', 'LR180959', 'LR180970']
# ['3.2L Pentastar V-6 engine', '3.2L Pentastar V-6 engine', '5.7L HEMI V-8 engine', '5.7L HEMI V-8 engine', '3.0L EcoDiesel V-6 intercooled turbo diesel engine', '3.0L EcoDiesel V-6 intercooled turbo diesel engine', '3.6L Pentastar VVT V-6 engine', '3.6L Pentastar V-6 engine', '5.7L HEMI V-8 engine', '3.6L Pentastar VVT V-6 engine', '3.6L Pentastar V-6 engine', '3.2L Pentastar V-6 engine', '3.6L Pentastar VVT V-6 engine', '3.6L Pentastar VVT V-6 engine', '3.6L Pentastar VVT V-6 engine']
# ['New', 'New', 'New', 'New', 'New', 'New', 'New', 'New', 'New', 'New', 'New', 'New', 'New', 'New', 'New']
# ['4x4', '4x4', '4x4', '4x4', '4x4', '4x4', 'FWD', '4x4', '4x4', 'FWD', '4x4', '4x4', 'FWD', 'FWD', 'FWD']

# %%
#Finding the initial prices of cars using find_all
#All the  initial prices are present in div class : vehicle-card__prices
i_price = []
c = soup.findAll('div',{"class":"vehicle-card__price-wrap"})
for i in c :
    sp=i.findAll('div',{"class":"price-block__price price-block__price--md price-block__price--grey"})#digging further
    for j in sp:
        s=j.find('span',{"class":"df aifs"}).text.split("df aifs")[0]#actual values are inside span class :df aifs
        print(s)#printing initial prices
        i_price.append(s)#appending in a list
print(i_price)#printing list
len(i_price)#length oflist
# Out:
# $48,760
# $48,980
# $73,415
# $88,675
# $89,830
# $90,025
# $51,305
# $57,265
# $57,245
# $36,660
# $64,810
# $50,405
# $48,380
# $48,625
# $48,380
# ['$48,760', '$48,980', '$73,415', '$88,675', '$89,830', '$90,025', '$51,305', '$57,265', '$57,245', '$36,660', '$64,810', '$50,405', '$48,380', '$48,625', '$48,380']
# 15

# %%
#Finding the initial discount on cars using find_all
#All the  initial discount  are present in div class :vehicle-card__price-wrap
i_discount = []
c = soup.findAll('div',{"class":"vehicle-card__price-wrap"})
for i in c :
    sp=i.findAll('div',{"class":"price-block__price price-block__price--sm price-block__price--primary"})#digging further
    for j in sp:
        s=j.find('span',{"class":"df aifs"}).text.split("df aifs")[0]#actual values are inside span class :df aifs
        print(s)#printing initial prices
        i_discount.append(s)#appending in a list
print(i_discount)#printing list
len(i_discount)#length oflist
# Out:
# $-5,626
# $-5,648
# $-10,000
# $-10,000
# $-12,500
# $-12,500
# $-12,613
# $-14,316
# $-14,311
# $-7,332
# $-16,202
# $-5,790
# $-12,095
# $-12,156
# $-12,095
# ['$-5,626', '$-5,648', '$-10,000', '$-10,000', '$-12,500', '$-12,500', '$-12,613', '$-14,316', '$-14,311', '$-7,332', '$-16,202', '$-5,790', '$-12,095', '$-12,156', '$-12,095']
# 15

# %%
#Finding the sales price on cars using find_all
#All the  sales price  are present in div class : price-block__single price-block--expanded
car_price = []
c = soup.findAll('div',{"class":"price-block__single price-block--expanded"})
for i in c :
    sp=i.findAll('div',{"class":"price-block__price price-block__price--lg price-block__price--dark"})#digging further
    for j in sp:
        s=j.find('span',{"class":"df aifs"}).text.split("df aifs")[0]#actual values are inside span class :df aifs
        print(s)#printing initial prices
        car_price.append(s)#appending in a list
print(car_price)#printing list
len(car_price)#length of list
# Out:
# $43,134
# $43,332
# $63,415
# $78,675
# $77,330
# $77,525
# $38,692
# $42,949
# $42,934
# $29,328
# $48,608
# $44,615
# $36,285
# $36,469
# $36,285
# ['$43,134', '$43,332', '$63,415', '$78,675', '$77,330', '$77,525', '$38,692', '$42,949', '$42,934', '$29,328', '$48,608', '$44,615', '$36,285', '$36,469', '$36,285']
# 15

# %%
#creating a dict of scrapped data
dict = {
        'Title' : car_titles ,
        'Stock':stock,
        'Engine':engine,
        'Condition':condition,
        'Engine':engine,
        'Drive Train':drive_train,
        'MSRP':i_price,
        'Discount':i_discount,
        'Price':car_price
}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                                                 Title     Stock  \
# 0   2020 Jeep Cherokee Limited  - Luxury Interior ...  LD550251
# 1   2020 Jeep Cherokee Limited  - Luxury Interior ...  LD562287
# 2   2020 RAM 1500 Sport  -  Android Auto -  Apple ...  LN228421
# 3   2020 RAM 1500 Limited  - Limited -  Navigation...  LN228339
# 4   2020 RAM 1500 Longhorn  - Longhorn -  Texas To...  LN211044
# 5   2020 RAM 1500 Longhorn  - Longhorn -  Texas To...  LN258999
# 6   2020 Dodge Grand Caravan Crew  - Aluminum Whee...  LR159730
# 7   2020 RAM 1500 Classic Express  -  Power Window...  LS117280
# 8   2020 RAM 1500 Classic Express  -  Power Window...  LS114110
# 9   2020 Dodge Grand Caravan SE CVP  - Dual Zone A...  LR167734
# 10  2020 RAM 1500 Classic Warlock  - Bluetooth -  ...  LS117288
# 11  2020 Jeep Cherokee Trailhawk Elite  - Off-Road...  LD601624
# 12  2020 Dodge Grand Caravan Premium Plus  - Leath...  LR167177
# 13  2020 Dodge Grand Caravan Premium Plus  - Leath...  LR180959
# 14  2020 Dodge Grand Caravan Premium Plus  - Leath...  LR180970
#
#                                                Engine Condition Drive Train  \
# 0                           3.2L Pentastar V-6 engine       New         4x4
# 1                           3.2L Pentastar V-6 engine       New         4x4
# 2                                5.7L HEMI V-8 engine       New         4x4
# 3                                5.7L HEMI V-8 engine       New         4x4
# 4   3.0L EcoDiesel V-6 intercooled turbo diesel en...       New         4x4
# 5   3.0L EcoDiesel V-6 intercooled turbo diesel en...       New         4x4
# 6                       3.6L Pentastar VVT V-6 engine       New         FWD
# 7                           3.6L Pentastar V-6 engine       New         4x4
# 8                                5.7L HEMI V-8 engine       New         4x4
# 9                       3.6L Pentastar VVT V-6 engine       New         FWD
# 10                          3.6L Pentastar V-6 engine       New         4x4
# 11                          3.2L Pentastar V-6 engine       New         4x4
# 12                      3.6L Pentastar VVT V-6 engine       New         FWD
# 13                      3.6L Pentastar VVT V-6 engine       New         FWD
# 14                      3.6L Pentastar VVT V-6 engine       New         FWD
#
#        MSRP  Discount    Price
# 0   $48,760   $-5,626  $43,134
# 1   $48,980   $-5,648  $43,332
# 2   $73,415  $-10,000  $63,415
# 3   $88,675  $-10,000  $78,675
# 4   $89,830  $-12,500  $77,330
# 5   $90,025  $-12,500  $77,525
# 6   $51,305  $-12,613  $38,692
# 7   $57,265  $-14,316  $42,949
# 8   $57,245  $-14,311  $42,934
# 9   $36,660   $-7,332  $29,328
# 10  $64,810  $-16,202  $48,608
# 11  $50,405   $-5,790  $44,615
# 12  $48,380  $-12,095  $36,285
# 13  $48,625  $-12,156  $36,469
# 14  $48,380  $-12,095  $36,285

# %%
df['Dealer'] = 'winniepegdodge'

# %%
split_title = df["Title"].str.split(" ", n = 5, expand = True) 
# splitting Tile column 
df["Make Year"]= split_title[0] 
df["Make"]= split_title[1] 
df["Model"]= split_title[2] 
df
# Out:
#                                                 Title     Stock  \
# 0   2020 Jeep Cherokee Limited  - Luxury Interior ...  LD550251
# 1   2020 Jeep Cherokee Limited  - Luxury Interior ...  LD562287
# 2   2020 RAM 1500 Sport  -  Android Auto -  Apple ...  LN228421
# 3   2020 RAM 1500 Limited  - Limited -  Navigation...  LN228339
# 4   2020 RAM 1500 Longhorn  - Longhorn -  Texas To...  LN211044
# 5   2020 RAM 1500 Longhorn  - Longhorn -  Texas To...  LN258999
# 6   2020 Dodge Grand Caravan Crew  - Aluminum Whee...  LR159730
# 7   2020 RAM 1500 Classic Express  -  Power Window...  LS117280
# 8   2020 RAM 1500 Classic Express  -  Power Window...  LS114110
# 9   2020 Dodge Grand Caravan SE CVP  - Dual Zone A...  LR167734
# 10  2020 RAM 1500 Classic Warlock  - Bluetooth -  ...  LS117288
# 11  2020 Jeep Cherokee Trailhawk Elite  - Off-Road...  LD601624
# 12  2020 Dodge Grand Caravan Premium Plus  - Leath...  LR167177
# 13  2020 Dodge Grand Caravan Premium Plus  - Leath...  LR180959
# 14  2020 Dodge Grand Caravan Premium Plus  - Leath...  LR180970
#
#                                                Engine Condition Drive Train  \
# 0                           3.2L Pentastar V-6 engine       New         4x4
# 1                           3.2L Pentastar V-6 engine       New         4x4
# 2                                5.7L HEMI V-8 engine       New         4x4
# 3                                5.7L HEMI V-8 engine       New         4x4
# 4   3.0L EcoDiesel V-6 intercooled turbo diesel en...       New         4x4
# 5   3.0L EcoDiesel V-6 intercooled turbo diesel en...       New         4x4
# 6                       3.6L Pentastar VVT V-6 engine       New         FWD
# 7                           3.6L Pentastar V-6 engine       New         4x4
# 8                                5.7L HEMI V-8 engine       New         4x4
# 9                       3.6L Pentastar VVT V-6 engine       New         FWD
# 10                          3.6L Pentastar V-6 engine       New         4x4
# 11                          3.2L Pentastar V-6 engine       New         4x4
# 12                      3.6L Pentastar VVT V-6 engine       New         FWD
# 13                      3.6L Pentastar VVT V-6 engine       New         FWD
# 14                      3.6L Pentastar VVT V-6 engine       New         FWD
#
#        MSRP  Discount    Price          Dealer Make Year   Make     Model
# 0   $48,760   $-5,626  $43,134  winniepegdodge      2020   Jeep  Cherokee
# 1   $48,980   $-5,648  $43,332  winniepegdodge      2020   Jeep  Cherokee
# 2   $73,415  $-10,000  $63,415  winniepegdodge      2020    RAM      1500
# 3   $88,675  $-10,000  $78,675  winniepegdodge      2020    RAM      1500
# 4   $89,830  $-12,500  $77,330  winniepegdodge      2020    RAM      1500
# 5   $90,025  $-12,500  $77,525  winniepegdodge      2020    RAM      1500
# 6   $51,305  $-12,613  $38,692  winniepegdodge      2020  Dodge     Grand
# 7   $57,265  $-14,316  $42,949  winniepegdodge      2020    RAM      1500
# 8   $57,245  $-14,311  $42,934  winniepegdodge      2020    RAM      1500
# 9   $36,660   $-7,332  $29,328  winniepegdodge      2020  Dodge     Grand
# 10  $64,810  $-16,202  $48,608  winniepegdodge      2020    RAM      1500
# 11  $50,405   $-5,790  $44,615  winniepegdodge      2020   Jeep  Cherokee
# 12  $48,380  $-12,095  $36,285  winniepegdodge      2020  Dodge     Grand
# 13  $48,625  $-12,156  $36,469  winniepegdodge      2020  Dodge     Grand
# 14  $48,380  $-12,095  $36,285  winniepegdodge      2020  Dodge     Grand

# %%
df.drop(columns =["Title"], inplace = True)
df
# Out:
#        Stock                                             Engine Condition  \
# 0   LD550251                          3.2L Pentastar V-6 engine       New
# 1   LD562287                          3.2L Pentastar V-6 engine       New
# 2   LN228421                               5.7L HEMI V-8 engine       New
# 3   LN228339                               5.7L HEMI V-8 engine       New
# 4   LN211044  3.0L EcoDiesel V-6 intercooled turbo diesel en...       New
# 5   LN258999  3.0L EcoDiesel V-6 intercooled turbo diesel en...       New
# 6   LR159730                      3.6L Pentastar VVT V-6 engine       New
# 7   LS117280                          3.6L Pentastar V-6 engine       New
# 8   LS114110                               5.7L HEMI V-8 engine       New
# 9   LR167734                      3.6L Pentastar VVT V-6 engine       New
# 10  LS117288                          3.6L Pentastar V-6 engine       New
# 11  LD601624                          3.2L Pentastar V-6 engine       New
# 12  LR167177                      3.6L Pentastar VVT V-6 engine       New
# 13  LR180959                      3.6L Pentastar VVT V-6 engine       New
# 14  LR180970                      3.6L Pentastar VVT V-6 engine       New
#
#    Drive Train     MSRP  Discount    Price          Dealer Make Year   Make  \
# 0          4x4  $48,760   $-5,626  $43,134  winniepegdodge      2020   Jeep
# 1          4x4  $48,980   $-5,648  $43,332  winniepegdodge      2020   Jeep
# 2          4x4  $73,415  $-10,000  $63,415  winniepegdodge      2020    RAM
# 3          4x4  $88,675  $-10,000  $78,675  winniepegdodge      2020    RAM
# 4          4x4  $89,830  $-12,500  $77,330  winniepegdodge      2020    RAM
# 5          4x4  $90,025  $-12,500  $77,525  winniepegdodge      2020    RAM
# 6          FWD  $51,305  $-12,613  $38,692  winniepegdodge      2020  Dodge
# 7          4x4  $57,265  $-14,316  $42,949  winniepegdodge      2020    RAM
# 8          4x4  $57,245  $-14,311  $42,934  winniepegdodge      2020    RAM
# 9          FWD  $36,660   $-7,332  $29,328  winniepegdodge      2020  Dodge
# 10         4x4  $64,810  $-16,202  $48,608  winniepegdodge      2020    RAM
# 11         4x4  $50,405   $-5,790  $44,615  winniepegdodge      2020   Jeep
# 12         FWD  $48,380  $-12,095  $36,285  winniepegdodge      2020  Dodge
# 13         FWD  $48,625  $-12,156  $36,469  winniepegdodge      2020  Dodge
# 14         FWD  $48,380  $-12,095  $36,285  winniepegdodge      2020  Dodge
#
#        Model
# 0   Cherokee
# 1   Cherokee
# 2       1500
# 3       1500
# 4       1500
# 5       1500
# 6      Grand
# 7       1500
# 8       1500
# 9      Grand
# 10      1500
# 11  Cherokee
# 12     Grand
# 13     Grand
# 14     Grand

# %%
#Dataframe to csv
df.to_csv('winnipegdodge.csv')
