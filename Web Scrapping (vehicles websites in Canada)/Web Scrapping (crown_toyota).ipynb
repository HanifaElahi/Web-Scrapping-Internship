# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = input(("Enter url : "))
# "https://www.crowntoyota.ca/new-vehicles-in-winnipeg-mb/"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class  vehicle list-view used-vehicle publish
data = soup.findAll('div',{"class":"vehicle list-view used-vehicle publish"})
#printing the extracted data of a single page
for info in data:
    print(info.text)

# %%
#Finding the titles of cars using find_all
#All the titles are present in div class : vehicle-title clearfix
a = soup.find_all("div",{"class" :"vehicle-title clearfix"})

# %%
#taking an empty list
car_titles = []
#printing all the separate titles using for loop
for i in a:
    titles = i.find('h2').text.split("listing")[0] # all titles are inside h2 
    print(titles)# printing values
    #appending values in a separate empty list
    car_titles.append(titles)  
print(car_titles)#printing car titles list
len(car_titles)#length of car titles list
# Out:
# New 2021 Toyota Corolla L
#
# New 2020 Toyota Corolla LE CVT
#
# New 2020 Toyota Corolla LE CVT
#
# New 2020 Toyota Corolla LE CVT
#
# New 2020 Toyota Corolla LE CVT
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
#
# New 2021 Toyota Corolla LE
# ['\nNew 2021 Toyota Corolla L ', '\nNew 2020 Toyota Corolla LE CVT ', '\nNew 2020 Toyota Corolla LE CVT ', '\nNew 2020 Toyota Corolla LE CVT ', '\nNew 2020 Toyota Corolla LE CVT ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ', '\nNew 2021 Toyota Corolla LE ']
# 20

# %%
#Finding the price of cars using find_all
#All the price are present in div class : vehicle-content
c = soup.findAll("div",{"class" :"vehicle-content"})
#taking an empty list
car_price = []
#printing all the separate price using for loop
for i in c:
    prices = i.find("span",{"class" :"price"}).text.strip()
    print(prices)
        #print(p)# printing values
    #appending values in a separate empty list
    car_price.append(prices)  
print(car_price)#printing car price list
len(car_price)#length of car price list
# Out:
# $22,839
# $23,679
# $23,679
# $23,679
# $23,679
# $23,839
# $23,839
# $23,839
# $23,839
# $23,839
# $23,839
# $23,839
# $23,839
# $23,839
# $23,839
# $23,839
# $23,839
# $23,839
# $23,839
# $23,839
# ['$22,839', '$23,679', '$23,679', '$23,679', '$23,679', '$23,839', '$23,839', '$23,839', '$23,839', '$23,839', '$23,839', '$23,839', '$23,839', '$23,839', '$23,839', '$23,839', '$23,839', '$23,839', '$23,839', '$23,839']
# 20

# %%
vin = []
stock = []
#taking empty lists 

d = soup.find_all("div",{"class" :"vinstock"}) #scrapping for vin and stock
for i in d:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('span')#finding all span inside div class
    for li in lis: 
        if 'VIN' in li.text: #if present
            vin.append(li.text.replace("VIN: ",""))#then append
        if 'Stock' in li.text:#if present
            stock.append(li.text.replace("Stock #:",""))#then append

#printing individual lists
print(vin)
print(stock)
# Out:
# ['5YFBPMBE5MP152985', '5YFBPRBEXLP132131', '5YFBPRBE7LP136931', '5YFBPRBE3LP137803', '5YFBPRBE2LP137520', '5YFBPMBE9MP149961', '5YFBPMBE6MP147388', '5YFBPMBE0MP147399', '5YFBPMBE7MP147528', '5YFBPMBE2MP147811', '5YFBPMBE5MP147155', '5YFBPMBEXMP147684', '5YFBPMBE7MP147691', '5YFBPMBE2MP147551', '5YFBPMBE0MP147063', '5YFBPMBE5MP147821', '5YFBPMBE1MP147945', '5YFBPMBE9MP148017', '5YFBPMBE8MP147036', '5YFBPMBE8MP146999']
# [' 251061', ' 250943', ' 260002', ' 260011', ' 260010', ' 251003', ' 251015', ' 251025', ' 251031', ' 251016', ' 251027', ' 251017', ' 251019', ' 251024', ' 251033', ' 251037', ' 251046', ' 251039', ' 251043', ' 251045']

# %%
#taking empty lists
engine = []
transmission = []
drive_train = []
exterior = []


d = soup.find_all("div",{"class" :"options"}) # all the details are inside div class:options
for i in d:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('li')#finding all lspan inside div class
    for li in lis: 
        if 'Engine' in li.text:
            engine.append(li.text.replace("\nEngine:\n","").strip())
        if 'Trans' in li.text:
            transmission.append(li.text.replace("\nTrans:\n","").strip())
        if 'Drivetrain' in li.text:
            drive_train.append(li.text.replace("\nDrivetrain:\n","").strip())
        if 'Exterior' in li.text:
            exterior.append(li.text.replace("\nExterior:\n","").strip())


#printing individual lists            
print(engine)
print(transmission)
print(drive_train)
print(exterior)
# Out:
# ['1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine', '1.8L 4-Cyl Engine']
# ['Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic']
# ['FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD']
# ['Classic Silver Metallic', 'Classic Silver Metallic', 'Black Sand Pearl', 'Super White', 'Super White', '01F7 Classic Silver Metal', 'Blueprint', 'Blueprint', 'Celestite', 'Classic Silver Metallic', 'Celestite', 'Classic Silver Metallic', 'Classic Silver Metallic', 'Classic Silver Metallic', 'Celestite', 'Black Sand Pearl', 'Super White', 'Classic Silver Metallic', 'Barcelona Red Metallic', 'Celestite']

# %%
dict = {
    'Title' : car_titles,
    'Price' : car_price,
    'Location' : car_location,
    'VIN' : vin,
    'Stock':stock,
    'Engine':engine,
    'Transmission':transmission,
    'Exterior':exterior,
    'Drive Train':drive_train
}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T

# %%
df
# Out:
#                                 Title    Price Location                VIN  \
# 0        \nNew 2021 Toyota Corolla L   $22,839     None  5YFBPMBE5MP152985
# 1   \nNew 2020 Toyota Corolla LE CVT   $23,679     None  5YFBPRBEXLP132131
# 2   \nNew 2020 Toyota Corolla LE CVT   $23,679     None  5YFBPRBE7LP136931
# 3   \nNew 2020 Toyota Corolla LE CVT   $23,679     None  5YFBPRBE3LP137803
# 4   \nNew 2020 Toyota Corolla LE CVT   $23,679     None  5YFBPRBE2LP137520
# 5       \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE9MP149961
# 6       \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE6MP147388
# 7       \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE0MP147399
# 8       \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE7MP147528
# 9       \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE2MP147811
# 10      \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE5MP147155
# 11      \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBEXMP147684
# 12      \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE7MP147691
# 13      \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE2MP147551
# 14      \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE0MP147063
# 15      \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE5MP147821
# 16      \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE1MP147945
# 17      \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE9MP148017
# 18      \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE8MP147036
# 19      \nNew 2021 Toyota Corolla LE   $23,839     None  5YFBPMBE8MP146999
#
#       Stock             Engine Transmission                   Exterior  \
# 0    251061  1.8L 4-Cyl Engine    Automatic    Classic Silver Metallic
# 1    250943  1.8L 4-Cyl Engine    Automatic    Classic Silver Metallic
# 2    260002  1.8L 4-Cyl Engine    Automatic           Black Sand Pearl
# 3    260011  1.8L 4-Cyl Engine    Automatic                Super White
# 4    260010  1.8L 4-Cyl Engine    Automatic                Super White
# 5    251003  1.8L 4-Cyl Engine    Automatic  01F7 Classic Silver Metal
# 6    251015  1.8L 4-Cyl Engine    Automatic                  Blueprint
# 7    251025  1.8L 4-Cyl Engine    Automatic                  Blueprint
# 8    251031  1.8L 4-Cyl Engine    Automatic                  Celestite
# 9    251016  1.8L 4-Cyl Engine    Automatic    Classic Silver Metallic
# 10   251027  1.8L 4-Cyl Engine    Automatic                  Celestite
# 11   251017  1.8L 4-Cyl Engine    Automatic    Classic Silver Metallic
# 12   251019  1.8L 4-Cyl Engine    Automatic    Classic Silver Metallic
# 13   251024  1.8L 4-Cyl Engine    Automatic    Classic Silver Metallic
# 14   251033  1.8L 4-Cyl Engine    Automatic                  Celestite
# 15   251037  1.8L 4-Cyl Engine    Automatic           Black Sand Pearl
# 16   251046  1.8L 4-Cyl Engine    Automatic                Super White
# 17   251039  1.8L 4-Cyl Engine    Automatic    Classic Silver Metallic
# 18   251043  1.8L 4-Cyl Engine    Automatic     Barcelona Red Metallic
# 19   251045  1.8L 4-Cyl Engine    Automatic                  Celestite
#
#    Drive Train
# 0          FWD
# 1          FWD
# 2          FWD
# 3          FWD
# 4          FWD
# 5          FWD
# 6          FWD
# 7          FWD
# 8          FWD
# 9          FWD
# 10         FWD
# 11         FWD
# 12         FWD
# 13         FWD
# 14         FWD
# 15         FWD
# 16         FWD
# 17         FWD
# 18         FWD
# 19         FWD

# %%
#Dataframe to csv
df.to_csv('crowntoyota.csv')
