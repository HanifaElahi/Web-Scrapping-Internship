# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = "https://www.wesellautos.com/inventory/search?page=1&page_length=20&stock_type=Used"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class group-content
data=soup.findAll('section',{"class":"group-content"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
# 66 Vehicles Found
#
#
# 5
#
# 10
#
# 20
#
# 50
#
# 100
#
#
# --- Sort by: ---
# Price: lowest first
# Price: highest first
# Makes: A - Z
# Makes: Z - A
# Models: A - Z
# Models: Z - A
# Odometer: lowest first
# Odometer: highest first
# Year: oldest first
# Year: newest first
# Dealer: closest
#
#
#
# List view
# Grid view
#
#
#
#
# On special
#
#
#
# View 16 Photos
#
#
# in stock
# 2018 Kia Rio 5-door
# S 4dr FWD Hatchback
# Details
#
# Odometer
# 66,321 KMS
# Color
# Silver
# Engine
# 1.6L I-4
# Transmission
# 6 Spd Automatic
# Drivetrain
# FWD
# Stock #
# 18kr25627
# VIN
# 3KPA25AB7JE025627
#
#
#
# Was $13,980
#
# $11,890*
# You Save $2,090
#
# $13,980 Retail Price
# - $2,090 Dealer Discount/Manufacturer Rebate
# 				= $2,090 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2018 Kia Rio 5-door",
# 		"brand": "Kia",
# ...

# %%
#Finding the titles of cars using find_all
#All the titles are present in h4 itemprop : name
car_titles = []
a=soup.findAll('h4',{"itemprop":"name"})
for i in a :
    print(i.text)
    car_titles.append(i.text)#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# 2018 Kia Rio 5-door
# 2018 Kia Rio 5-door
# 2018 Kia Soul
# 2016 Chevrolet CRUZE LIMITED
# 2018 Kia Soul
# 2015 Mazda Mazda3
# 2018 Chevrolet Cruze
# 2016 Nissan Sentra
# 2015 Volkswagen Tiguan
# 2016 Chevrolet Trax
# 2016 Toyota Corolla
# 2016 Mazda Mazda3
# 2019 Kia Rio
# 2018 Chevrolet Malibu
# 2017 Hyundai Elantra
# 2019 Hyundai Elantra
# 2019 Chevrolet Cruze
# 2019 Volkswagen Jetta
# 2014 Honda Accord Sedan
# 2016 Honda Civic Coupe
# ['2018 Kia Rio 5-door', '2018 Kia Rio 5-door', '2018 Kia Soul', '2016 Chevrolet CRUZE LIMITED', '2018 Kia Soul', '2015 Mazda Mazda3', '2018 Chevrolet Cruze', '2016 Nissan Sentra', '2015 Volkswagen Tiguan', '2016 Chevrolet Trax', '2016 Toyota Corolla', '2016 Mazda Mazda3', '2019 Kia Rio', '2018 Chevrolet Malibu', '2017 Hyundai Elantra', '2019 Hyundai Elantra', '2019 Chevrolet Cruze', '2019 Volkswagen Jetta', '2014 Honda Accord Sedan', '2016 Honda Civic Coupe']
# 20

# %%
#Finding the price of cars using find_all
#All the priceare present in strong class : price _bpcolor
car_price = []
a=soup.findAll('strong',{"class":"price _bpcolor"})
for i in a :
    print(i.text)
    car_price.append(i.text.strip())#appending values
print(car_price)#printing price
len(car_price)#printing length of list
# Out:
# $11,890*
#
# $11,980*
#
# $15,780*
#
# $15,780*
#
# $15,890*
#
# $15,980*
#
# $15,980*
#
# $15,990*
#
# $16,890*
#
# $16,890*
#
# $16,980*
#
# $16,980*
#
# $16,980*
#
# $16,990*
#
# $17,680*
#
# $17,890*
#
# $17,890*
#
# $17,980*
#
# $17,980*
#
# $17,990*
# ['$11,890*', '$11,980*', '$15,780*', '$15,780*', '$15,890*', '$15,980*', '$15,980*', '$15,990*', '$16,890*', '$16,890*', '$16,980*', '$16,980*', '$16,980*', '$16,990*', '$17,680*', '$17,890*', '$17,890*', '$17,980*', '$17,980*', '$17,990*']
# 20

# %%
car_description = []#taking empty list
a = soup.findAll('div',{"class":"used-description product-description"})#scrapping description
for i in a:
    s = i.find('h5')
    car_description.append(s.text)#appending in a list
print(car_description)#printing list
# Out:
# ['S 4dr FWD Hatchback', 'LX+ 4dr FWD Hatchback', 'EX+ 4dr FWD Hatchback', 'LT 4dr FWD Sedan', 'EX 4dr FWD Hatchback', 'GS 4dr FWD Sedan Skyactiv', 'LT 4dr FWD Hatchback', 'SV 4dr FWD Sedan', 'Comfortline 4dr AWD 4MOTION', 'LT 4dr AWD Sport Utility Vehicle', 'S 4dr FWD Sedan', 'GS 4dr FWD Sedan Skyactiv', 'LX+ 4dr FWD Sedan', 'LT 4dr FWD Sedan', 'GLS 4dr FWD Sedan', 'Preferred 4dr FWD Sedan', 'LT 4dr FWD Sedan', 'Comfortline 4dr FWD Sedan', 'Touring 4dr FWD Sedan', 'LX 2dr FWD Coupe']

# %%
mileage = []#taking empty list
a = soup.findAll('dd',{"class":"srp-odometer"})#scrapping mileage
for i in a:
    print(i.text)
    mileage.append(i.text)#appending in a list
print(mileage)#printing list
# Out:
# 66,321 KMS
# 60,143 KMS
# 65,344 KMS
# 82,345 KMS
# 68,206 KMS
# 48,524 KMS
# 50,955 KMS
# 67,119 KMS
# 98,923 KMS
# 71,342 KMS
# 65,836 KMS
# 79,058 KMS
# 15,620 KMS
# 66,581 KMS
# 36,073 KMS
# 46,798 KMS
# 48,143 KMS
# 41,649 KMS
# 80,165 KMS
# 63,217 KMS
# ['66,321 KMS', '60,143 KMS', '65,344 KMS', '82,345 KMS', '68,206 KMS', '48,524 KMS', '50,955 KMS', '67,119 KMS', '98,923 KMS', '71,342 KMS', '65,836 KMS', '79,058 KMS', '15,620 KMS', '66,581 KMS', '36,073 KMS', '46,798 KMS', '48,143 KMS', '41,649 KMS', '80,165 KMS', '63,217 KMS']

# %%
exterior = []#taking empty list
a = soup.findAll('dd',{"class":"srp-color-exterior"})#scrapping exterior
for i in a:
    print(i.text)
    exterior.append(i.text)#appending in a list
print(exterior)#printing list
# Out:
# Silver
# Hyper Blue Metallic
# Caffeine Brown
# Summit White
# Brown
# Aluminum Metallic
# Graphite Metallic
# Black
# Pure White
# Mosaic Black Metallic
# Silver
# Black
# Radiant Red Metallic
# Silver Ice Metallic
# Black
# Intense Blue
# Silver Ice Metallic
# Tornado Red
# White Orchid Pearl
# Aegean Blue Metallic
# ['Silver', 'Hyper Blue Metallic', 'Caffeine Brown', 'Summit White', 'Brown', 'Aluminum Metallic', 'Graphite Metallic', 'Black', 'Pure White', 'Mosaic Black Metallic', 'Silver', 'Black', 'Radiant Red Metallic', 'Silver Ice Metallic', 'Black', 'Intense Blue', 'Silver Ice Metallic', 'Tornado Red', 'White Orchid Pearl', 'Aegean Blue Metallic']

# %%
engine = []#taking empty list
a = soup.findAll('dd',{"class":"srp-engine-combined"}) #scrapping engine
for i in a:
    print(i.text)
    engine.append(i.text)#appending in a list
print(engine)#printing list
# Out:
# 1.6L I-4
# 1.6L I-4
# 2L I-4
# 1.4L I-4
# 2L I-4
# 2L I-0
# 1.4L I-4
# 1.8L I-4
# 2L I-4
# 1.8L I-4
# 2L I-4
# 1.6L I-4
# 1.5L I-4
# 2L I-4
# 2L I-4
# 1.4L I-4
# 1.4L I-4
# 2.4L I-4
# 2L I-4
# ['1.6L I-4', '1.6L I-4', '2L I-4', '1.4L I-4', '2L I-4', '2L I-0', '1.4L I-4', '1.8L I-4', '2L I-4', '1.8L I-4', '2L I-4', '1.6L I-4', '1.5L I-4', '2L I-4', '2L I-4', '1.4L I-4', '1.4L I-4', '2.4L I-4', '2L I-4']

# %%
transmission = []#taking empty list
a = soup.findAll('dd',{"class":"srp-transmission"})#scrappping transmission
for i in a:
    print(i.text)
    transmission.append(i.text)#appending in a list
print(transmission)#printing list
# Out:
# 6 Spd Automatic
# 6 Spd Automatic
# 6 Spd Automatic
# 6 Spd Automatic
# 6 Spd Automatic
# 6 Spd Automatic
# Automatic
# 6 Spd Automatic
# 6 Spd Automatic
# CVT
# 6 Spd Automatic
# 6 Spd Automatic
# 6 Spd Automatic
# 6 Spd Automatic
# 6 Spd Automatic
# 8 Spd Automatic
# CVT
# CVT
# ['6 Spd Automatic', '6 Spd Automatic', '6 Spd Automatic', '6 Spd Automatic', '6 Spd Automatic', '6 Spd Automatic', 'Automatic', '6 Spd Automatic', '6 Spd Automatic', 'CVT', '6 Spd Automatic', '6 Spd Automatic', '6 Spd Automatic', '6 Spd Automatic', '6 Spd Automatic', '8 Spd Automatic', 'CVT', 'CVT']

# %%
drive_train = []#taking empty list
a = soup.findAll('dd',{"class":"srp-driveType"})#scrapping drive_Train
for i in a:
    print(i.text)
    drive_train.append(i.text)#appending in a list
print(drive_train)#printing list
# Out:
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# AWD
# AWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# ['FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'AWD', 'AWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD']

# %%
stock = []#taking empty list
a = soup.findAll('dd',{"class":"srp-stock-number"})#wscrapping stock
for i in a:
    print(i.text)
    stock.append(i.text)#appending in a list
print(stock)#printing list
# Out:
# 18kr25627
# 18kr24387
# 18ks50099
# 16cc82763
# 18KS29293
# 15m383398
# 18cc44847
# 16ns49936
# 19HS61505A
# 16ct30924
# 16tc50889
# 16MM24046
# 19kr35701
# 18cm38398
# 17HE53067
# 19con67808
# 19CC05782
# 19VJ42166
# 14HA02590
# 16hc01772
# ['18kr25627', '18kr24387', '18ks50099', '16cc82763', '18KS29293', '15m383398', '18cc44847', '16ns49936', '19HS61505A', '16ct30924', '16tc50889', '16MM24046', '19kr35701', '18cm38398', '17HE53067', '19con67808', '19CC05782', '19VJ42166', '14HA02590', '16hc01772']

# %%
vin = []#taking empty list
a = soup.findAll('dd',{"class":"srp-vin"}) #scrapping vin
for i in a:
    print(i.text)
    vin.append(i.text)#appending in a list
print(vin)#printing list
# Out:
# 3KPA25AB7JE025627
# 3KPA25AB8JE024387
# KNDJP3A53J7550099
# 1G1PF5SB1G7182763
# KNDJP3A54J7529293
# 3MZBM1V78FM183398
# 3G1BE6SMXJS644847
# 3N1AB7AP8GL649936
# WVGJV7AX7FW562196
# 3GNCJPSB6GL230924
# 2T1BURHEXGC650889
# 3mzbm1v72gm324046
# 3KPA24AB8KE235701
# 1G1ZD5ST9JF138398
# KMHD84LF3HU153067
# KMHD84LF7KU867808
# 1G1BE5SM6K7105782
# 3VWC57BU1KM142166
# 1hgcr2f92ea802590
# 2HGFC4B56GH401772
# ['3KPA25AB7JE025627', '3KPA25AB8JE024387', 'KNDJP3A53J7550099', '1G1PF5SB1G7182763', 'KNDJP3A54J7529293', '3MZBM1V78FM183398', '3G1BE6SMXJS644847', '3N1AB7AP8GL649936', 'WVGJV7AX7FW562196', '3GNCJPSB6GL230924', '2T1BURHEXGC650889', '3mzbm1v72gm324046', '3KPA24AB8KE235701', '1G1ZD5ST9JF138398', 'KMHD84LF3HU153067', 'KMHD84LF7KU867808', '1G1BE5SM6K7105782', '3VWC57BU1KM142166', '1hgcr2f92ea802590', '2HGFC4B56GH401772']

# %%
#creating a dict of scrapped data
dict = {
        'Title' : car_titles ,
        'Description':car_description,
        'Mileage':mileage,
        'Exterior':exterior,
        'Transmission':transmission,
        'Engine':engine,
        'Drive Train':drive_train,
        'Stock':stock,
        'VIN':vin,
        'Price':car_price
}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                            Title                       Description  \
# 0            2018 Kia Rio 5-door               S 4dr FWD Hatchback
# 1            2018 Kia Rio 5-door             LX+ 4dr FWD Hatchback
# 2                  2018 Kia Soul             EX+ 4dr FWD Hatchback
# 3   2016 Chevrolet CRUZE LIMITED                  LT 4dr FWD Sedan
# 4                  2018 Kia Soul              EX 4dr FWD Hatchback
# 5              2015 Mazda Mazda3         GS 4dr FWD Sedan Skyactiv
# 6           2018 Chevrolet Cruze              LT 4dr FWD Hatchback
# 7             2016 Nissan Sentra                  SV 4dr FWD Sedan
# 8         2015 Volkswagen Tiguan       Comfortline 4dr AWD 4MOTION
# 9            2016 Chevrolet Trax  LT 4dr AWD Sport Utility Vehicle
# 10           2016 Toyota Corolla                   S 4dr FWD Sedan
# 11             2016 Mazda Mazda3         GS 4dr FWD Sedan Skyactiv
# 12                  2019 Kia Rio                 LX+ 4dr FWD Sedan
# ...

# %%
df['Dealer'] = 'wesellautos'
df['Condition'] = 'Used'

# %%
split_title = df["Title"].str.split(" ", n = 2, expand = True) 
# splitting Tile column 
df["Make Year"]= split_title[0] 
df["Make"]= split_title[1] 
df["Model"]= split_title[2] 
df
# Out:
#                            Title                       Description  \
# 0            2018 Kia Rio 5-door               S 4dr FWD Hatchback
# 1            2018 Kia Rio 5-door             LX+ 4dr FWD Hatchback
# 2                  2018 Kia Soul             EX+ 4dr FWD Hatchback
# 3   2016 Chevrolet CRUZE LIMITED                  LT 4dr FWD Sedan
# 4                  2018 Kia Soul              EX 4dr FWD Hatchback
# 5              2015 Mazda Mazda3         GS 4dr FWD Sedan Skyactiv
# 6           2018 Chevrolet Cruze              LT 4dr FWD Hatchback
# 7             2016 Nissan Sentra                  SV 4dr FWD Sedan
# 8         2015 Volkswagen Tiguan       Comfortline 4dr AWD 4MOTION
# 9            2016 Chevrolet Trax  LT 4dr AWD Sport Utility Vehicle
# 10           2016 Toyota Corolla                   S 4dr FWD Sedan
# 11             2016 Mazda Mazda3         GS 4dr FWD Sedan Skyactiv
# 12                  2019 Kia Rio                 LX+ 4dr FWD Sedan
# ...

# %%
df.drop(columns =["Title"], inplace = True)
df
# Out:
#                          Description     Mileage               Exterior  \
# 0                S 4dr FWD Hatchback  66,321 KMS                 Silver
# 1              LX+ 4dr FWD Hatchback  60,143 KMS    Hyper Blue Metallic
# 2              EX+ 4dr FWD Hatchback  65,344 KMS         Caffeine Brown
# 3                   LT 4dr FWD Sedan  82,345 KMS           Summit White
# 4               EX 4dr FWD Hatchback  68,206 KMS                  Brown
# 5          GS 4dr FWD Sedan Skyactiv  48,524 KMS      Aluminum Metallic
# 6               LT 4dr FWD Hatchback  50,955 KMS      Graphite Metallic
# 7                   SV 4dr FWD Sedan  67,119 KMS                  Black
# 8        Comfortline 4dr AWD 4MOTION  98,923 KMS             Pure White
# 9   LT 4dr AWD Sport Utility Vehicle  71,342 KMS  Mosaic Black Metallic
# 10                   S 4dr FWD Sedan  65,836 KMS                 Silver
# 11         GS 4dr FWD Sedan Skyactiv  79,058 KMS                  Black
# ...

# %%
#Dataframe to csv
df.to_csv('wesellautos.csv')
