# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = "https://www.vikingmotors.ca/used-vehicles/"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in id lvrp-results-container
data=soup.findAll('div',{"id":"lvrp-results-container"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
# Reset Results
#
#
#
#
#
#
# 3rd Row Seat
#
#
#
#
# AWD
#
#
#
#
# Android Auto
#
#
#
#
# Apple CarPlay
#
#
#
#
# Automatic Climate Control
#
#
#
#
# Backup Camera
#
#
#
#
# Blind Spot Monitor
#
#
#
#
# Bluetooth
#
#
#
#
# Cooled Seats
#
#
#
#
# Dual Zone Climate Control
#
#
#
#
# Fog Lights
#
#
#
#
# Hands-Free Liftgate
#
#
#
#
# Heated Seats
#
#
#
#
# Keyless Entry
#
#
#
#
# Leather Seats
#
#
#
#
# Memory Seats
#
#
#
#
# Parking Sensors / Assist
#
#
#
#
# Power Seats
#
#
#
#
# Premium Audio
#
#
#
#
# Remote Start
#
#
#
#
# Satellite Radio Ready
#
#
#
#
# Sunroof / Moonroof
#
#
#
#
# Wireless Phone Charging
#
#
#
#
# Xenon Headlights
#
#
#
#
#
# 23 Results Found
#
#
#
# Previous1 of 2Next
#
#
#
# UsedCertified Used
#
#
#
#
#
#
#
#
#
# Special OfferUsed 2008Chevrolet HHR LS DetailsViking Price$2,977Exterior: OrangeCheck AvailabilitySpecial OfferUsed 2011GMC Acadia SLT1 - Bluetooth - Leather Seats 4WD DetailsViking Price$11,588Exterior: RedKey Features:
#
#
#
#
#
#
#  Check AvailabilitySpecial OfferUsed 2014Jeep Cherokee SPORT - Bluetooth - Power Windows - $92 B/W DetailsViking Price$11,966Exterior: GreenKey Features:
#  Check AvailabilitySpecial OfferUsed 2010Ford Edge LIMITED - Leather Seats - Bluetooth 4WD DetailsViking Price$12,944Exterior: BlackKey Features:
#
#
#
#
#
#
#
#  Check AvailabilitySpecial OfferUsed 2010GMC Yukon SLT - Leather Seats - Bluetooth 4WD DetailsViking Price$14,269Exterior: SilverKey Features:
#
#
#
#
#  Check AvailabilitySpecial OfferUsed 2013Ford Edge SEL - Bluetooth - SYNC - SiriusXM - $142 B/W 4WD DetailsViking Price$15,488Exterior: BlackKey Features:
#
#
#
#
#
#  Check AvailabilitySpecial OfferUsed 2018Dodge Grand Caravan Canada Value Package - $135 B/W DetailsViking Price$19,988Exterior: WhiteInterior: GreystoneKey Features:
#
#  Check AvailabilitySpecial OfferUsed 2014Chevrolet Silverado 1500 LT D/C 4X4 5.3L V8 - $205 B/W DetailsViking Price$26,772Exterior: GreenKey Features:
#  Check AvailabilitySpecial OfferUsed 2018Chevrolet Traverse LT Cloth - Bluetooth - $216 B/W 4WD DetailsViking Price$31,988Exterior: PepperdustKey Features:
#
#
#
#
#
#
#
#  Check AvailabilitySpecial OfferUsed 2017Ram 1500 Longhorn - Navigation - Cooled Seats - $219 B/W DetailsViking Price$32,488Exterior: BlackKey Features:
#
#
#
#
#
#  Check AvailabilityUsed 2004Chevrolet Malibu Maxx LS DetailsViking Price$2,950Exterior: BlueCheck AvailabilityUsed 2010Chevrolet Colorado LT W/1SD DetailsViking Price$6,844Exterior: WhiteKey Features:
#
#  Check AvailabilityUsed 2012Dodge Grand Caravan SE - One owner - Non-smoker DetailsViking Price$8,745Exterior: Cashmere PearlCheck AvailabilityUsed 2013Chevrolet Impala LT - Bluetooth - OnStar - $88 B/W DetailsViking Price$9,644Exterior: BlackKey Features:
#  Check AvailabilityUsed 2013Subaru XV Crosstrek PURPLE - $137 B/W AWD DetailsViking Price$14,966Interior: EbonyKey Features:
#
#
#
#  Check AvailabilityUsed 2018Chevrolet Cruze LT - Bluetooth - Heated Seats - $124 B/W DetailsViking Price$18,288Exterior: SilverKey Features:
#
#
#
#  Check AvailabilityUsed 2018GMC Terrain SLE Diesel Amazing Fuel Mileage - Trade-in - $159 B/W 4WD DetailsViking Price$23,522Exterior: Summit WhiteInterior: GreyKey Features:
#
#
#
#
#
#
#
#  Check AvailabilityUsed 2017Chevrolet Traverse LT True North Edition - $173 B/W 4WD DetailsViking Price$25,598Exterior: Siren Red TintcoatKey Features:
#
#
#
#
#
#
#  Check AvailabilityUsed 2019Chevrolet Impala Premier - Navigation - Premier Luxury - $175 B/W DetailsViking Price$25,916Exterior: Nightfall GreyKey Features:
#
#
#
#
#
#
#   Check AvailabilityUsed 2017Chevrolet Silverado 1500 - $182 B/W DetailsViking Price$26,894Exterior: GraphiteKey Features:
#
#
#  Check Availability
#
#
# Contact InfoFirst Name*Last Name*PhoneEmail*
#
# Preferred Method of Contact*EmailPhonePreferred Language*EnglishFrenchWhat Are You Looking For?Type*NewUsedYear*20202019201820172016201520142013Odometer (Max)*50001000015000200002500030000400005000060000700008000090000100000150000AnyPrice (Max)*Any$200000$150000$120000$100000$90000$80000$70000$60000$50000$40000$30000$25000$20000$15000$10000$5000Make*Model*Trim*Colour*Transmission*AutomaticManualMessage
#
# ConsentPlease tell us how you would like us to communicate with you so we can better address your needs.
#
# Yes! Please sign me up to receive e-mails and other communications from Viking Motors. And please send me information on products, promotions and other related information.
#
#
# Yes! Please sign me up to receive e-mails and other communications from GM Canada. And please send me the GM newsletter, exclusive invites, special promotions and other related information.
#
#
# No, opt-out of receiving future marketing information.
# By providing my personal information, I am consenting to its use and disclosure in accordance with GM Canada's Privacy Policy. I confirm that I have read the Privacy Policy. I understand that I may withdraw my consent and unsubscribe from receiving future communications from GM Canada or Viking Motors, Main Street & Highway 68 Box 340, (855) 549-9944, boyd@vikingmotors.ca.By submitting this form, you agree to be contacted with information regarding the vehicle you are searching for.Referral ID #field_8_40 { display: none;}NameThis field is for validation purposes and should be left unchanged.
#
#
#
#
#
#
#
#
#
#
#
#
#
# jQuery(document).ready(function($){gformInitSpinner( 8, 'https://www.vikingmotors.ca/wp-content/plugins/gravityforms/images/spinner.gif' );jQuery('#gform_ajax_frame_8').load( function(){var contents = jQuery(this).contents().find('*').html();var is_postback = contents.indexOf('GF_AJAX_POSTBACK') >= 0;if(!is_postback){return;}var form_content = jQuery(this).contents().find('#gform_wrapper_8');var is_confirmation = jQuery(this).contents().find('#gform_confirmation_wrapper_8').length > 0;var is_redirect = contents.indexOf('gformRedirect(){') >= 0;var is_form = form_content.length > 0 && ! is_redirect && ! is_confirmation;if(is_form){jQuery('#gform_wrapper_8').html(form_content.html());if(form_content.hasClass('gform_validation_error')){jQuery('#gform_wrapper_8').addClass('gform_validation_error');} else {jQuery('#gform_wrapper_8').removeClass('gform_validation_error');}setTimeout( function() { /* delay the scroll by 50 milliseconds to fix a bug in chrome */ jQuery(document).scrollTop(jQuery('#gform_wrapper_8').offset().top); }, 50 );if(window['gformInitDatepicker']) {gformInitDatepicker();}if(window['gformInitPriceFields']) {gformInitPriceFields();}var current_page = jQuery('#gform_source_page_number_8').val();gformInitSpinner( 8, 'https://www.vikingmotors.ca/wp-content/plugins/gravityforms/images/spinner.gif' );jQuery(document).trigger('gform_page_loaded', [8, current_page]);window['gf_submitting_8'] = false;}else if(!is_redirect){var confirmation_content = jQuery(this).contents().find('#gforms_confirmation_message_8').html();if(!confirmation_content){confirmation_content = contents;}setTimeout(function(){jQuery('#gform_wrapper_8').replaceWith('<' + 'div id=\'gforms_confirmation_message_8\' class=\'gform_confirmation_message_8 gforms_confirmation_message\'' + '>' + confirmation_content + '<' + '/div' + '>');jQuery(document).scrollTop(jQuery('#gforms_confirmation_message_8').offset().top);jQuery(document).trigger('gform_confirmation_loaded', [8]);window['gf_submitting_8'] = false;}, 50);}else{jQuery('#gform_8').append(contents);if(window['gformRedirect']) {gformRedirect();}}jQuery(document).trigger('gform_post_render', [8, current_page]);} );} ); if(typeof gf_global == 'undefined') var gf_global = {"gf_currency_config":{"name":"U.S. Dollar","symbol_left":"$","symbol_right":"","symbol_padding":"","thousand_separator":",","decimal_separator":".","decimals":2},"base_url":"https:\/\/www.vikingmotors.ca\/wp-content\/plugins\/gravityforms","number_formats":[],"spinnerUrl":"https:\/\/www.vikingmotors.ca\/wp-content\/plugins\/gravityforms\/images\/spinner.gif"};jQuery(document).bind('gform_post_render', function(event, formId, currentPage){if(formId == 8) {if(!/(android)/i.test(navigator.userAgent)){jQuery('#input_8_3').mask('(999) 999-9999').bind('keypress', function(e){if(e.which == 13){jQuery(this).blur();} } );}} } );jQuery(document).bind('gform_post_conditional_logic', function(event, formId, fields, isInit){} ); jQuery(document).ready(function(){jQuery(document).trigger('gform_post_render', [8, 1]) } );
#
#
#
#
# Previous1 of 2Next
# Disclaimer:
# New vehicle pricing includes all offers and incentives. Tax, Title and Tags not included in vehicle prices shown and must be paid by the purchaser. While great effort is made to ensure the accuracy of the information on this site, errors do occur so please verify information with a customer service rep. This is easily done by calling us at (855) 549-9944 or by visiting us at the dealership.
# **With approved credit. Terms may vary. Monthly payments are only estimates derived from the vehicle price with a 72 month term, 5.9% interest and 0% downpayment.
# Dealer #0760

# %%
#Finding the titles of cars using find_all
#All the titles are present in h2 class : result-title
car_titles = []
a=soup.findAll('h2',{"class":"result-title"})
for i in a :
    print(i.text)#printing titles
    car_titles.append(i.text)#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# Used 2008Chevrolet HHR LS
# Used 2011GMC Acadia SLT1 - Bluetooth - Leather Seats 4WD
# Used 2014Jeep Cherokee SPORT - Bluetooth - Power Windows - $92 B/W
# Used 2010Ford Edge LIMITED - Leather Seats - Bluetooth 4WD
# Used 2010GMC Yukon SLT - Leather Seats - Bluetooth 4WD
# Used 2013Ford Edge SEL - Bluetooth - SYNC - SiriusXM - $142 B/W 4WD
# Used 2018Dodge Grand Caravan Canada Value Package - $135 B/W
# Used 2014Chevrolet Silverado 1500 LT D/C 4X4 5.3L V8 - $205 B/W
# Used 2018Chevrolet Traverse LT Cloth - Bluetooth - $216 B/W 4WD
# Used 2017Ram 1500 Longhorn - Navigation - Cooled Seats - $219 B/W
# Used 2004Chevrolet Malibu Maxx LS
# Used 2010Chevrolet Colorado LT W/1SD
# Used 2012Dodge Grand Caravan SE - One owner - Non-smoker
# Used 2013Chevrolet Impala LT - Bluetooth - OnStar - $88 B/W
# Used 2013Subaru XV Crosstrek PURPLE - $137 B/W AWD
# Used 2018Chevrolet Cruze LT - Bluetooth - Heated Seats - $124 B/W
# Used 2018GMC Terrain SLE Diesel Amazing Fuel Mileage - Trade-in - $159 B/W 4WD
# Used 2017Chevrolet Traverse LT True North Edition - $173 B/W 4WD
# Used 2019Chevrolet Impala Premier - Navigation - Premier Luxury - $175 B/W
# Used 2017Chevrolet Silverado 1500 - $182 B/W
# ['Used 2008Chevrolet HHR LS', 'Used 2011GMC Acadia SLT1 - Bluetooth - Leather Seats 4WD', 'Used 2014Jeep Cherokee SPORT - Bluetooth - Power Windows - $92 B/W', 'Used 2010Ford Edge LIMITED - Leather Seats - Bluetooth 4WD', 'Used 2010GMC Yukon SLT - Leather Seats - Bluetooth 4WD', 'Used 2013Ford Edge SEL - Bluetooth - SYNC - SiriusXM - $142 B/W 4WD', 'Used 2018Dodge Grand Caravan Canada Value Package - $135 B/W', 'Used 2014Chevrolet Silverado 1500 LT D/C 4X4 5.3L V8 - $205 B/W', 'Used 2018Chevrolet Traverse LT Cloth - Bluetooth - $216 B/W 4WD', 'Used 2017Ram 1500 Longhorn - Navigation - Cooled Seats - $219 B/W', 'Used 2004Chevrolet Malibu Maxx LS', 'Used 2010Chevrolet Colorado LT W/1SD', 'Used 2012Dodge Grand Caravan SE - One owner - Non-smoker', 'Used 2013Chevrolet Impala LT - Bluetooth - OnStar - $88 B/W', 'Used 2013Subaru XV Crosstrek PURPLE - $137 B/W AWD', 'Used 2018Chevrolet Cruze LT - Bluetooth - Heated Seats - $124 B/W', 'Used 2018GMC Terrain SLE Diesel Amazing Fuel Mileage - Trade-in - $159 B/W 4WD', 'Used 2017Chevrolet Traverse LT True North Edition - $173 B/W 4WD', 'Used 2019Chevrolet Impala Premier - Navigation - Premier Luxury - $175 B/W', 'Used 2017Chevrolet Silverado 1500 - $182 B/W']
# 20

# %%
exterior = []
interior = []
# taking empty lists

spec= soup.findAll('ul',{"class":"vehicle-details"}) #all the details are inside ul class: vehicle-details

for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('li')#finding all li inside ul
    for li in lis:
        
        if 'Exterior' in li.text: #if present
            exterior.append(li.text.replace("Exterior:",""))#then append
        if 'Interior' in li.text:#if present
            interior.append(li.text.replace("Interior:",""))#then append
       
        
#printing individual lists        
print(exterior)
print(interior)
# Out:
# [' Orange', ' Red', ' Green', ' Black', ' Silver', ' Black', ' White', ' Green', ' Pepperdust', ' Black', ' Blue', ' White', ' Cashmere Pearl', ' Black', ' Silver', ' Summit White', ' Siren Red Tintcoat', ' Nightfall Grey', ' Graphite']
# [' Greystone', ' Ebony', ' Grey']

# %%
car_price = []
a = soup.findAll('div',{"class":"hit-price__value"})
for i in a:
    print(i.text.strip())
    car_price.append(i.text.replace("Price","").strip())
print(car_price)
# Out:
# $2,977
# $11,588
# $11,966
# $12,944
# $14,269
# $15,488
# $19,988
# $26,772
# $31,988
# $32,488
# $2,950
# $6,844
# $8,745
# $9,644
# $14,966
# $18,288
# $23,522
# $25,598
# $25,916
# $26,894
# ['$2,977', '$11,588', '$11,966', '$12,944', '$14,269', '$15,488', '$19,988', '$26,772', '$31,988', '$32,488', '$2,950', '$6,844', '$8,745', '$9,644', '$14,966', '$18,288', '$23,522', '$25,598', '$25,916', '$26,894']

# %%
#creating dict of scrapped data
dict = {
    'Title' : car_titles ,
    'Exterior' : exterior , 
    'Interior ': interior,
    'Price' : car_price
}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                                                 Title             Exterior  \
# 0                           Used 2008Chevrolet HHR LS               Orange
# 1   Used 2011GMC Acadia SLT1 - Bluetooth - Leather...                  Red
# 2   Used 2014Jeep Cherokee SPORT - Bluetooth - Pow...                Green
# 3   Used 2010Ford Edge LIMITED - Leather Seats - B...                Black
# 4   Used 2010GMC Yukon SLT - Leather Seats - Bluet...               Silver
# 5   Used 2013Ford Edge SEL - Bluetooth - SYNC - Si...                Black
# 6   Used 2018Dodge Grand Caravan Canada Value Pack...                White
# 7   Used 2014Chevrolet Silverado 1500 LT D/C 4X4 5...                Green
# 8   Used 2018Chevrolet Traverse LT Cloth - Bluetoo...           Pepperdust
# 9   Used 2017Ram 1500 Longhorn - Navigation - Cool...                Black
# 10                  Used 2004Chevrolet Malibu Maxx LS                 Blue
# 11               Used 2010Chevrolet Colorado LT W/1SD                White
# 12  Used 2012Dodge Grand Caravan SE - One owner - ...       Cashmere Pearl
# 13  Used 2013Chevrolet Impala LT - Bluetooth - OnS...                Black
# 14  Used 2013Subaru XV Crosstrek PURPLE - $137 B/W...               Silver
# 15  Used 2018Chevrolet Cruze LT - Bluetooth - Heat...         Summit White
# 16  Used 2018GMC Terrain SLE Diesel Amazing Fuel M...   Siren Red Tintcoat
# 17  Used 2017Chevrolet Traverse LT True North Edit...       Nightfall Grey
# 18  Used 2019Chevrolet Impala Premier - Navigation...             Graphite
# 19       Used 2017Chevrolet Silverado 1500 - $182 B/W                 None
#
#      Interior     Price
# 0    Greystone   $2,977
# 1        Ebony  $11,588
# 2         Grey  $11,966
# 3         None  $12,944
# 4         None  $14,269
# 5         None  $15,488
# 6         None  $19,988
# 7         None  $26,772
# 8         None  $31,988
# 9         None  $32,488
# 10        None   $2,950
# 11        None   $6,844
# 12        None   $8,745
# 13        None   $9,644
# 14        None  $14,966
# 15        None  $18,288
# 16        None  $23,522
# 17        None  $25,598
# 18        None  $25,916
# 19        None  $26,894

# %%
#Dataframe to csv
df.to_csv('vikingmotors.csv')
