# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = input(("Enter url : "))
# "https://www.mcphillipstoyota.com/used/"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class col-xs-12 col-sm-12 col-md-12
data=soup.findAll('div',{"class":"col-xs-12 col-sm-12 col-md-12"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2010-suzuki-sx4-jlx-id10405846.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/84085012.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085012.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085014.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085014.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085016.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085016.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085018.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085018.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085020.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085020.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085022.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085022.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085024.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085024.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085025.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085025.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085028.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085028.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085031.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085031.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085033.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085033.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085035.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085035.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085045.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085045.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085051.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085051.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085056.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085056.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085066.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085066.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085069.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085069.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085070.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085070.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085072.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085072.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085075.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085075.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085076.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085076.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085077.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085077.jpeg"}]}
#                     jQuery("#carousel-example-generic-10405846").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# Get e-PriceBook a Test DriveApply For Financing2010 Suzuki SX4 JLXJLXPrice: $7,599Price does not include taxes and licensing fees.
# Subject to availability.Mileage:193,774 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:HatchbackEngine:2.0L 4cylExterior Colour:Blue
#
#
#
#
# Transmission:AutomaticDrivetrain:All Wheel DriveStock #:B10943ACity:Winnipeg
#
# McPhillips Toyota+1-866-289-1417RECENT TRADE IN LOW COST AWD JUST IN TIME FOR WINTER COME CHECK OUT THIS 2010 Suzuki SX4 JLX AWD CVT 2.0L I4 DOHC 16V    AWD..maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2009-toyota-rav4-base-id10321001.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/83866936.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83866936.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445285.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445285.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445287.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445287.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445290.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445290.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445293.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445293.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445294.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445294.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445297.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445297.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445298.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445298.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445300.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445300.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445303.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445303.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445305.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445305.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445307.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445307.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445311.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445311.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445313.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445313.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445315.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445315.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445318.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445318.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445320.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445320.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445323.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445323.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445325.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445325.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445326.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445326.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445327.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445327.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445328.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445328.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82445329.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82445329.jpeg"}]}
#                     jQuery("#carousel-example-generic-10321001").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# Get e-PriceBook a Test DriveApply For Financing2009 Toyota RAV4Price:$11,599 $9,534Price does not include taxes and licensing fees.
# Subject to availability.Mileage:212,505 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SUVEngine:2.5L 4cylExterior Colour:White
#
#
#
#
# Transmission:AutomaticDrivetrain:4x4Stock #:S042029CCity:Winnipeg
#
# McPhillips Toyota+1-866-289-14172009 Toyota RAV4 4WD 4-Speed Automatic with Overdrive 2.5L 4-Cylinder    4WD..maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2008-toyota-rav4-base-id10405850.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/83955575.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83955575.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83955576.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83955576.jpeg"}]}
#                     jQuery("#carousel-example-generic-10405850").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# Get e-PriceBook a Test DriveApply For Financing2008 Toyota RAV4Price: $11,599Price does not include taxes and licensing fees.
# Subject to availability.Mileage:136,329 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SUVEngine:2.4L 4cylExterior Colour:Silver
#
#
#
#
# Transmission:AutomaticDrivetrain:4x4Stock #:X950842BCity:Winnipeg
#
# McPhillips Toyota+1-866-289-14172008 Toyota RAV4 4WD 4-Speed Automatic with Overdrive 2.4L 4-Cylinder    4WD.    EXTREMELY NICE RIDE AMERICAN VEHICLE WHICH HAS ONLY HAS 136,000 KMS (85,000 MILES)     PERFECT BUDGET SUV AWD FOR THE UPCOMING SNOWY SEASON!!.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/
jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085013.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085015.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085015.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085017.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085017.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085019.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085019.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085021.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085021.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085023.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085023.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085026.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085026.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085030.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085030.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085032.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085032.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085034.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085034.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085038.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085038.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085044.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085044.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085049.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085049.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085060.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085060.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085064.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085064.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085068.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085068.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085071.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085071.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84085073.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84085073.jpeg"}]}
#                     jQuery("#carousel-example-generic-10395308").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# Get e-PriceBook a Test DriveApply For Financing2013 Toyota RAV4Price: $16,599Price does not include taxes and licensing fees.
# Subject to availability.Mileage:91,816 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SUVEngine:2.5L 4cylExterior Colour:Black
#
#
#
#
# Transmission:AutomaticDrivetrain:Front Wheel DriveStock #:W106345ACity:Winnipeg
#
# McPhillips Toyota+1-866-289-1417.....Read LessRecent arrival this 2013 Toyota RAV4 LE FWD 6-Speed Automatic 2.5L 4-Cylinder SMPI      Reviews:    * RAV4 owners typically rave about fuel economy, highway ride quality and noise levels, and semi-sporty handling. The slick and seamless AWD system is a feature favourite in i.....Read More.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2017-toyota-corolla-id10410605.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/84074330.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074330.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074331.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074331.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074333.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074333.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074335.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074335.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074338.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074338.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074341.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074341.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074343.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074343.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074345.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074345.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074348.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074348.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074351.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074351.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074354.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074354.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074356.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074356.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074363.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074363.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074366.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074366.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074371.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074371.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074374.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074374.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074378.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074378.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074380.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074380.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074384.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074384.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074386.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074386.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074389.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074389.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074392.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074392.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074394.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074394.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/84074397.jpeg","thumbnailUrl":"https://images.edealer.ca/4/84074397.jpeg"}]}
#                     jQuery("#carousel-example-generic-10410605").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# Get e-PriceBook a Test DriveApply For Financing2017 Toyota CorollaPrice: $17,599Price does not include taxes and licensing fees.
# Subject to availability.Finance from $126*(Bi-weekly)$17,599 x 84 Months @ 7.99% APR (estimated financing rate, cost of borrowing $5,404).
# $0 down payment. Plus Taxes and License.Mileage:31,470 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SedanEngine:1.8L 4cylExterior Colour:Red
#
#
#
#
# Transmission:AutomaticDrivetrain:Front Wheel DriveStock #:P142127ACity:Winnipeg
#
# McPhillips Toyota+1-866-289-1417
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2019-toyota-corolla-le-id10359210.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/83274120.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83274120.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956831.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956831.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956833.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956833.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956835.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956835.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956836.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956836.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956837.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956837.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956838.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956838.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956839.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956839.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956840.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956840.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956841.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956841.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956842.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956842.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956843.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956843.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956844.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956844.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956847.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956847.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956849.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956849.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956850.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956850.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956851.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956851.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956852.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956852.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956853.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956853.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956854.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956854.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956855.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956855.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82956856.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82956856.jpeg"}]}
#                     jQuery("#carousel-example-generic-10359210").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# Get e-PriceBook a Test DriveApply For Financing2019 Toyota Corolla LELEPrice: $18,599Price does not include taxes and licensing fees.
# Subject to availability.Finance from $121*(Bi-weekly)$18,599 x 96 Months @ 7.99% APR (estimated financing rate, cost of borrowing $6,601).
# $0 down payment. Plus Taxes and License.Mileage:53,473 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SedanEngine:1.8L 4cylExterior Colour:Red
#
#
#
#
# Transmission:AutomaticDrivetrain:Front Wheel DriveStock #:W128672ACity:Winnipeg
#
# McPhillips Toyota+1-866-289-1417.....Read Less2019 Toyota Corolla LE FWD CVT 1.8L 4-Cylinder DOHC 16V    SUPER NICE SUPER CLEAN VEHICLE GREAT KMS ONLY 53,000!!! LOCAL TRADE DON'T MISS OUT ON THIS PREMIUM VEHICLE    ABS brakes, Active Cruise Control, Electronic Stability Control, Heated door mirrors, Heated Front Bucket .....Read More.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}

# %%
#Finding the titles of cars using find_all
#All the titles are present in p class : vehicle-year-make-model
car_titles = []
a=soup.findAll('p',{"class":"vehicle-year-make-model"})
for i in a :
    print(i.text)#printing titles
    car_titles.append(i.text)#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# 2010 Suzuki SX4 JLX
# 2009 Toyota RAV4
# 2008 Toyota RAV4
# 2013 Honda Accord EX-L-NAVI
# 2019 Ford Fiesta SE
# 2016 Toyota Corolla LE
# 2013 Toyota RAV4
# 2017 Toyota Corolla
# 2019 Toyota Corolla LE
# ['2010 Suzuki SX4 JLX', '2009 Toyota RAV4', '2008 Toyota RAV4', '2013 Honda Accord EX-L-NAVI', '2019 Ford Fiesta SE', '2016 Toyota Corolla LE', '2013 Toyota RAV4', '2017 Toyota Corolla', '2019 Toyota Corolla LE']
# 9

# %%
#Finding the msrp of cars using find_all
#All the msrp are present in strike class : old-price
msrp = []
a=soup.findAll('strike',{"class":"old-price"})
for i in a :
    print(i.text)#printing msrp
    msrp.append(i.text)#appending values
print(msrp)#printing msrp
len(msrp)#printing length of list
# Out:
# $11,599
# $16,599
# ['$11,599', '$16,599']
# 2

# %%
#Finding the car  price   using find_all
#All the car price are present in span itemprop : price
car_price = []
a=soup.findAll('span',{"itemprop":"price"})
for i in a :
    print(i.text)#printing  price
    car_price .append(i.text)#appending values
print(car_price)#printing  price
len(car_price)#printing length of list
# Out:
# $7,599
# $9,534
# $11,599
# $13,598
# $15,113
# $15,599
# $16,599
# $17,599
# $18,599
# ['$7,599', '$9,534', '$11,599', '$13,598', '$15,113', '$15,599', '$16,599', '$17,599', '$18,599']
# 9

# %%
transmission = []
body_style = []
exterior = []
stock = []
# taking empty lists

spec= soup.findAll('table',{"class":"table"})
for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('tr',{"class":"tr-even"})#finding all tr inside table wit class tr-even
    for li in lis:
        
        if 'Transmission' in li.text: #if present
            transmission.append(li.text.replace("Transmission:",""))#then append
        if 'Exterior Colour' in li.text:#if present
            exterior.append(li.text.replace("Exterior Colour:",""))#then append
        if 'Body Style' in li.text:#if present
            body_style.append(li.text.replace("Body Style:",""))#then append
        if 'Stock' in li.text: #if present
            stock.append(li.text.replace("Stock #:","")) #then append

            #printing individual lists        
print(transmission)
print(exterior)
print(body_style)
print(stock)
# Out:
# ['Automatic', 'Automatic', 'Automatic', 'Automatic', 'Other', 'Automatic', 'Automatic', 'Automatic', 'Automatic']
# ['Blue', 'White', 'Silver', 'Grey', 'White', 'White', 'Black', 'Red', 'Red']
# ['Hatchback', 'SUV', 'SUV', 'Coupe', 'Sedan', 'Sedan', 'SUV', 'Sedan', 'Sedan']
# ['B10943A', 'S042029C', 'X950842B', 'X243896A', 'A14063', 'C117312A', 'W106345A', 'P142127A', 'W128672A']

# %%
engine = []
drive_train = []
location = []
# taking empty lists

spec= soup.findAll('table',{"class":"table"})
for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('tr',{"class":"tr-odd"})#finding all tr inside table wit class tr-odd
    for li in lis:
       
        if 'Engine' in li.text: #if present
            engine.append(li.text.replace("Engine:",""))#then append
        if 'Drivetrain' in li.text:#if present
            drive_train.append(li.text.replace("Drivetrain:",""))#then append
        if 'City' in li.text:#if present
            location.append(li.text.replace("City:",""))#then append
       
 #printing individual lists        
print(engine)
print(drive_train)
print(location)
# Out:
# ['2.0L 4cyl', '2.5L 4cyl', '2.4L 4cyl', '2.4L 4cyl', '1.6L 4cyl', '1.8L 4cyl', '2.5L 4cyl', '1.8L 4cyl', '1.8L 4cyl']
# ['All Wheel Drive', '4x4', '4x4', 'Front Wheel Drive', 'Front Wheel Drive', 'Front Wheel Drive', 'Front Wheel Drive', 'Front Wheel Drive', 'Front Wheel Drive']
# ['Winnipeg', 'Winnipeg', 'Winnipeg', 'Winnipeg', 'Winnipeg', 'Winnipeg', 'Winnipeg', 'Winnipeg', 'Winnipeg']

# %%
car_mileage = []#taking an empty list
mileage = soup.findAll('span',{"class":"mileage-used-list"})#scrapping mileage
for i in mileage:
    print(i.text)
    car_mileage.append(i.text)#appending in a list
print(car_mileage)#printing values
# Out:
# 193,774 km
# 212,505 km
# 136,329 km
# 163,738 km
# 40,224 km
# 88,097 km
# 91,816 km
# 31,470 km
# 53,473 km
# ['193,774 km', '212,505 km', '136,329 km', '163,738 km', '40,224 km', '88,097 km', '91,816 km', '31,470 km', '53,473 km']

# %%
#creating dict of scrapped data
dict = {
    'Title' : car_titles,
    'MSRP':msrp,
    'Price' : car_price,
    'Transmission' : transmission,
    'Exterior':exterior,
    'Body Style':body_style,
    'Stock' : stock,
    'Engine' : engine ,
    'Drive Train':drive_train,
    'Location':location,
    'Mileage':car_mileage
}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                          Title     MSRP    Price Transmission Exterior  \
# 0          2010 Suzuki SX4 JLX  $11,599   $7,599    Automatic     Blue
# 1             2009 Toyota RAV4  $16,599   $9,534    Automatic    White
# 2             2008 Toyota RAV4     None  $11,599    Automatic   Silver
# 3  2013 Honda Accord EX-L-NAVI     None  $13,598    Automatic     Grey
# 4          2019 Ford Fiesta SE     None  $15,113        Other    White
# 5       2016 Toyota Corolla LE     None  $15,599    Automatic    White
# 6             2013 Toyota RAV4     None  $16,599    Automatic    Black
# 7          2017 Toyota Corolla     None  $17,599    Automatic      Red
# 8       2019 Toyota Corolla LE     None  $18,599    Automatic      Red
#
#   Body Style     Stock     Engine        Drive Train  Location     Mileage
# 0  Hatchback   B10943A  2.0L 4cyl    All Wheel Drive  Winnipeg  193,774 km
# 1        SUV  S042029C  2.5L 4cyl                4x4  Winnipeg  212,505 km
# 2        SUV  X950842B  2.4L 4cyl                4x4  Winnipeg  136,329 km
# 3      Coupe  X243896A  2.4L 4cyl  Front Wheel Drive  Winnipeg  163,738 km
# 4      Sedan    A14063  1.6L 4cyl  Front Wheel Drive  Winnipeg   40,224 km
# 5      Sedan  C117312A  1.8L 4cyl  Front Wheel Drive  Winnipeg   88,097 km
# 6        SUV  W106345A  2.5L 4cyl  Front Wheel Drive  Winnipeg   91,816 km
# 7      Sedan  P142127A  1.8L 4cyl  Front Wheel Drive  Winnipeg   31,470 km
# 8      Sedan  W128672A  1.8L 4cyl  Front Wheel Drive  Winnipeg   53,473 km

# %%
#Dataframe to csv
df.to_csv('mcphillipstoyota.csv')
