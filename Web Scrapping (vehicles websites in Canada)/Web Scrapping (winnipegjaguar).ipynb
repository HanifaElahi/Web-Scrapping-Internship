# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = "https://www.winnipegjaguar.com/en/inventory/search-new-inventory"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class group-content
data=soup.findAll('section',{"class":"group-content"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
# 12 Vehicles Found
#
#
# 5
#
# 10
#
# 20
#
# 50
#
# 100
#
#
# --- Sort by: ---
# Price: lowest first
# Price: highest first
# Makes: A - Z
# Makes: Z - A
# Models: A - Z
# Models: Z - A
# Odometer: lowest first
# Odometer: highest first
# Year: oldest first
# Year: newest first
# Dealer: closest
#
#
#
# List view
# Grid view
#
#
#
#
# On special
#
#
#
# View 31 Photos
#
#
# in stock
# 2020 Jaguar XE
# SE
# Details
#
# Odometer
# 42 KMS
# Color
# Fuji White
# Engine
# 2L I-4
# Transmission
# 8 Spd Automatic
# Drivetrain
# AWD
# Stock #
# J20018
# VIN
# SAJAP4FX4LCP61355
#
#
#
# Was $61,365
#
# $53,975*
# You Save $7,390
#
# $61,365 Retail Price
# - $7,390 Dealer Discount/Manufacturer Rebate
# 				= $7,390 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Jaguar XE",
# 		"brand": "Jaguar",
# 		"description": "12-Way with Heated Front and Driver Memory Seats&lt;br&gt;&lt;br&gt;Meshed Aluminum Trim Finisher&lt;br&gt;&lt;br&gt;Technology Pack&lt;br&gt;&lt;br&gt;Black Pack&lt;br&gt;&lt;br&gt;Heated Steering Wheel&lt;br&gt;&lt;br&gt;19&quot; Style 5031 - Gloss Silver with Contrast Diamond Turned Wheels&lt;br&gt;&lt;br&gt;Meridian Surround System&lt;br&gt;&lt;br&gt;DEFA Battery Charger and Pan Heater&lt;br&gt;&lt;br&gt;Also Included with SE:&lt;br&gt;- D-Pack&lt;br&gt;- Grained - Ebony Seats&lt;br&gt;- Fuji White&lt;br&gt;- Auto-Dimming, Power Fold, Heated Door Mirrors with Memory and Approach Lights -- Dealer permit #0112 #3",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5df2de6a7cb38273dd48dd4e.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "53975"
# 		},
# 		"sku": "J20018",
# 		"itemCondition": "new",
# 		"color": "White",
# 		"model": "XE",
# 		"vehicleConfiguration": "SE SE",
# 		"driveWheelConfiguration": "AWD",
# 		"vehicleTransmission": "8 Spd Automatic",
# 		"disambiguatingDescription": "4dr AWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "42",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "SAJAP4FX4LCP61355",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 4 Photos
#
#
# in stock
# 2020 Jaguar F-PACE
# R-Sport
# Details
#
# Odometer
# 2 KMS
# Color
# Fuji White
# Engine
# 2L I-4
# Transmission
# 8 Spd Automatic
# Drivetrain
# AWD
# Stock #
# J20041
# VIN
# SADCL2FX5LA660803
#
#
#
#
# $74,570
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Jaguar F-PACE",
# 		"brand": "Jaguar",
# 		"description": "Technology Pack&lt;br&gt;&lt;br&gt;Luxury Interior Pack&lt;br&gt;&lt;br&gt;Heated Windscreen&lt;br&gt;&lt;br&gt;Ebony Headlining&lt;br&gt;&lt;br&gt;Tow Hitch Receiver&lt;br&gt;&lt;br&gt;Sirius XM Satellite Radio and HD Radio&lt;br&gt;&lt;br&gt;Drive Pack&lt;br&gt;&lt;br&gt;DEFA Battery Charger and Pan Heater&lt;br&gt;&lt;br&gt;Also Included with R-Sport:&lt;br&gt;- D-Pack&lt;br&gt;- Ebony, Grained Perforated Leather&lt;br&gt;- Fuji White&lt;br&gt;- Gloss Black Trim Finisher&lt;br&gt;- Side Vents - R Sport&lt;br&gt;- Bodyside Cladding - Body Colored w/Satin Black&lt;br&gt;- Grille - Gloss Black/Satin Chrome Surround&lt;br&gt;- Illuminated Metal Tread Plates with Brand-Name Script&lt;br&gt;- 18-Way Sport Front Seats&lt;br&gt;- Premium Seats&lt;br&gt;- Heated Front Seats -- Dealer permit #0112 #3",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5fb46d5394721b3fffd18bd5.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "74570"
# 		},
# 		"sku": "J20041",
# 		"itemCondition": "new",
# 		"color": "White",
# 		"model": "F-PACE",
# 		"vehicleConfiguration": "R-Sport R-Sport",
# 		"driveWheelConfiguration": "AWD",
# 		"vehicleTransmission": "8 Spd Automatic",
# 		"disambiguatingDescription": "4dr AWD Sport Utility",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "2",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "SADCL2FX5LA660803",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 31 Photos
#
#
# in stock
# 2020 Jaguar F-PACE
# R-Sport
# Details
#
# Odometer
# 3,406 KMS
# Color
# Santorini Black
# Engine
# 2L I-4
# Transmission
# 8 Spd Automatic
# Drivetrain
# AWD
# Stock #
# J20037
# VIN
# SADCL2FX6LA644061
#
#
#
# Was $78,593
#
# $74,593*
# You Save $4,000
#
# $78,593 Retail Price
# - $4,000 Dealer Discount/Manufacturer Rebate
# 				= $4,000 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Jaguar F-PACE",
# 		"brand": "Jaguar",
# 		"description": "Protection Pack (Chrome Wheel Locks)&lt;br&gt;&lt;br&gt;Santorini Black&lt;br&gt;&lt;br&gt;360 Surround Camera&lt;br&gt;&lt;br&gt;Technology Pack&lt;br&gt;&lt;br&gt;Gloss Black Roof Rails&lt;br&gt;&lt;br&gt;Black Exterior Pack R-Sport&lt;br&gt;&lt;br&gt;22&quot; Style 1020 - Gloss Black w/Satin Black Inserts&lt;br&gt;&lt;br&gt;Sirius XM Satellite Radio and HD Radio&lt;br&gt;&lt;br&gt;Drive Pack&lt;br&gt;&lt;br&gt;Also Included with R-Sport:&lt;br&gt;- D-Pack&lt;br&gt;- Ebony/Pimento, Grained Leather Seats&lt;br&gt;- Gloss Black Trim Finisher&lt;br&gt;- Illuminated Metal Treadplates with Brand-Name Script&lt;br&gt;- 18-Way Sport Front Seats&lt;br&gt;- Premium Seats&lt;br&gt;- Heated Front Seats -- Dealer permit #0112 #3",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f260af1ca2e9d413aafc211.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "74593"
# 		},
# 		"sku": "J20037",
# 		"itemCondition": "new",
# 		"color": "Black",
# 		"model": "F-PACE",
# 		"vehicleConfiguration": "R-Sport R-Sport",
# 		"driveWheelConfiguration": "AWD",
# 		"vehicleTransmission": "8 Spd Automatic",
# 		"disambiguatingDescription": "4dr AWD Sport Utility",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "3,406",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "SADCL2FX6LA644061",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 4 Photos
#
#
# in stock
# 2020 Jaguar F-PACE
# R-Sport
# Details
#
# Odometer
# 3,712 KMS
# Color
# Narvik Black
# Engine
# 2L I-4
# Transmission
# 8 Spd Automatic
# Drivetrain
# AWD
# Stock #
# J20036
# VIN
# SADCL2GX5LA632028
#
#
#
# Was $86,993
#
# $82,993*
# You Save $4,000
#
# $86,993 Retail Price
# - $4,000 Dealer Discount/Manufacturer Rebate
# 				= $4,000 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Jaguar F-PACE",
# 		"brand": "Jaguar",
# 		"description": "Protection Package&lt;br&gt;&lt;br&gt;Etched Aluminum Trim Finisher&lt;br&gt;&lt;br&gt;Technology Pack&lt;br&gt;&lt;br&gt;Gloss Black Roof Rails&lt;br&gt;&lt;br&gt;Heated Windscreen&lt;br&gt;&lt;br&gt;Black Exterior Pack&lt;br&gt;&lt;br&gt;Ebony Headlining&lt;br&gt;&lt;br&gt;20&quot; Style 5035 - Gloss Black&lt;br&gt;&lt;br&gt;Sirius XM Satellite Radio and HD Radio&lt;br&gt;&lt;br&gt;Driver Assist Pack&lt;br&gt;&lt;br&gt;Comfort and Convenience Pack&lt;br&gt;&lt;br&gt;Also Included with R-Sport:&lt;br&gt;- D-Pack&lt;br&gt;- Narvik Black&lt;br&gt;- Illuminated Metal Treadplates with Brand-Name Script&lt;br&gt;- 18-Way Sport Front Seats -- Dealer permit #0112 #3",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f260aae1015b13163abb3c7.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "82993"
# 		},
# 		"sku": "J20036",
# 		"itemCondition": "new",
# 		"color": "Black",
# 		"model": "F-PACE",
# 		"vehicleConfiguration": "R-Sport R-Sport",
# 		"driveWheelConfiguration": "AWD",
# 		"vehicleTransmission": "8 Spd Automatic",
# 		"disambiguatingDescription": "4dr AWD Sport Utility",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "3,712",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "SADCL2GX5LA632028",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 31 Photos
#
#
# in stock
# 2020 Jaguar F-PACE
# 300 Sport | The Art of Performance
# Details
#
# Odometer
# 1,032 KMS
# Color
# Santorini Black
# Engine
# 2L I-4
# Transmission
# 8 Spd Automatic
# Drivetrain
# AWD
# Stock #
# J20027
# VIN
# SADCX2GX2LA642732
#
#
#
# Was $89,048
#
# $86,048*
# You Save $3,000
#
# $89,048 Retail Price
# - $3,000 Dealer Discount/Manufacturer Rebate
# 				= $3,000 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Jaguar F-PACE",
# 		"brand": "Jaguar",
# 		"description": "Protection Pack (Chrome Wheel Locks)&lt;br&gt;&lt;br&gt;Satin Burr Ash Veneer&lt;br&gt;&lt;br&gt;360 Surround Camera&lt;br&gt;&lt;br&gt;Luxury Interior Pack&lt;br&gt;&lt;br&gt;Heated Windscreen&lt;br&gt;&lt;br&gt;Head-Up Display&lt;br&gt;&lt;br&gt;Tow Hitch Receiver&lt;br&gt;&lt;br&gt;Meridian Surround Sound System - 825W&lt;br&gt;&lt;br&gt;Sirius XM Satellite Radio and HD Radio&lt;br&gt;&lt;br&gt;Drive Pack&lt;br&gt;&lt;br&gt;Comfort and Convenience Pack&lt;br&gt;&lt;br&gt;DEFA Battery Charger and Pan Heater&lt;br&gt;&lt;br&gt;Also Included with 300 Sport:&lt;br&gt;- D-Pack&lt;br&gt;- Ebony, Grained Perforated Leather&lt;br&gt;- Santorini Black&lt;br&gt;- 20&quot; Style 5035 - Satin Dark Grey w/Contrast Diamond Turned -- Dealer permit #0112 #3",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5e3b5f6df9a9e70bf75683b2.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "86048"
# 		},
# 		"sku": "J20027",
# 		"itemCondition": "new",
# 		"color": "Black",
# 		"model": "F-PACE",
# 		"vehicleConfiguration": "300 Sport | The Art of Performance 300 Sport",
# 		"driveWheelConfiguration": "AWD",
# 		"vehicleTransmission": "8 Spd Automatic",
# 		"disambiguatingDescription": "4dr AWD Sport Utility",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "1,032",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "SADCX2GX2LA642732",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 26 Photos
#
#
# in stock
# 2020 Jaguar F-PACE
# S
# Details
#
# Odometer
# 2 KMS
# Color
# Fuji White
# Engine
# 3L V-6
# Transmission
# 8 Spd Automatic
# Drivetrain
# AWD
# Stock #
# J20039
# VIN
# SADCM2FV1LA658848
#
#
#
#
# $93,215
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Jaguar F-PACE",
# 		"brand": "Jaguar",
# 		"description": "Carbon Fibre Trim Finisher&lt;br&gt;&lt;br&gt;Technology Pack&lt;br&gt;&lt;br&gt;Luxury Interior Pack&lt;br&gt;&lt;br&gt;Heated Windscreen&lt;br&gt;&lt;br&gt;Head-Up Display&lt;br&gt;&lt;br&gt;Black Exterior Pack&lt;br&gt;&lt;br&gt;22&quot; Style 1020 - Gloss Black w/Satin Black Inserts&lt;br&gt;&lt;br&gt;Driver Assist Pack&lt;br&gt;&lt;br&gt;Memory Pack + Performance Seats&lt;br&gt;&lt;br&gt;Also Included with S:&lt;br&gt;- D-Pack&lt;br&gt;- Lt. Oyster/Ebony, Windsor Leather&lt;br&gt;- Fuji White&lt;br&gt;- Metal Treadplates with Trim Level Branding (non-illuminated)&lt;br&gt; -- Dealer permit #0112 #3",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f9a0e7cd5b91b0f173a1d9a.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "93215"
# 		},
# 		"sku": "J20039",
# 		"itemCondition": "new",
# 		"color": "White",
# 		"model": "F-PACE",
# 		"vehicleConfiguration": "S S",
# 		"driveWheelConfiguration": "AWD",
# 		"vehicleTransmission": "8 Spd Automatic",
# 		"disambiguatingDescription": "4dr AWD Sport Utility",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "2",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "V-6",
# 		"vehicleIdentificationNumber": "SADCM2FV1LA658848",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 30 Photos
#
#
# in stock
# 2020 Jaguar F-PACE
# SVR
# Details
#
# Odometer
# 19 KMS
# Color
# Ultra Blue
# Engine
# 5L V-8
# Transmission
# 8 Spd Automatic
# Drivetrain
# AWD
# Stock #
# J20023
# VIN
# SADCZ2EE5LA639643
#
#
#
# Was $108,630
#
# $103,630*
# You Save $5,000
#
# $108,630 Retail Price
# - $5,000 Dealer Discount/Manufacturer Rebate
# 				= $5,000 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Jaguar F-PACE",
# 		"brand": "Jaguar",
# 		"description": "Aluminum Weave Carbon Fibre Trim Finisher&lt;br&gt;&lt;br&gt;Luxury Interior Pack&lt;br&gt;&lt;br&gt;Heated Windscreen&lt;br&gt;&lt;br&gt;Head-Up Display&lt;br&gt;&lt;br&gt;22&quot; Style 5081 - Gloss Black&lt;br&gt;&lt;br&gt;Tow Hitch Receiver&lt;br&gt;&lt;br&gt;Meridian Surround System - 825W&lt;br&gt;&lt;br&gt;Sirius XM Satellite Radio and HD Radio&lt;br&gt;&lt;br&gt;Drive Pack&lt;br&gt;&lt;br&gt;DEFA Battery Charger and Pan Heater&lt;br&gt;&lt;br&gt;Also Included with SVR:&lt;br&gt;- D-Pack&lt;br&gt;- Ebony, Lozenge Quilted Interior&lt;br&gt;- Ultra Blue&lt;br&gt;- Rear Seat Remote Release Levers -- Dealer permit #0112 #3",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5e1130799bd8611b6d8d5a24.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "103630"
# 		},
# 		"sku": "J20023",
# 		"itemCondition": "new",
# 		"color": "Blue",
# 		"model": "F-PACE",
# 		"vehicleConfiguration": "SVR SVR",
# 		"driveWheelConfiguration": "AWD",
# 		"vehicleTransmission": "8 Spd Automatic",
# 		"disambiguatingDescription": "4dr AWD Sport Utility",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "19",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "V-8",
# 		"vehicleIdentificationNumber": "SADCZ2EE5LA639643",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 30 Photos
#
#
# in stock
# 2020 Jaguar F-PACE
# SVR
# Details
#
# Odometer
# 19 KMS
# Color
# Fuji White
# Engine
# 5L V-8
# Transmission
# 8 Spd Automatic
# Drivetrain
# AWD
# Stock #
# J20024
# VIN
# SADCZ2EE5LA639531
#
#
#
# Was $109,040
#
# $104,040*
# You Save $5,000
#
# $109,040 Retail Price
# - $5,000 Dealer Discount/Manufacturer Rebate
# 				= $5,000 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Jaguar F-PACE",
# 		"brand": "Jaguar",
# 		"description": "Aluminum Weave Carbon Fibre Trim Finisher&lt;br&gt;&lt;br&gt;Luxury Interior Pack&lt;br&gt;&lt;br&gt;Roof Rails - Gloss Black&lt;br&gt;&lt;br&gt;Heated Windscreen&lt;br&gt;&lt;br&gt;Head-Up Display&lt;br&gt;&lt;br&gt;22&quot; Style 5081 - Gloss Black&lt;br&gt;&lt;br&gt;Tow Hitch Receiver&lt;br&gt;&lt;br&gt;Meridian Surround System - 825W&lt;br&gt;&lt;br&gt;Sirius XM Satellite Radio and HD Radio&lt;br&gt;&lt;br&gt;Drive Pack&lt;br&gt;&lt;br&gt;DEFA Battery Charger and Pan Heater&lt;br&gt;&lt;br&gt;Also Included with SVR:&lt;br&gt;- D-Pack&lt;br&gt;- Ebony/Sienna Tan, Lozenge Quilted&lt;br&gt;- Fuji White&lt;br&gt;- Rear Seat Remote Release Levers -- Dealer permit #0112 #3",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5e11303493443f1661c045c6.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "104040"
# 		},
# 		"sku": "J20024",
# 		"itemCondition": "new",
# 		"color": "White",
# 		"model": "F-PACE",
# 		"vehicleConfiguration": "SVR SVR",
# 		"driveWheelConfiguration": "AWD",
# 		"vehicleTransmission": "8 Spd Automatic",
# 		"disambiguatingDescription": "4dr AWD Sport Utility",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "19",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "V-8",
# 		"vehicleIdentificationNumber": "SADCZ2EE5LA639531",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 29 Photos
#
#
# in stock
# 2020 Jaguar I-PACE
# SE
# Details
#
# Odometer
# 4,622 KMS
# Color
# Fuji White
# Drivetrain
# AWD
# Stock #
# J20021
# VIN
# SADHC2S14L1F87157
#
#
#
# Was $114,625
#
# $104,125*
# You Save $10,500
#
# $114,625 Retail Price
# - $10,500 Dealer Discount/Manufacturer Rebate
# 				= $10,500 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Jaguar I-PACE",
# 		"brand": "Jaguar",
# 		"description": "Sport Windsor - Ebony/Ebony&lt;br&gt;&lt;br&gt;18-Way Heated and Cooled Electric Memory Front Seats with Heated Rear Seats&lt;br&gt;&lt;br&gt;Activity Key&lt;br&gt;&lt;br&gt;Front Fog Lights&lt;br&gt;&lt;br&gt;Head-Up Display Full Color (HUD Gen 2)&lt;br&gt;&lt;br&gt;Black Exterior Pack&lt;br&gt;&lt;br&gt;Full Extended Leather Upgrade&lt;br&gt;&lt;br&gt;20&quot; Style 5068, 5-Spoke Gloss Black&lt;br&gt;&lt;br&gt;Adaptive Dynamics&lt;br&gt;&lt;br&gt;Driver Assist Pack&lt;br&gt;&lt;br&gt;Cold Climate Pack&lt;br&gt;&lt;br&gt;Also Included with SE:&lt;br&gt;- Fuji White&lt;br&gt;- Light Oyster Morzine Headlining&lt;br&gt;- Power Tailgate&lt;br&gt; -- Dealer permit #0112 #3",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5df975229bd86146e3ac9b5e.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "104125"
# 		},
# 		"sku": "J20021",
# 		"itemCondition": "new",
# 		"color": "White",
# 		"model": "I-PACE",
# 		"vehicleConfiguration": "SE SE",
# 		"driveWheelConfiguration": "AWD",
# 		"vehicleTransmission": "",
# 		"disambiguatingDescription": "4dr AWD Sport Utility",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Electric Fuel System",
# 		"mileageFromOdometer": "4,622",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "E-0",
# 		"vehicleIdentificationNumber": "SADHC2S14L1F87157",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 34 Photos
#
#
# in stock
# 2020 Jaguar F-PACE
# SVR | 5.0L V8 Supercharged, 550 hp
# Details
#
# Odometer
# 49 KMS
# Color
# Indus Silver Metallic
# Engine
# 5L V-8
# Transmission
# 8 Spd Automatic
# Drivetrain
# AWD
# Stock #
# J20011
# VIN
# SADCZ2EE3LA632724
#
#
#
# Was $112,058
#
# $107,058*
# You Save $5,000
#
# $112,058 Retail Price
# - $5,000 Dealer Discount/Manufacturer Rebate
# 				= $5,000 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Jaguar F-PACE",
# 		"brand": "Jaguar",
# 		"description": "Protection Package (Chrome Wheel Locks)&lt;br&gt;&lt;br&gt;Aluminum Weave Carbon Fiber Trim Finisher&lt;br&gt;&lt;br&gt;Luxury Interior Pack&lt;br&gt;&lt;br&gt;Heated Windscreen&lt;br&gt;&lt;br&gt;Head-Up Display&lt;br&gt;&lt;br&gt;22&quot; Style 5081 - Satin Technical Grey w/Contrast Diamond Turned Wheels&lt;br&gt;&lt;br&gt;Tow Hitch Receiver&lt;br&gt;&lt;br&gt;Meridian Surround System - 825W&lt;br&gt;&lt;br&gt;Sirius XM Satellite Radio and HD Radio&lt;br&gt;&lt;br&gt;Driver Assist Pack&lt;br&gt;&lt;br&gt;Winter Tires&lt;br&gt;&lt;br&gt;Also Included with SVR:&lt;br&gt;- D-Pack&lt;br&gt;- Lozenge-Quilted Leather Performance Seat - Ebony&lt;br&gt;- Indus Silver&lt;br&gt;- Rear Seat Remote Release Levers -- Dealer permit #0112 #3",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5dc368508375315fef522a3f.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "107058"
# 		},
# 		"sku": "J20011",
# 		"itemCondition": "new",
# 		"color": "Silver",
# 		"model": "F-PACE",
# 		"vehicleConfiguration": "SVR | 5.0L V8 Supercharged, 550 hp SVR",
# 		"driveWheelConfiguration": "AWD",
# 		"vehicleTransmission": "8 Spd Automatic",
# 		"disambiguatingDescription": "4dr AWD Sport Utility",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "49",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "V-8",
# 		"vehicleIdentificationNumber": "SADCZ2EE3LA632724",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 33 Photos
#
#
# in stock
# 2020 Jaguar I-PACE
# HSE
# Details
#
# Odometer
# 55 KMS
# Color
# Yulong White
# Drivetrain
# AWD
# Stock #
# J20034
# VIN
# SADHD2S1XL1F87922
#
#
#
# Was $113,715
#
# $109,166*
# You Save $4,549
#
# $113,715 Retail Price
# - $4,549 Dealer Discount/Manufacturer Rebate
# 				= $4,549 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Jaguar I-PACE",
# 		"brand": "Jaguar",
# 		"description": "14-Way Heated and Cooled Electric Memory Performance Front Seats with Heated Rear&lt;br&gt;&lt;br&gt;Yulong White&lt;br&gt;&lt;br&gt;Ebony Suedecloth Headlining&lt;br&gt;&lt;br&gt;Configurable Ambient Interior Lighting&lt;br&gt;&lt;br&gt;Front Fog Lights&lt;br&gt;&lt;br&gt;Illuminated Metal Treadplates with Brand-Name Script&lt;br&gt;&lt;br&gt;Head-Up Display Full Colour (HUD Gen 2)&lt;br&gt;&lt;br&gt;Black Exterior Pack&lt;br&gt;&lt;br&gt;Adaptive Dynamics&lt;br&gt;&lt;br&gt;Cabin Air Ionisation&lt;br&gt;&lt;br&gt;Cold Climate Pack&lt;br&gt;&lt;br&gt;DEFA Battery Charger and Pan Heater -- Dealer permit #0112 #3",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5ec71f6e8a60ef103327b10e.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "109166"
# 		},
# 		"sku": "J20034",
# 		"itemCondition": "new",
# 		"color": "White",
# 		"model": "I-PACE",
# 		"vehicleConfiguration": "HSE HSE",
# 		"driveWheelConfiguration": "AWD",
# 		"vehicleTransmission": "",
# 		"disambiguatingDescription": "4dr AWD Sport Utility",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Electric Fuel System",
# 		"mileageFromOdometer": "55",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "E-0",
# 		"vehicleIdentificationNumber": "SADHD2S1XL1F87922",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 28 Photos
#
#
# in stock
# 2021 Jaguar F-TYPE
# First Edition Santorini Black
# Details
#
# Odometer
# 16 KMS
# Color
# Santorini Black
# Engine
# 3L V-6
# Transmission
# 8 Spd Automatic
# Drivetrain
# AWD
# Stock #
# J21002
# VIN
# SAJD81FV4MCK69367
#
#
#
# Was $114,795
#
# $109,795*
# You Save $5,000
#
# $114,795 Retail Price
# - $5,000 Dealer Discount/Manufacturer Rebate
# 				= $5,000 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Jaguar F-TYPE",
# 		"brand": "Jaguar",
# 		"description": "Santorini Black&lt;br&gt;&lt;br&gt;Configurable Dynamics&lt;br&gt;&lt;br&gt;Powered Tailgate&lt;br&gt;&lt;br&gt;Keyless Entry&lt;br&gt;&lt;br&gt;Fixed Panoramic Roof&lt;br&gt;&lt;br&gt;20&quot; Style 5102, 5 Spoke, Gloss Black Wheels&lt;br&gt;&lt;br&gt;Meridian Surround Sound System&lt;br&gt;&lt;br&gt;Garage Door Opener (HomeLink)&lt;br&gt;&lt;br&gt;Blind Spot Assist&lt;br&gt;&lt;br&gt;Climate Pack&lt;br&gt;&lt;br&gt;DEFA Battery Charger and Pan Heater&lt;br&gt;&lt;br&gt;Also Included with First Edition:&lt;br&gt;- D-Pack Options&lt;br&gt;- Ebony Premium Windsor Leather Performance Seats -- Dealer permit #0112 #3",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5eec0993bc303f65a2d2ca92.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "109795"
# 		},
# 		"sku": "J21002",
# 		"itemCondition": "new",
# 		"color": "Black",
# 		"model": "F-TYPE",
# 		"vehicleConfiguration": "First Edition Santorini Black First Edition Santorini Black",
# 		"driveWheelConfiguration": "AWD",
# 		"vehicleTransmission": "8 Spd Automatic",
# 		"disambiguatingDescription": "2dr AWD Coupe",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "16",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "V-6",
# 		"vehicleIdentificationNumber": "SAJD81FV4MCK69367",
# 		"vehicleSeatingCapacity": ""
# }
#
#
#
# 1

# %%
#Finding the titles of cars using find_all
#All the titles are present in h4 itemprop : name
car_titles = []
a=soup.findAll('h4',{"itemprop":"name"})
for i in a :
    print(i.text)
    car_titles.append(i.text)#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# 2020 Jaguar XE
# 2020 Jaguar F-PACE
# 2020 Jaguar F-PACE
# 2020 Jaguar F-PACE
# 2020 Jaguar F-PACE
# 2020 Jaguar F-PACE
# 2020 Jaguar F-PACE
# 2020 Jaguar F-PACE
# 2020 Jaguar I-PACE
# 2020 Jaguar F-PACE
# 2020 Jaguar I-PACE
# 2021 Jaguar F-TYPE
# ['2020 Jaguar XE', '2020 Jaguar F-PACE', '2020 Jaguar F-PACE', '2020 Jaguar F-PACE', '2020 Jaguar F-PACE', '2020 Jaguar F-PACE', '2020 Jaguar F-PACE', '2020 Jaguar F-PACE', '2020 Jaguar I-PACE', '2020 Jaguar F-PACE', '2020 Jaguar I-PACE', '2021 Jaguar F-TYPE']
# 12

# %%
#Finding the price of cars using find_all
#All the priceare present in strong class : price _bpcolor
car_price = []
a=soup.findAll('strong',{"class":"price _bpcolor"})
for i in a :
    print(i.text)
    car_price.append(i.text.strip())#appending values
print(car_price)#printing price
len(car_price)#printing length of list
# Out:
# $53,975*
#
# $74,570
#
# $74,593*
#
# $82,993*
#
# $86,048*
#
# $93,215
#
# $103,630*
#
# $104,040*
#
# $104,125*
#
# $107,058*
#
# $109,166*
#
# $109,795*
# ['$53,975*', '$74,570', '$74,593*', '$82,993*', '$86,048*', '$93,215', '$103,630*', '$104,040*', '$104,125*', '$107,058*', '$109,166*', '$109,795*']
# 12

# %%
mileage = []#taking empty list
a = soup.findAll('dd',{"class":"srp-odometer"})#scrapping mileage
for i in a:
    print(i.text)
    mileage.append(i.text)#appending in a list
print(mileage)#printing list
# Out:
# 42 KMS
# 2 KMS
# 3,406 KMS
# 3,712 KMS
# 1,032 KMS
# 2 KMS
# 19 KMS
# 19 KMS
# 4,622 KMS
# 49 KMS
# 55 KMS
# 16 KMS
# ['42 KMS', '2 KMS', '3,406 KMS', '3,712 KMS', '1,032 KMS', '2 KMS', '19 KMS', '19 KMS', '4,622 KMS', '49 KMS', '55 KMS', '16 KMS']

# %%
exterior = []#taking empty list
a = soup.findAll('dd',{"class":"srp-color-exterior"})#scrapping exterior
for i in a:
    print(i.text)
    exterior.append(i.text)#appending in a list
print(exterior)#printing list
# Out:
# Fuji White
# Fuji White
# Santorini Black
# Narvik Black
# Santorini Black
# Fuji White
# Ultra Blue
# Fuji White
# Fuji White
# Indus Silver Metallic
# Yulong White
# Santorini Black
# ['Fuji White', 'Fuji White', 'Santorini Black', 'Narvik Black', 'Santorini Black', 'Fuji White', 'Ultra Blue', 'Fuji White', 'Fuji White', 'Indus Silver Metallic', 'Yulong White', 'Santorini Black']

# %%
engine = []#taking empty list
a = soup.findAll('dd',{"class":"srp-engine-combined"}) #scrapping engine
for i in a:
    print(i.text)
    engine.append(i.text)#appending in a list
print(engine)#printing list
# Out:
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 3L V-6
# 5L V-8
# 5L V-8
# 5L V-8
# 3L V-6
# ['2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '3L V-6', '5L V-8', '5L V-8', '5L V-8', '3L V-6']

# %%
transmission = []#taking empty list
a = soup.findAll('dd',{"class":"srp-transmission"})#scrappping transmission
for i in a:
    print(i.text)
    transmission.append(i.text)#appending in a list
print(transmission)#printing list
# Out:
# 8 Spd Automatic
# 8 Spd Automatic
# 8 Spd Automatic
# 8 Spd Automatic
# 8 Spd Automatic
# 8 Spd Automatic
# 8 Spd Automatic
# 8 Spd Automatic
# 8 Spd Automatic
# 8 Spd Automatic
# ['8 Spd Automatic', '8 Spd Automatic', '8 Spd Automatic', '8 Spd Automatic', '8 Spd Automatic', '8 Spd Automatic', '8 Spd Automatic', '8 Spd Automatic', '8 Spd Automatic', '8 Spd Automatic']

# %%
drive_train = []#taking empty list
a = soup.findAll('dd',{"class":"srp-driveType"})#scrapping drive_Train
for i in a:
    print(i.text)
    drive_train.append(i.text)#appending in a list
print(drive_train)#printing list
# Out:
# AWD
# AWD
# AWD
# AWD
# AWD
# AWD
# AWD
# AWD
# AWD
# AWD
# AWD
# AWD
# ['AWD', 'AWD', 'AWD', 'AWD', 'AWD', 'AWD', 'AWD', 'AWD', 'AWD', 'AWD', 'AWD', 'AWD']

# %%
stock = []#taking empty list
a = soup.findAll('dd',{"class":"srp-stock-number"})#wscrapping stock
for i in a:
    print(i.text)
    stock.append(i.text)#appending in a list
print(stock)#printing list
# Out:
# J20018
# J20041
# J20037
# J20036
# J20027
# J20039
# J20023
# J20024
# J20021
# J20011
# J20034
# J21002
# ['J20018', 'J20041', 'J20037', 'J20036', 'J20027', 'J20039', 'J20023', 'J20024', 'J20021', 'J20011', 'J20034', 'J21002']

# %%
vin = []#taking empty list
a = soup.findAll('dd',{"class":"srp-vin"}) #scrapping vin
for i in a:
    print(i.text)
    vin.append(i.text)#appending in a list
print(vin)#printing list
# Out:
# SAJAP4FX4LCP61355
# SADCL2FX5LA660803
# SADCL2FX6LA644061
# SADCL2GX5LA632028
# SADCX2GX2LA642732
# SADCM2FV1LA658848
# SADCZ2EE5LA639643
# SADCZ2EE5LA639531
# SADHC2S14L1F87157
# SADCZ2EE3LA632724
# SADHD2S1XL1F87922
# SAJD81FV4MCK69367
# ['SAJAP4FX4LCP61355', 'SADCL2FX5LA660803', 'SADCL2FX6LA644061', 'SADCL2GX5LA632028', 'SADCX2GX2LA642732', 'SADCM2FV1LA658848', 'SADCZ2EE5LA639643', 'SADCZ2EE5LA639531', 'SADHC2S14L1F87157', 'SADCZ2EE3LA632724', 'SADHD2S1XL1F87922', 'SAJD81FV4MCK69367']

# %%
#creating a dict of scrapped data
dict = {
        'Title' : car_titles ,
        'Mileage':mileage,
        'Exterior':exterior,
        'Transmission':transmission,
        'Engine':engine,
        'Drive Train':drive_train,
        'Stock':stock,
        'VIN':vin,
        'Price':car_price
}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                  Title    Mileage               Exterior     Transmission  \
# 0       2020 Jaguar XE     42 KMS             Fuji White  8 Spd Automatic
# 1   2020 Jaguar F-PACE      2 KMS             Fuji White  8 Spd Automatic
# 2   2020 Jaguar F-PACE  3,406 KMS        Santorini Black  8 Spd Automatic
# 3   2020 Jaguar F-PACE  3,712 KMS           Narvik Black  8 Spd Automatic
# 4   2020 Jaguar F-PACE  1,032 KMS        Santorini Black  8 Spd Automatic
# 5   2020 Jaguar F-PACE      2 KMS             Fuji White  8 Spd Automatic
# 6   2020 Jaguar F-PACE     19 KMS             Ultra Blue  8 Spd Automatic
# 7   2020 Jaguar F-PACE     19 KMS             Fuji White  8 Spd Automatic
# 8   2020 Jaguar I-PACE  4,622 KMS             Fuji White  8 Spd Automatic
# 9   2020 Jaguar F-PACE     49 KMS  Indus Silver Metallic  8 Spd Automatic
# 10  2020 Jaguar I-PACE     55 KMS           Yulong White             None
# 11  2021 Jaguar F-TYPE     16 KMS        Santorini Black             None
#
#     Engine Drive Train   Stock                VIN      Price
# 0   2L I-4         AWD  J20018  SAJAP4FX4LCP61355   $53,975*
# 1   2L I-4         AWD  J20041  SADCL2FX5LA660803    $74,570
# 2   2L I-4         AWD  J20037  SADCL2FX6LA644061   $74,593*
# 3   2L I-4         AWD  J20036  SADCL2GX5LA632028   $82,993*
# 4   2L I-4         AWD  J20027  SADCX2GX2LA642732   $86,048*
# 5   3L V-6         AWD  J20039  SADCM2FV1LA658848    $93,215
# 6   5L V-8         AWD  J20023  SADCZ2EE5LA639643  $103,630*
# 7   5L V-8         AWD  J20024  SADCZ2EE5LA639531  $104,040*
# 8   5L V-8         AWD  J20021  SADHC2S14L1F87157  $104,125*
# 9   3L V-6         AWD  J20011  SADCZ2EE3LA632724  $107,058*
# 10    None         AWD  J20034  SADHD2S1XL1F87922  $109,166*
# 11    None         AWD  J21002  SAJD81FV4MCK69367  $109,795*

# %%
df['Dealer'] = 'winnipegjaguar'
df['Condition'] = 'New'

# %%
split_title = df["Title"].str.split(" ", n = 2, expand = True) 
# splitting Tile column 
df["Make Year"]= split_title[0] 
df["Make"]= split_title[1] 
df["Model"]= split_title[2] 
df
# Out:
#                  Title    Mileage               Exterior     Transmission  \
# 0       2020 Jaguar XE     42 KMS             Fuji White  8 Spd Automatic
# 1   2020 Jaguar F-PACE      2 KMS             Fuji White  8 Spd Automatic
# 2   2020 Jaguar F-PACE  3,406 KMS        Santorini Black  8 Spd Automatic
# 3   2020 Jaguar F-PACE  3,712 KMS           Narvik Black  8 Spd Automatic
# 4   2020 Jaguar F-PACE  1,032 KMS        Santorini Black  8 Spd Automatic
# 5   2020 Jaguar F-PACE      2 KMS             Fuji White  8 Spd Automatic
# 6   2020 Jaguar F-PACE     19 KMS             Ultra Blue  8 Spd Automatic
# 7   2020 Jaguar F-PACE     19 KMS             Fuji White  8 Spd Automatic
# 8   2020 Jaguar I-PACE  4,622 KMS             Fuji White  8 Spd Automatic
# 9   2020 Jaguar F-PACE     49 KMS  Indus Silver Metallic  8 Spd Automatic
# 10  2020 Jaguar I-PACE     55 KMS           Yulong White             None
# 11  2021 Jaguar F-TYPE     16 KMS        Santorini Black             None
#
#     Engine Drive Train   Stock                VIN      Price          Dealer  \
# 0   2L I-4         AWD  J20018  SAJAP4FX4LCP61355   $53,975*  winnipegjaguar
# 1   2L I-4         AWD  J20041  SADCL2FX5LA660803    $74,570  winnipegjaguar
# 2   2L I-4         AWD  J20037  SADCL2FX6LA644061   $74,593*  winnipegjaguar
# 3   2L I-4         AWD  J20036  SADCL2GX5LA632028   $82,993*  winnipegjaguar
# 4   2L I-4         AWD  J20027  SADCX2GX2LA642732   $86,048*  winnipegjaguar
# 5   3L V-6         AWD  J20039  SADCM2FV1LA658848    $93,215  winnipegjaguar
# 6   5L V-8         AWD  J20023  SADCZ2EE5LA639643  $103,630*  winnipegjaguar
# 7   5L V-8         AWD  J20024  SADCZ2EE5LA639531  $104,040*  winnipegjaguar
# 8   5L V-8         AWD  J20021  SADHC2S14L1F87157  $104,125*  winnipegjaguar
# 9   3L V-6         AWD  J20011  SADCZ2EE3LA632724  $107,058*  winnipegjaguar
# 10    None         AWD  J20034  SADHD2S1XL1F87922  $109,166*  winnipegjaguar
# 11    None         AWD  J21002  SAJD81FV4MCK69367  $109,795*  winnipegjaguar
#
#    Condition Make Year    Make   Model
# 0        New      2020  Jaguar      XE
# 1        New      2020  Jaguar  F-PACE
# 2        New      2020  Jaguar  F-PACE
# 3        New      2020  Jaguar  F-PACE
# 4        New      2020  Jaguar  F-PACE
# 5        New      2020  Jaguar  F-PACE
# 6        New      2020  Jaguar  F-PACE
# 7        New      2020  Jaguar  F-PACE
# 8        New      2020  Jaguar  I-PACE
# 9        New      2020  Jaguar  F-PACE
# 10       New      2020  Jaguar  I-PACE
# 11       New      2021  Jaguar  F-TYPE

# %%
df.drop(columns =["Title"], inplace = True)
df
# Out:
#       Mileage               Exterior     Transmission  Engine Drive Train  \
# 0      42 KMS             Fuji White  8 Spd Automatic  2L I-4         AWD
# 1       2 KMS             Fuji White  8 Spd Automatic  2L I-4         AWD
# 2   3,406 KMS        Santorini Black  8 Spd Automatic  2L I-4         AWD
# 3   3,712 KMS           Narvik Black  8 Spd Automatic  2L I-4         AWD
# 4   1,032 KMS        Santorini Black  8 Spd Automatic  2L I-4         AWD
# 5       2 KMS             Fuji White  8 Spd Automatic  3L V-6         AWD
# 6      19 KMS             Ultra Blue  8 Spd Automatic  5L V-8         AWD
# 7      19 KMS             Fuji White  8 Spd Automatic  5L V-8         AWD
# 8   4,622 KMS             Fuji White  8 Spd Automatic  5L V-8         AWD
# 9      49 KMS  Indus Silver Metallic  8 Spd Automatic  3L V-6         AWD
# 10     55 KMS           Yulong White             None    None         AWD
# 11     16 KMS        Santorini Black             None    None         AWD
#
#      Stock                VIN      Price          Dealer Condition Make Year  \
# 0   J20018  SAJAP4FX4LCP61355   $53,975*  winnipegjaguar       New      2020
# 1   J20041  SADCL2FX5LA660803    $74,570  winnipegjaguar       New      2020
# 2   J20037  SADCL2FX6LA644061   $74,593*  winnipegjaguar       New      2020
# 3   J20036  SADCL2GX5LA632028   $82,993*  winnipegjaguar       New      2020
# 4   J20027  SADCX2GX2LA642732   $86,048*  winnipegjaguar       New      2020
# 5   J20039  SADCM2FV1LA658848    $93,215  winnipegjaguar       New      2020
# 6   J20023  SADCZ2EE5LA639643  $103,630*  winnipegjaguar       New      2020
# 7   J20024  SADCZ2EE5LA639531  $104,040*  winnipegjaguar       New      2020
# 8   J20021  SADHC2S14L1F87157  $104,125*  winnipegjaguar       New      2020
# 9   J20011  SADCZ2EE3LA632724  $107,058*  winnipegjaguar       New      2020
# 10  J20034  SADHD2S1XL1F87922  $109,166*  winnipegjaguar       New      2020
# 11  J21002  SAJD81FV4MCK69367  $109,795*  winnipegjaguar       New      2021
#
#       Make   Model
# 0   Jaguar      XE
# 1   Jaguar  F-PACE
# 2   Jaguar  F-PACE
# 3   Jaguar  F-PACE
# 4   Jaguar  F-PACE
# 5   Jaguar  F-PACE
# 6   Jaguar  F-PACE
# 7   Jaguar  F-PACE
# 8   Jaguar  I-PACE
# 9   Jaguar  F-PACE
# 10  Jaguar  I-PACE
# 11  Jaguar  F-TYPE

# %%
#Dataframe to csv
df.to_csv('winnipegjaguar.csv')
