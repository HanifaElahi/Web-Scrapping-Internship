# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = input(("Enter url : "))
# "https://www.capitalfordwinnipeg.ca/new-vehicles/?_paymentType=our_price"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class vehicle-cards
data = soup.findAll('div',{"class":"vehicle-cards"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
# Special OfferUsed 2015Lincoln MKZ 4DR SDN FWD *LED Headlights *Navigation *Leather Seats 4 Door SedanStock: P2948B DetailsGreatest Auto Sale$15,999Exterior: WhiteOdometer: 125,000Key Features:
#
#
#
#
#
#
#  📆 AT HOME TEST DRIVE ✔︎
#  Show Payment OptionsShow PaymentsAdded to GarageAdd to GarageSpecial OfferUsed 2018Ford Escape SE 4WD *Bluetooth *Back-up Camera SUVStock: U0972A DetailsMarket Value$22,154Capital Discount$2,866Greatest Auto Sale$19,288Exterior: SilverOdometer: 83,082Key Features:
#
#
#
#
#
#
#
#  📆 AT HOME TEST DRIVE ✔︎
#  Show Payment OptionsShow PaymentsAdded to GarageAdd to GarageSpecial OfferUsed 2015Lincoln MKC 4DR AWD *Navigation *Leather Seats *Memory Seat SUVStock: P2710A DetailsGreatest Auto Sale$19,888Exterior: RedOdometer: 106,825Key Features:
#
#
#
#
#
#
#  📆 AT HOME TEST DRIVE ✔︎
# ...

# %%
#Finding the make years of cars using find_all
#All the make years are present in h2 class : result-title
a = soup.find_all("h2",{"class" :"result-title"})
#taking an empty list
car_makeyear = []
#printing all the separate make years using for loop
for i in a:
    my = i.find('span',{"class":"title-top"}).text #digging down for make years
    print(my)# printing values
    #appending values in a separate empty list
    car_makeyear.append(my)  
print(car_makeyear)#printing car make years list
len(car_makeyear)#length of car make years list
# Out:
# Used 2015
# Used 2018
# Used 2015
# Used 2015
# Used 2019
# Used 2018
# Used 2014
# Used 2017
# New 2020
# Used 2019
# Used 2019
# Used 2015
# Used 2015
# Used 2015
# Used 2014
# Used 2017
# Used 2015
# Used 2017
# Used 2014
# Used 2014
# ['Used 2015', 'Used 2018', 'Used 2015', 'Used 2015', 'Used 2019', 'Used 2018', 'Used 2014', 'Used 2017', 'New 2020', 'Used 2019', 'Used 2019', 'Used 2015', 'Used 2015', 'Used 2015', 'Used 2014', 'Used 2017', 'Used 2015', 'Used 2017', 'Used 2014', 'Used 2014']
# 20

# %%
#Finding the titles of cars using find_all
#All the titles are present in h2 class : result-title
a = soup.find_all("h2",{"class" :"result-title"})
#taking an empty list
car_title = []
#printing all the separate titles using for loop
for i in a:
    title = i.find('span',{"class":"title-bottom"}).text #digging down for titles
    print(title)# printing values
    #appending values in a separate empty list
    car_title.append(title)  
print(car_title)#printing car titles list
len(car_title)#length of car titles list
# Out:
# Lincoln MKZ 4DR SDN FWD *LED Headlights *Navigation *Leather Seats 4 Door Sedan
# Ford Escape SE 4WD *Bluetooth *Back-up Camera SUV
# Lincoln MKC 4DR AWD *Navigation *Leather Seats *Memory Seat SUV
# Ford Escape Titanium 4WD *Ask about 1.9%! SUV
# Chevrolet Malibu LT*Heated Seats *Apple CarPlay *Alloy Wheels 4 Door Sedan
# Chevrolet Traverse LS *LED Headlights *Alloy Wheels *Backup Camera SUV
# Ford F-150 XLT SuperCrew EcoBoost™ *Bluetooth *Alloy 19 Machined Aluminum SuperCrew Pickup
# Lincoln MKZ Reserve AWD *No Accidents *Low KM *A/C Seats 4 Door Sedan
# Ford EcoSport SE*Apple Car Play *Heated Seats *Sunroof Sport Utility
# Ford Escape Titanium 4WD *Available at 1.9% SUV
# Toyota Highlander LE AWD *3rd Row Seating *Back Up Camera *Bluetooth SUV
# Ford Escape SE *Heated Seats *Backup Camera *Bluetooth SUV
# Ford Fusion SE *Heated Leather Seats *Sunroof *Navigation 4 Door Sedan
# Ford Escape SE 4WD *Heated Seats *Alloy Wheels *Bluetooth SUV
# ...

# %%
#Finding the stocks of cars using find_all
#All the stocks are present in div class : hit-content-title-wrap
b = soup.find_all("div",{"class" :"hit-content-title-wrap"})
#taking an empty list
car_stocks = []
#printing all the separate stocks using for loop
for i in b:
    stocks = i.find('div',{"class":"stock-row"}).text #digging down for stocks
    print(stocks)# printing values
    #appending values in a separate empty list
    car_stocks.append(stocks.replace("Stock:",""))  
print(car_stocks)#printing car stocks list
len(car_stocks)#length of car stocks list
# Out:
# Stock: P2948B
# Stock: U0972A
# Stock: P2710A
# Stock: L0382A
# Stock: P2971A
# Stock: P3058A
# Stock: P3235A
# Stock: L0390A
# Stock: P2899
# Stock: U1037A
# Stock: U1058A
# Stock: U1088A
# Stock: P3344A
# Stock: U0956B
# Stock: P3228A
# Stock: U0994B
# Stock: P3243A
# Stock: P3325A
# Stock: U1045B
# Stock: P3011B
# [' P2948B', ' U0972A', ' P2710A', ' L0382A', ' P2971A', ' P3058A', ' P3235A', ' L0390A', ' P2899', ' U1037A', ' U1058A', ' U1088A', ' P3344A', ' U0956B', ' P3228A', ' U0994B', ' P3243A', ' P3325A', ' U1045B', ' P3011B']
# 20

# %%
#Finding the msrp of cars using find_all
#All the msrp are present in div class : hit-price hit-price--extra
c = soup.find_all("div",{"class" :"hit-price hit-price--extra"})
#taking an empty list
msrp = []
#printing all the separate msrp using for loop
for i in c:
    mv = i.find('div',{"class":"hit-price__value"}).text #diggig down for msrp
    print(mv)# printing values
    #appending values in a separate empty list
    msrp.append(mv)  
print(msrp)#printing car msrp list
len(msrp)#length of car msrp list
# Out:
# $22,154
# $23,387
# $24,727
# $26,216
# $31,101
# $31,899
# $33,342
# $36,282
# $15,461
# $16,888
# $16,848
# $19,543
# $18,846
# $18,887
# $19,464
# $19,999
# ['$22,154', '$23,387', '$24,727', '$26,216', '$31,101', '$31,899', '$33,342', '$36,282', '$15,461', '$16,888', '$16,848', '$19,543', '$18,846', '$18,887', '$19,464', '$19,999']
# 16

# %%
#Finding the discount on  cars using find_all
#All the discount value are present in div class : hit-price hit-price--savings
d = soup.find_all("div",{"class" :"hit-price hit-price--savings"})
#taking an empty list
c_discount = []
#printing all the separate discount using for loop
for i in d:
    dis = i.find('div',{"class":"hit-price__value"}).text #diggig down for discount
    print(dis)# printing values
    #appending values in a separate empty list
    c_discount.append(dis)  
print(c_discount)#printing car discount list
len(c_discount)#length of car discount list
# Out:
# $2,866
# $2,499
# $3,505
# $616
# $4,111
# $1,175
# $2,342
# $2,383
# $1,261
# $1,888
# $548
# $2,723
# $1,846
# $1,487
# $1,564
# $1,711
# ['$2,866', '$2,499', '$3,505', '$616', '$4,111', '$1,175', '$2,342', '$2,383', '$1,261', '$1,888', '$548', '$2,723', '$1,846', '$1,487', '$1,564', '$1,711']
# 16

# %%
#Finding the final price of cars using find_all
#All the final price value are present in div class : hit-price hit-price--primary
d = soup.find_all("div",{"class" :"hit-price hit-price--primary"})
#taking an empty list
car_price = []
#printing all the separate final price using for loop
for i in d:
    price = i.find('div',{"class":"hit-price__value"}).text #diggig down for final price
    print(price)# printing values
    #appending values in a separate empty list
    car_price .append(price)  
print(car_price )#printing car final price list
len(car_price )#length of car final price list
# Out:
# $15,999
# $19,288
# $19,888
# $20,888
# $21,222
# $25,600
# $26,990
# $28,888
# $30,724
# $31,000
# $33,899
# $14,200
# $14,887
# $15,000
# $16,300
# $16,820
# $17,000
# $17,400
# $17,900
# $18,288
# ['$15,999', '$19,288', '$19,888', '$20,888', '$21,222', '$25,600', '$26,990', '$28,888', '$30,724', '$31,000', '$33,899', '$14,200', '$14,887', '$15,000', '$16,300', '$16,820', '$17,000', '$17,400', '$17,900', '$18,288']
# 20

# %%
#All the exterior are present in li class : vehicle-details--item vehicle-details--item-color exterior
b = soup.findAll("li",{"class" :"vehicle-details--item vehicle-details--item-color exterior"})
#taking an empty list
car_exterior = []
#printing all the separate exterior using for loop
for i in b:
    print(i.text)# printing values
    #appending values in a separate empty list
    car_exterior.append(i.text.replace("Exterior: ","").strip())  
print(car_exterior)#printing car exterior list
len(car_exterior)#length of car exterior list
# Out:
# Exterior: White
# Exterior: Silver
# Exterior: Red
# Exterior: White
# Exterior: BLACK
# Exterior: BLACK
# Exterior: Blue
# Exterior: Silver
# Exterior: Shadow Black
# Exterior: Blue
# Exterior: BLACK
# Exterior: Gray
# Exterior: Red
# Exterior: WHITE METALLIC
# Exterior: BLACK
# Exterior: Billet Metallic
# Exterior: Blue
# Exterior: BLACK
# Exterior: BLACK
# ['White', 'Silver', 'Red', 'White', 'BLACK', 'BLACK', 'Blue', 'Silver', 'Shadow Black', 'Blue', 'BLACK', 'Gray', 'Red', 'WHITE METALLIC', 'BLACK', 'Billet Metallic', 'Blue', 'BLACK', 'BLACK']
# 19

# %%
#All the mileage are present in li class : vehicle-details--item mileage
b = soup.findAll("li",{"class" :"vehicle-details--item mileage"})
#taking an empty list
car_mileage = []

for i in b:
    print(i.text)
    car_mileage.append(i.text.replace("Odometer:",""))  
print(car_mileage)#printing car mileage list
len(car_mileage)#length of car mileage list
# Out:
# Odometer: 125,000
# Odometer: 83,082
# Odometer: 106,825
# Odometer: 59,250
# Odometer: 45,480
# Odometer: 83,803
# Odometer: 100,610
# Odometer: 47,200
# Odometer: 14,403
# Odometer: 57,705
# Odometer: 136,776
# Odometer: 89,283
# Odometer: 138,038
# Odometer: 101,738
# Odometer: 111,339
# Odometer: 119,340
# Odometer: 67,732
# Odometer: 100,400
# Odometer: 80,054
# [' 125,000', ' 83,082', ' 106,825', ' 59,250', ' 45,480', ' 83,803', ' 100,610', ' 47,200', ' 14,403', ' 57,705', ' 136,776', ' 89,283', ' 138,038', ' 101,738', ' 111,339', ' 119,340', ' 67,732', ' 100,400', ' 80,054']
# 19

# %%
#creating dict of scrapped data
dict = {
    'Title' : car_title ,
    'Make Year' : car_makeyear,
    'Stock' : car_stocks,
    'Mileage' : car_mileage , 
    'MSRP':msrp,
    'Discount' : c_discount ,  
    'Price ': car_price,
    'Exterior' : car_exterior,
}

# %%
#creating dataframe from dict
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                                                 Title  Make Year    Stock  \
# 0   Lincoln MKZ 4DR SDN FWD *LED Headlights *Navig...  Used 2015   P2948B
# 1   Ford Escape SE 4WD *Bluetooth *Back-up Camera SUV  Used 2018   U0972A
# 2   Lincoln MKC 4DR AWD *Navigation *Leather Seats...  Used 2015   P2710A
# 3       Ford Escape Titanium 4WD *Ask about 1.9%! SUV  Used 2015   L0382A
# 4   Chevrolet Malibu LT*Heated Seats *Apple CarPla...  Used 2019   P2971A
# 5   Chevrolet Traverse LS *LED Headlights *Alloy W...  Used 2018   P3058A
# 6   Ford F-150 XLT SuperCrew EcoBoost™ *Bluetooth ...  Used 2014   P3235A
# 7   Lincoln MKZ Reserve AWD *No Accidents *Low KM ...  Used 2017   L0390A
# 8   Ford EcoSport SE*Apple Car Play *Heated Seats ...   New 2020    P2899
# 9     Ford Escape Titanium 4WD *Available at 1.9% SUV  Used 2019   U1037A
# 10  Toyota Highlander LE AWD *3rd Row Seating *Bac...  Used 2019   U1058A
# 11  Ford Escape SE *Heated Seats *Backup Camera *B...  Used 2015   U1088A
# ...

# %%
#Dataframe to csv
df.to_csv('capitalfordwinnipeg.csv')
