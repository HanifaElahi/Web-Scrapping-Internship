# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = input(("Enter url : "))
# "https://www.stcharlesmotors.ca/used/"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class col-xs-12 col-sm-12 col-md-12
data=soup.findAll('div',{"class":"col-xs-12 col-sm-12 col-md-12"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2015-chevrolet-equinox-1lt-id9466257.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/72942484.jpeg","thumbnailUrl":"https://images.edealer.ca/4/72942484.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/72942485.jpeg","thumbnailUrl":"https://images.edealer.ca/4/72942485.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/72942486.jpeg","thumbnailUrl":"https://images.edealer.ca/4/72942486.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/72942487.jpeg","thumbnailUrl":"https://images.edealer.ca/4/72942487.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/72942488.jpeg","thumbnailUrl":"https://images.edealer.ca/4/72942488.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/72942489.jpeg","thumbnailUrl":"https://images.edealer.ca/4/72942489.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/72942490.jpeg","thumbnailUrl":"https://images.edealer.ca/4/72942490.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/72942491.jpeg","thumbnailUrl":"https://images.edealer.ca/4/72942491.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/72942492.jpeg","thumbnailUrl":"https://images.edealer.ca/4/72942492.jpeg"}]}
#                     jQuery("#carousel-example-generic-9466257").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# 2015 Chevrolet Equinox 1LTLike New. Great looking. Price: $11,995Mileage:175,476 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SUVEngine:2.4L 4cylExterior Colour:Black
#
#
#
#
# Transmission:AutomaticDrivetrain:Front Wheel DriveStock #:N/ACity:Winnipeg
#
# Brand new safety.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2015-honda-accord-sport-id10203836.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/79792840.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79792840.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79792852.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79792852.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79792863.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79792863.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79792888.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79792888.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79792904.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79792904.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79792912.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79792912.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79792922.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79792922.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79792940.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79792940.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79792946.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79792946.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79793040.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79793040.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79793051.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79793051.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79793077.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79793077.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79793100.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79793100.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79793125.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79793125.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79793132.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79793132.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79793142.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79793142.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79793176.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79793176.jpeg"}]}
#                     jQuery("#carousel-example-generic-10203836").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# 2015 Honda Accord SportBrand new safety. Manitoba vehiclePrice: $14,499Mileage:139,621 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SedanEngine:2.4L 4cylExterior Colour:Dark Grey
#
#
#
#
# Transmission:AutomaticDrivetrain:Front Wheel DriveStock #:N/ACity:Winnipeg
#
# Great condition.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2015-honda-civic-ex-id10172893.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/79106282.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106282.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106293.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106293.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106300.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106300.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106305.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106305.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106314.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106314.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106321.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106321.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106339.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106339.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106363.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106363.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106375.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106375.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106418.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106418.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106419.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106419.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106420.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106420.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106537.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106537.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106547.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106547.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106571.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106571.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106591.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106591.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106593.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106593.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/79106614.jpeg","thumbnailUrl":"https://images.edealer.ca/4/79106614.jpeg"}]}
#                     jQuery("#carousel-example-generic-10172893").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# 2015 Honda Civic EXBrand new safety Manitoba vehiclePrice: $12,995Mileage:146,840 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SedanEngine:1.8L 4cylExterior Colour:Dark Grey
#
#
#
#
# Transmission:AutomaticDrivetrain:Front Wheel DriveStock #:N/ACity:Winnipeg
#
# New good year tires and top of the line Honda wheels. Great condition.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/
jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83273890.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83273890.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83273904.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83273904.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83273921.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83273921.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83273923.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83273923.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83273925.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83273925.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83273928.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83273928.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83273931.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83273931.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83273936.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83273936.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83273947.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83273947.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83273997.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83273997.jpeg"}]}
#                     jQuery("#carousel-example-generic-10374537").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# 2012 Ford Escape LimitedManitoba vehicle. Brand new safetyPrice: $10,995Mileage:141,459 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SUVEngine:2.5L 4cylExterior Colour:Beige
#
#
#
#
# Transmission:AutomaticDrivetrain:4x4Stock #:N/ACity:Winnipeg
#
# Loaded limited model. Leather upholstery.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2011-cadillac-cts-base-id10321834.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/82255521.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255521.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255534.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255534.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255540.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255540.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255547.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255547.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255555.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255555.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255566.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255566.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255572.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255572.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255573.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255573.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255576.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255576.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255578.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255578.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255585.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255585.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255588.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255588.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255612.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255612.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255614.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255614.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255617.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255617.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255619.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255619.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255621.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255621.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255632.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255632.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/82255643.jpeg","thumbnailUrl":"https://images.edealer.ca/4/82255643.jpeg"}]}
#                     jQuery("#carousel-example-generic-10321834").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# 2011 Cadillac CTSNew safety. Manitoba carPrice: $13,995Mileage:165,353 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SedanEngine:3.6L 6cylExterior Colour:Black
#
#
#
#
# Transmission:AutomaticDrivetrain:All Wheel DriveStock #:-City:Winnipeg
#
# Pure luxury. All wheel drive.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2010-dodge-grand-caravan-se-id10406071.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/83959989.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83959989.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83959993.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83959993.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960015.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960015.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960019.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960019.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960022.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960022.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960028.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960028.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960031.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960031.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960035.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960035.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960039.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960039.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960051.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960051.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960062.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960062.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960070.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960070.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960123.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960123.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960131.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960131.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960148.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960148.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960162.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960162.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83960203.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83960203.jpeg"}]}
#                     jQuery("#carousel-example-generic-10406071").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# 2010 Dodge Grand Caravan SEAccident free! Manitoba vehiclePrice: $7,995Mileage:157,330 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:VansEngine:3.3L 6cylExterior Colour:Grey
#
#
#
#
# Transmission:AutomaticDrivetrain:Front Wheel DriveStock #:N/ACity:Winnipeg
#
# Brand new safety. 7 passenger van.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}

# %%
#Finding the titles of cars using find_all
#All the titles are present in p class : vehicle-year-make-model
car_titles = []
a=soup.findAll('p',{"class":"vehicle-year-make-model"})
for i in a :
    print(i.text)#printing titles
    car_titles.append(i.text)#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# 2015 Chevrolet Equinox 1LT
# 2015 Honda Accord Sport
# 2015 Honda Civic EX
# 2014 Chevrolet Cruze 2LT
# 2014 Ford Escape SE
# 2012 Dodge Grand Caravan SE/SXT
# 2012 Ford Escape Limited
# 2011 Cadillac CTS
# 2010 Dodge Grand Caravan SE
# ['2015 Chevrolet Equinox 1LT', '2015 Honda Accord Sport', '2015 Honda Civic EX', '2014 Chevrolet Cruze 2LT', '2014 Ford Escape SE', '2012 Dodge Grand Caravan SE/SXT', '2012 Ford Escape Limited', '2011 Cadillac CTS', '2010 Dodge Grand Caravan SE']
# 9

# %%
body_style = []
exterior = []
transmission = []
stock = []
# taking empty lists

spec= soup.findAll('table',{"class":"table"}) #all the details are inside table class

for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('tr',{"class":"tr-even"})#finding all tr with tr-even class
    for li in lis:
        if 'Body Style' in li.text: #if present
            body_style.append(li.text.replace("Body Style:",""))#then append
        if 'Stock #' in li.text:#if present
            stock.append(li.text.replace("Stock #:",""))#then append
        if 'Transmission' in li.text:#if present
            transmission.append(li.text.replace("Transmission:",""))#then append
        if 'Exterior Colour' in li.text: #if present
            exterior.append(li.text.replace("Exterior Colour:",""))#then append
        
        
#printing individual lists        
print(body_style)
print(stock)
print(exterior)
print(transmission)
# Out:
# ['SUV', 'Sedan', 'Sedan', 'Sedan', 'SUV', 'Vans', 'SUV', 'Sedan', 'Vans']
# ['N/A', 'N/A', 'N/A', 'N/A', '-', '-', 'N/A', '-', 'N/A']
# ['Black', 'Dark Grey', 'Dark Grey', 'Black', 'Blue', 'White', 'Beige', 'Black', 'Grey']
# ['Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic']

# %%
engine = []
drive_train = []
location = []

# taking empty lists

spec= soup.findAll('table',{"class":"table"})#all the details are inside table class

for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('tr',{"class":"tr-odd"})#finding all tr-odd class
    for li in lis:
        if 'Engine' in li.text: #if present
            engine.append(li.text.replace("Engine:",""))#then append
        if 'Drivetrain' in li.text:#if present
            drive_train.append(li.text.replace("Drivetrain:",""))#then append
        if 'City' in li.text:#if present
            location.append(li.text.replace("City:",""))#then append
        
        
#printing individual lists        
print(engine)
print(drive_train)
print(location)
# Out:
# ['2.4L 4cyl', '2.4L 4cyl', '1.8L 4cyl', '1.4L 4cyl', '1.6L 4cyl', '3.6L 6cyl', '2.5L 4cyl', '3.6L 6cyl', '3.3L 6cyl']
# ['Front Wheel Drive', 'Front Wheel Drive', 'Front Wheel Drive', 'Front Wheel Drive', '4x4', 'Front Wheel Drive', '4x4', 'All Wheel Drive', 'Front Wheel Drive']
# ['Winnipeg', 'Winnipeg', 'Winnipeg', 'Winnipeg', 'Winnipeg', 'Winnipeg', 'Winnipeg', 'Winnipeg', 'Winnipeg']

# %%
#Finding the car price on cars using find_all
#All the  car price  are present in span itemprop : price
car_price = []

c = soup.findAll('span',{"itemprop":"price"})
for i in c :
    print(i.text)
    car_price.append(i.text)#appending in a list
print(car_price)#printing list
# Out:
# $11,995
# $14,499
# $12,995
# $8,995
# $9,995
# $11,999
# $10,995
# $13,995
# $7,995
# ['$11,995', '$14,499', '$12,995', '$8,995', '$9,995', '$11,999', '$10,995', '$13,995', '$7,995']

# %%
description = []#taking an empty list
a = soup.findAll('div',{"class":"description"})#scrapping description
for i in a:
    description.append(i.text.strip())#appending in a list
    
print(description)#printing list
len(description)#length of list
# Out:
# ['Brand new safety', 'Great condition', 'New good year tires and top of the line Honda wheels. Great condition', 'Accident free. Manitoba vehicle', 'Clean unit, new tires with new saftey', 'Weather tech floor mats', 'Loaded limited model. Leather upholstery', 'Pure luxury. All wheel drive', 'Brand new safety. 7 passenger van']
# 9

# %%
mileage = []#taking an empty list
a = soup.findAll('span',{"class":"mileage-used-list"}) #scrapping mileage
for i in a:
     mileage.append(i.text.replace("Rural Discount\n","").strip())#appending in list
print(mileage)#printing list
# Out:
# ['175,476 km', '139,621 km', '146,840 km', '161,000 km', '193,025 km', '100,477 km', '141,459 km', '165,353 km', '157,330 km']

# %%
#creating dict of scrapped data
dict = {
    'Title' : car_titles ,
    'Exterior' : exterior , 
    'Body Style ': body_style,
    'Transmission' : transmission ,
    'Stock' : stock ,
    'Engine': engine,
    'Drive Train' : drive_train,
    'Location':location,
    'Price':car_price,
    'Mileage':mileage,
    'Description':description
   
}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                              Title   Exterior Body Style  Transmission Stock  \
# 0       2015 Chevrolet Equinox 1LT      Black         SUV    Automatic   N/A
# 1          2015 Honda Accord Sport  Dark Grey       Sedan    Automatic   N/A
# 2              2015 Honda Civic EX  Dark Grey       Sedan    Automatic   N/A
# 3         2014 Chevrolet Cruze 2LT      Black       Sedan    Automatic   N/A
# 4              2014 Ford Escape SE       Blue         SUV    Automatic     -
# 5  2012 Dodge Grand Caravan SE/SXT      White        Vans    Automatic     -
# 6         2012 Ford Escape Limited      Beige         SUV    Automatic   N/A
# 7                2011 Cadillac CTS      Black       Sedan    Automatic     -
# 8      2010 Dodge Grand Caravan SE       Grey        Vans    Automatic   N/A
#
#       Engine        Drive Train  Location    Price     Mileage  \
# 0  2.4L 4cyl  Front Wheel Drive  Winnipeg  $11,995  175,476 km
# 1  2.4L 4cyl  Front Wheel Drive  Winnipeg  $14,499  139,621 km
# 2  1.8L 4cyl  Front Wheel Drive  Winnipeg  $12,995  146,840 km
# 3  1.4L 4cyl  Front Wheel Drive  Winnipeg   $8,995  161,000 km
# 4  1.6L 4cyl                4x4  Winnipeg   $9,995  193,025 km
# 5  3.6L 6cyl  Front Wheel Drive  Winnipeg  $11,999  100,477 km
# 6  2.5L 4cyl                4x4  Winnipeg  $10,995  141,459 km
# 7  3.6L 6cyl    All Wheel Drive  Winnipeg  $13,995  165,353 km
# 8  3.3L 6cyl  Front Wheel Drive  Winnipeg   $7,995  157,330 km
#
#                                          Description
# 0                                   Brand new safety
# 1                                    Great condition
# 2  New good year tires and top of the line Honda ...
# 3                    Accident free. Manitoba vehicle
# 4              Clean unit, new tires with new saftey
# 5                            Weather tech floor mats
# 6           Loaded limited model. Leather upholstery
# 7                       Pure luxury. All wheel drive
# 8                  Brand new safety. 7 passenger van

# %%
#Dataframe to csv
df.to_csv('stcharlesmotors.csv')
