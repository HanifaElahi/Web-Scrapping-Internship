# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = "https://www.zorzosauto.ca/used/pg/4"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class row
data=soup.findAll('div',{"class":"row"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
#  Used Cars, SUVs, Trucks for Sale in Brandon
#
#
#
#
#
#
# Price
# $0
#
#
#
# $18,400
#
#
#
#
#
# 0 km
#
#
#
# 262,919 km
#
#
#
#
#
#
#
#
#
# View Setting:
#
#
#
#
#                         .maincontent .switch-view-wrapper {
#                             float: left;
#                             text-align: right;
#                             width: 42%;
#                             margin-top: 8px;
#                         }
#                         .maincontent .btn-list {
#                             background: url(https://static.edealer.ca/v31/img/list.png) no-repeat;
#                         }
#                         .maincontent .btn-grid {
#                             background: url(https://static.edealer.ca/v31/img/grid.png) no-repeat;
#                         }
#                         .maincontent .btn-list-active, .maincontent .btn-list:active, .maincontent .btn-list.active, .maincontent .open .dropdown-toggle.btn-list {
#                             background: url(https://static.edealer.ca/v31/img/list-hover-active.png) no-repeat;
#                         }
#                         .maincontent .btn-grid-active, .maincontent .btn-grid:active, .maincontent .btn-grid.active, .maincontent .open .dropdown-toggle.btn-grid {
#                             background: url(https://static.edealer.ca/v31/img/grid-hover-active.png) no-repeat;
#                         }
#                         .maincontent .btn-list:hover, .maincontent .btn-list:focus, .maincontent .btn-list:active, .maincontent .btn-list.active, .maincontent .open .dropdown-toggle.btn-list {
#                             background: url(https://static.edealer.ca/v31/img/list-hover-active.png) no-repeat;
#                         }
#                         .maincontent .btn-grid:hover, .maincontent .btn-grid:focus, .maincontent .btn-grid:active, .maincontent .btn-grid.active, .maincontent .open .dropdown-toggle.btn-grid {
#                             background: url(https://static.edealer.ca/v31/img/grid-hover-active.png) no-repeat;
#                         }
#
#
#
#
#
#  Shopping Assistant
#
#
#
#
#
# Recently Viewed
#
#
# Recommended for you
#
#
# Payment Calculator
#
#
# Car Finder
#
#
#
#
#
#
# loading...
#
#
#
#
# loading...
#
#
#
#
# loading...
#
#
#
#
# loading...
#
#
#
#
#
#
#
#
#  Sort By
#
#
# Year
#
#
# Newest to Oldest
#
# Oldest to Newest
# Price
#
#
# Lowest to Highest
#
# Highest to Lowest
# Mileage
#
#
# Lowest to Highest
#
# Highest to Lowest
# Make
#
#
# A to Z
#
# Z to A
# Added to Site
#
#
# Newest to Oldest
#
# Oldest to Newest
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2002-pontiac-grand-am-se1-id10271925.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/81261464.jpeg","thumbnailUrl":"https://images.edealer.ca/4/81261464.jpeg"}]}# SOLD #
#
#
#
# Apply for FinancingAppraise My Trade InBook a Test Drive2002 Pontiac Grand Am SE1Price:$4,525 $1,799Mileage:202,360 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SedanEngine:3.4L 6cylExterior Colour:Teal
#
#
#
#
# Transmission:AutomaticDrivetrain:Front Wheel DriveStock #:P599City:Brandon
#
# 202 GRAND AM SE V6.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/
maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
# Apply for FinancingAppraise My Trade InBook a Test Drive2009 Dodge Challenger SRT8Price: $CALLMileage:26,008 km
#
# View DetailsAdd to Compare
#
#
#
#
#
# Body Style:CoupeEngine:6.1L 8cylExterior Colour:Blue
#
#
#
#
# Transmission:ManualDrivetrain:Rear Wheel DriveStock #:P472City:Brandon

# %%
#Finding the titles of cars using find_all
#All the titles are present in p class : vehicle-year-make-model
car_titles = []
a=soup.findAll('p',{"class":"vehicle-year-make-model"})
for i in a :
    print(i.text)#printing titles
    car_titles.append(i.text)#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list

# %%
#Finding the car msrp  of cars using find_all
#All the car msrp  are present in strike class : old-price
msrp = []
a=soup.findAll('strike',{"class":"old-price"})
for i in a :
    print(i.text)#printing msrp
    msrp.append(i.text)#appending values
print(msrp)#printing msrp
len(msrp)#printing length of list

# %%
#Finding the car  price   using find_all
#All the car price are present in span itemprop : price
car_price = []
a=soup.findAll('span',{"itemprop":"price"})
for i in a :
    print(i.text)#printing  price
    car_price .append(i.text)#appending values
print(car_price)#printing  price
len(car_price)#printing length of list

# %%
transmission = []
body_style = []
exterior = []
stock = []
# taking empty lists

spec= soup.findAll('table',{"class":"table"})
for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('tr',{"class":"tr-even"})#finding all tr inside table wit class tr-even
    for li in lis:
        print(li.text)
        if 'Transmission' in li.text: #if present
            transmission.append(li.text.replace("Transmission:",""))#then append
        if 'Exterior Colour' in li.text:#if present
            exterior.append(li.text.replace("Exterior Colour:",""))#then append
        if 'Body Style' in li.text:#if present
            body_style.append(li.text.replace("Body Style:",""))#then append
        if 'Stock' in li.text: #if present
            stock.append(li.text.replace("Stock #:","")) #then append

            #printing individual lists        
print(transmission)
print(exterior)
print(body_style)
print(stock)

# %%
engine = []
drive_train = []
location = []
# taking empty lists

spec= soup.findAll('table',{"class":"table"})
for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('tr',{"class":"tr-odd"})#finding all tr inside table wit class tr-odd
    for li in lis:
        print(li.text)
        if 'Engine' in li.text: #if present
            engine.append(li.text.replace("Engine:",""))#then append
        if 'Drivetrain' in li.text:#if present
            drive_train.append(li.text.replace("Drivetrain:",""))#then append
        if 'City' in li.text:#if present
            location.append(li.text.replace("City:",""))#then append
       
 #printing individual lists        
print(engine)
print(drive_train)
print(location)

# %%
#creating dict of scrapped data
dict = {
    'Title' : car_titles,
    'MSRP':msrp,
    'Price' : car_price,
    'Transmission' : transmission,
    'Exterior':exterior,
    'Body Style':body_style,
    'Stock' : stock,
    'Engine' : engine ,
    'Drive Train':drive_train,
    'Location':location
}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df

# %%
#Dataframe to csv
df.to_csv('zorzosautos.csv')
