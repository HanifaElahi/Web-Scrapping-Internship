# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = input(("Enter url : ")) 
# "https://www.autosavewpg.com/used-cars/"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class container-inventory-page
data=soup.findAll('div',{"class":"container-inventory-page"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
# Used Cars For Sale in Winnipeg, Manitoba
#
#
#
#
#  Search
#
#
#
#
#
#
#
#
#
#
# Any Make
#
# Chevrolet
# Dodge
# Ford
# GMC
# Hyundai
# Nissan
#
#
#
#
# Any Model
#
#
#
#
#
# Any Body Style
#
# SUV
# Sedan
# Van-Minivan
#
#
#
#
#
#
#
#
# Min Year
#
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
#
#
#
#
# Max Year
#
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
#
#
#
#
#
#
#
#
# Min Price
#
# $1,000
#
# $2,000
#
# $3,000
#
# $4,000
#
# $5,000
#
# $6,000
#
# $7,000
#
# $8,000
#
# $9,000
#
# $10,000
#
# $11,000
#
# $12,000
#
# $13,000
#
# $14,000
#
# $15,000
#
# $16,000
#
# $17,000
#
# $18,000
#
# $19,000
#
# $20,000
#
# $21,000
#
# $22,000
#
# $23,000
#
# $24,000
#
# $25,000
#
# $30,000
#
# $35,000
#
# $40,000
#
# $45,000
#
# $50,000
#
# $55,000
#
# $60,000
#
# $65,000
#
# $70,000
#
# $75,000
#
# $80,000
#
#
#
#
#
# Max Price
#
# $1,000
#
# $2,000
#
# $3,000
#
# $4,000
#
# $5,000
#
# $6,000
#
# $7,000
#
# $8,000
#
# $9,000
#
# $10,000
#
# $11,000
#
# $12,000
#
# $13,000
#
# $14,000
#
# $15,000
#
# $16,000
#
# $17,000
#
# $18,000
#
# $19,000
#
# $20,000
#
# $21,000
#
# $22,000
#
# $23,000
#
# $24,000
#
# $25,000
#
# $30,000
#
# $35,000
#
# $40,000
#
# $45,000
#
# $50,000
#
# $55,000
#
# $60,000
#
# $65,000
#
# $70,000
#
# $75,000
#
# $80,000
#
#
#
#
#
#
#
#
#
# Min Km
#
# 10,000
#
# 20,000
#
# 30,000
#
# 40,000
#
# 50,000
#
# 60,000
#
# 70,000
#
# 80,000
#
# 90,000
#
# 100,000
#
# 125,000
#
# 150,000
#
# 175,000
#
# 200,000
#
# 250,000
#
#
#
#
#
# Max Km
#
# 10,000
#
# 20,000
#
# 30,000
#
# 40,000
#
# 50,000
#
# 60,000
#
# 70,000
#
# 80,000
#
# 90,000
#
# 100,000
#
# 125,000
#
# 150,000
#
# 175,000
#
# 200,000
#
# 250,000
#
#
#
#
#
#
#
#
#
# Any Engine
#
# 4 Cylinder
# 6 Cylinder
#
#
#
#
# Any Transmission
#
# Automatic
# CVT
# 6 Speed Automatic
#
#
#
#
# Any Fuel Type
#
# Gasoline
# Other
#
#
#
#
#
#
# Any Color
#
# Graphite
# Silver
# Off White
# Blue
# Red
# Dark Grey
# Gray
#
#
#
#
#  Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         7 Vehicles
#
#
#
#
#
#
#
#
#
# Sort:
# Make
# Model
# Year
# Price
# Mileage
# Body Style
#
#
#
#
#
#
#
#
#
#
#
#
#
# 8
#
#
#
#
#
#
#
#  2018 Chevrolet Malibu  4dr Sdn LT w/1LT
#
#
#                                                                                                                                                                                                                                                             94,000                                                                                        Km
#
#
#
#
#
#
#
#
#
# Stock #:4100
#
#
#
#
# Body Style:Sedan
#
#
#
#
# Engine:4 Cylinder
#
#
#
#
# Driveline:FWD
#
#
#
#
# Fuel Type:Gasoline
#
#
#
#
# Doors:4 doors
#
#
#
#
# Exterior:Gray
#
#
#
#
# Transmission:Automatic
#
#
#
#
#
#
#
#
#
# $17,498
#
# View Details
#
# Contact Us
#
#
#                                                                                                     Financing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 11
#
#
#
#
#
#
#
#  2017 Dodge Grand Caravan  4dr Wgn
#
#
#                                                                                                                                                                                                                                                             65,000                                                                                        Km
#
#
#
#
#
#
#
#
#
# Stock #:4141
#
#
#
#
# Body Style:Van-Minivan
#
#
#
#
# Engine:6 Cylinder
#
#
#
#
# Driveline:FWD
#
#
#
#
# Fuel Type:Other
#
#
#
#
# Doors:4 doors
#
#
#
#
# Exterior:Dark Grey
#
#
#
#
# Transmission:6 Speed Automatic
#
#
#
#
#
#
#
#
#
# $27,000
#
# View Details
#
# Contact Us
#
#
#                                                                                                     Financing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 7
#
#
#
#
#
#
#
#  2013 Nissan Sentra  4dr Sdn
#
#
#                                                                                                                                                                                                                                                             122,000                                                                                        Km
#
#
#
#
#
#
#
#
#
# Stock #:3838
#
#
#
#
# Body Style:Sedan
#
#
#
#
# Engine:4 Cylinder
#
#
#
#
# Driveline:FWD
#
#
#
#
# Fuel Type:Gasoline
#
#
#
#
# Doors:4 doors
#
#
#
#
# Exterior:Red
#
#
#
#
# Transmission:CVT
#
#
#
#
#
#
#
#
#
# $8,499
#
# View Details
#
# Contact Us
#
#
#                                                                                                     Financing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 7
#
#
#
#
#
#
#
#  2013 Ford Fiesta  4dr Sdn SE
#
#
#                                                                                                                                                                                                                                                             133,000                                                                                        Km
#
#
#
#
#
#
#
#
#
# Stock #:4152
#
#
#
#
# Body Style:Sedan
#
#
#
#
# Engine:4 Cylinder
#
#
#
#
# Driveline:FWD
#
#
#
#
# Fuel Type:Gasoline
#
#
#
#
# Doors:4 doors
#
#
#
#
# Exterior:Blue
#
#
#
#
# Transmission:Automatic
#
#
#
#
#
#
#
#
#
# $7,200
#
# View Details
#
# Contact Us
#
#
#                                                                                                     Financing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 7
#
#
#
#
#
#
#
#  2013 GMC Acadia  FWD 4dr SLE2
#
#
#                                                                                                                                                                                                                                                             131,000                                                                                        Km
#
#
#
#
#
#
#
#
#
# Stock #:4145
#
#
#
#
# Body Style:SUV
#
#
#
#
# Engine:6 Cylinder
#
#
#
#
# Driveline:FWD
#
#
#
#
# Fuel Type:Gasoline
#
#
#
#
# Doors:4 doors
#
#
#
#
# Exterior:Off White
#
#
#
#
# Transmission:Automatic
#
#
#
#
#
#
#
#
#
# $12,999
#
# View Details
#
# Contact Us
#
#
#                                                                                                     Financing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 7
#
#
#
#
#
#
#
#  2017 Hyundai Elantra  4dr Sdn
#
#
#                                                                                                                                                                                                                                                             62,000                                                                                        Km
#
#
#
#
#
#
#
#
#
# Stock #:4015
#
#
#
#
# Body Style:Sedan
#
#
#
#
# Engine:4 Cylinder
#
#
#
#
# Driveline:FWD
#
#
#
#
# Fuel Type:Gasoline
#
#
#
#
# Doors:4 doors
#
#
#
#
# Exterior:Silver
#
#
#
#
# Transmission:Automatic
#
#
#
#
#
#
#
#
#
# $12,998
#
# View Details
#
# Contact Us
#
#
#                                                                                                     Financing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 9
#
#
#
#
#
#
#
#  2017 Chevrolet Equinox  AWD 4dr LS
#
#
#                                                                                                                                                                                                                                                             171,000                                                                                        Km
#
#
#
#
#
#
#
#
#
# Stock #:4025
#
#
#
#
# Body Style:SUV
#
#
#
#
# Engine:4 Cylinder
#
#
#
#
# Driveline:AWD
#
#
#
#
# Fuel Type:Gasoline
#
#
#
#
# Doors:4 doors
#
#
#
#
# Exterior:Graphite
#
#
#
#
# Transmission:Automatic
#
#
#
#
#
#
#
#
#
# $10,998
#
# View Details
#
# Contact Us
#
#
#                                                                                                     Financing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                     Dealership
#
# Auto Save- Your Local Used Car Dealership
# Established in 1996, Auto Save has grown to become a premier wholesale pre-owned auto dealership in the West End of Winnipeg. We strive to include the best possible customer service with top-notch repair and maintenance work and comprehensive pre-owned... Read More
#
#
#
#
#
# Our Hours
# Monday 9AM-6PM Tuesday 9AM-6PM Wednesday 9AM-6PM Thursday 9AM-6PM Friday 9AM-6PM Saturday 9AM-6PM Sunday Closed
#
#
#
# Our Contacts
#
#
#
#
#                                             1450 Notre Dame Ave
#                                             Winnipeg,
#                                             Manitoba
#                                             R3E 3G5
#
#
#  204-774-8900
#
#
#
#
# Connect with us

# %%
#Finding the titles of cars using find_all
#All the titles are present in h3 class : vehicleName
car_titles = []
a=soup.findAll('h3',{"class":"vehicleName"})
for titles in a :
    print(titles.text)#printing titles
    car_titles.append(titles.text)#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# 2018 Chevrolet Malibu  4dr Sdn LT w/1LT
# 2017 Dodge Grand Caravan  4dr Wgn
# 2013 Nissan Sentra  4dr Sdn
# 2013 Ford Fiesta  4dr Sdn SE
# 2013 GMC Acadia  FWD 4dr SLE2
# 2017 Hyundai Elantra  4dr Sdn
# 2017 Chevrolet Equinox  AWD 4dr LS
# ['2018 Chevrolet Malibu  4dr Sdn LT w/1LT', '2017 Dodge Grand Caravan  4dr Wgn', '2013 Nissan Sentra  4dr Sdn', '2013 Ford Fiesta  4dr Sdn SE', '2013 GMC Acadia  FWD 4dr SLE2', '2017 Hyundai Elantra  4dr Sdn', '2017 Chevrolet Equinox  AWD 4dr LS']
# 7

# %%
#Finding the mileage of cars using find_all
#All the mileage are present in div class : Kilometers
car_mileage = []
a=soup.findAll('div',{"class":"Kilometers"})
for mileage in a :
    print(mileage.text.strip())#printing mileage
    car_mileage.append(mileage.text.replace("                                                                                      ","").strip())#appending values
print(car_mileage)#printing mileage
len(car_mileage)#printing length of list
# Out:
# 94,000                                                                                        Km
# 65,000                                                                                        Km
# 122,000                                                                                        Km
# 133,000                                                                                        Km
# 131,000                                                                                        Km
# 62,000                                                                                        Km
# 171,000                                                                                        Km
# ['94,000  Km', '65,000  Km', '122,000  Km', '133,000  Km', '131,000  Km', '62,000  Km', '171,000  Km']
# 7

# %%
stock=[]
body_style = []
engine = []
drive_line = []
fuel_type = []
doors = []
exterior = []
transmission = []
#taking individual empty lists

details = soup.find_all("div",{"class":"col-md-6"}) # all the details are inside div class:col-md-6
for i in details:
    if 'Stock #' in i.text: #if present
        stock.append(i.text.replace("Stock #:","").strip()) #then append
    if 'Body Style' in i.text:
        body_style.append(i.text.replace("Body Style:","").strip())
    if 'Engine' in i.text: #if present
        engine.append(i.text.replace("Engine:","").strip()) #then append
    if 'Driveline' in i.text:
        drive_line.append(i.text.replace("Driveline:","").strip())
    if 'Fuel Type' in i.text: #if present
        fuel_type.append(i.text.replace("Fuel Type:","").strip()) #then append
    if 'Doors' in i.text:
        doors.append(i.text.replace("Doors:","").strip())
    if 'Exterior' in i.text: #if present
        exterior.append(i.text.replace("Exterior:","").strip()) #then append
    if 'Transmission' in i.text:
        transmission.append(i.text.replace("Transmission:","").strip())

        
#printing lists
print(stock)
print(body_style)
print(engine)
print(drive_line)
print(fuel_type)
print(doors)
print(exterior)
print(transmission)
# Out:
# ['4100', '4141', '3838', '4152', '4145', '4015', '4025']
# ['Sedan', 'Van-Minivan', 'Sedan', 'Sedan', 'SUV', 'Sedan', 'SUV']
# ['4 Cylinder', '6 Cylinder', '4 Cylinder', '4 Cylinder', '6 Cylinder', '4 Cylinder', '4 Cylinder']
# ['FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'AWD']
# ['Gasoline', 'Other', 'Gasoline', 'Gasoline', 'Gasoline', 'Gasoline', 'Gasoline']
# ['4 doors', '4 doors', '4 doors', '4 doors', '4 doors', '4 doors', '4 doors']
# ['Gray', 'Dark Grey', 'Red', 'Blue', 'Off White', 'Silver', 'Graphite']
# ['Automatic', '6 Speed Automatic', 'CVT', 'Automatic', 'Automatic', 'Automatic', 'Automatic']

# %%
#Finding the car price using find_all
#All the car price are present in div class : priceVal
car_price = []
a=soup.findAll('div',{"class":"priceVal"})
for c in a :
    print(c.text.strip())#printing car price
    car_price.append(c.text.strip())#appending values
print(car_price)#printing car price
len(car_price)#printing length of list
# Out:
# $17,498
# $27,000
# $8,499
# $7,200
# $12,999
# $12,998
# $10,998
# ['$17,498', '$27,000', '$8,499', '$7,200', '$12,999', '$12,998', '$10,998']
# 7

# %%
#creating dict of scrapped data
dict = {
    'Title' : car_titles ,
    'Mileage' : car_mileage , 
    'Price ': car_price ,
    'Stock' : stock ,
    'Body Style' : body_style ,
    'Engine' : engine,
    'Driveline':drive_line,
    'Fuel Type':fuel_type,
    'Doors': doors,
    'Exterior': exterior,
    'Transmission':transmission,
}

# %%
#creating dataframe from dict
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                                      Title      Mileage   Price  Stock  \
# 0  2018 Chevrolet Malibu  4dr Sdn LT w/1LT   94,000  Km  $17,498  4100
# 1        2017 Dodge Grand Caravan  4dr Wgn   65,000  Km  $27,000  4141
# 2              2013 Nissan Sentra  4dr Sdn  122,000  Km   $8,499  3838
# 3             2013 Ford Fiesta  4dr Sdn SE  133,000  Km   $7,200  4152
# 4            2013 GMC Acadia  FWD 4dr SLE2  131,000  Km  $12,999  4145
# 5            2017 Hyundai Elantra  4dr Sdn   62,000  Km  $12,998  4015
# 6       2017 Chevrolet Equinox  AWD 4dr LS  171,000  Km  $10,998  4025
#
#     Body Style      Engine Driveline Fuel Type    Doors   Exterior  \
# 0        Sedan  4 Cylinder       FWD  Gasoline  4 doors       Gray
# 1  Van-Minivan  6 Cylinder       FWD     Other  4 doors  Dark Grey
# 2        Sedan  4 Cylinder       FWD  Gasoline  4 doors        Red
# 3        Sedan  4 Cylinder       FWD  Gasoline  4 doors       Blue
# 4          SUV  6 Cylinder       FWD  Gasoline  4 doors  Off White
# 5        Sedan  4 Cylinder       FWD  Gasoline  4 doors     Silver
# 6          SUV  4 Cylinder       AWD  Gasoline  4 doors   Graphite
#
#         Transmission
# 0          Automatic
# 1  6 Speed Automatic
# 2                CVT
# 3          Automatic
# 4          Automatic
# 5          Automatic
# 6          Automatic

# %%
#Dataframe to csv
df.to_csv('autoshow.csv')
