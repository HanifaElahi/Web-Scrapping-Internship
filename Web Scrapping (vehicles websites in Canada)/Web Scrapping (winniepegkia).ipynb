# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = "https://www.winnipegkia.com/inventory/search?page=1&page_length=20&stock_type=New&make=Kia"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class group-content
data=soup.findAll('section',{"class":"group-content"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
# 67 Vehicles Found
#
#
# 5
#
# 10
#
# 20
#
# 50
#
# 100
#
#
# --- Sort by: ---
# Price: lowest first
# Price: highest first
# Makes: A - Z
# Makes: Z - A
# Models: A - Z
# Models: Z - A
# Odometer: lowest first
# Odometer: highest first
# Year: oldest first
# Year: newest first
# Dealer: closest
#
#
#
# List view
# Grid view
#
#
#
#
# On special
#
#
#
# View 23 Photos
#
#
# in stock
# 2020 Kia Forte
# LX MT
# Details
#
# Odometer
# 5 KMS
# Color
# Urban Grey
# Engine
# 2L I-4
# Transmission
# 6 Spd Manual
# Drivetrain
# FWD
# Stock #
# 20FR834
# VIN
# 3KPF24AD3LE182270
#
#
#
# Was $20,739
#
# $18,739*
# You Save $2,000
#
# $20,739 Retail Price
# - $2,000 Dealer Discount/Manufacturer Rebate
# 				= $2,000 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f0808c7cc8b8911c3514ee8.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "18739"
# 		},
# 		"sku": "20FR834",
# 		"itemCondition": "new",
# 		"color": "Grey",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX MT LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "6 Spd Manual",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "5",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF24AD3LE182270",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 23 Photos
#
#
# in stock
# 2020 Kia Rio 5-door
# LX+
# Details
#
# Odometer
# 15 KMS
# Color
# Radiant Red
# Engine
# 1.6L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 20RI067
# VIN
# 3KPA25AD5LE345792
#
#
#
# Was $21,239
#
# $18,972*
# You Save $2,267
#
# $21,239 Retail Price
# - $2,267 Dealer Discount/Manufacturer Rebate
# 				= $2,267 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Kia Rio 5-door",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f9e535e94721b37758a6361.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "18972"
# 		},
# 		"sku": "20RI067",
# 		"itemCondition": "new",
# 		"color": "Red",
# 		"model": "Rio 5-door",
# 		"vehicleConfiguration": "LX+ LX+",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Hatchback",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "15",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPA25AD5LE345792",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 23 Photos
#
#
# in stock
# 2020 Kia Rio 5-door
# LX+
# Details
#
# Odometer
# 15 KMS
# Color
# Radiant Red
# Engine
# 1.6L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 20RI969
# VIN
# 3KPA25ADXLE337221
#
#
#
# Was $21,239
#
# $18,972*
# You Save $2,267
#
# $21,239 Retail Price
# - $2,267 Dealer Discount/Manufacturer Rebate
# 				= $2,267 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Kia Rio 5-door",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f547fc9af408e0cbb65877d.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "18972"
# 		},
# 		"sku": "20RI969",
# 		"itemCondition": "new",
# 		"color": "Red",
# 		"model": "Rio 5-door",
# 		"vehicleConfiguration": "LX+ LX+",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Hatchback",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "15",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPA25ADXLE337221",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 23 Photos
#
#
# in stock
# 2021 Kia Forte
# LX
# Details
#
# Color
# Urban Grey
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 21FR070
# VIN
# 3KPF24ADXME282710
#
#
#
# Was $22,539
#
# $21,772*
# You Save $767
#
# $22,539 Retail Price
# - $767 Dealer Discount/Manufacturer Rebate
# 				= $767 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5fa4eb5f3670ee3c70fa1348.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21772"
# 		},
# 		"sku": "21FR070",
# 		"itemCondition": "new",
# 		"color": "Grey",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "0",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF24ADXME282710",
# 		"vehicleSeatingCapacity": ""
# }
#
#
#
# On special
#
#
#
# View 23 Photos
#
#
# in stock
# 2021 Kia Forte
# LX
# Details
#
# Color
# Aurora Black
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 21FR071
# VIN
# 3KPF24ADXME282917
#
#
#
# Was $22,539
#
# $21,772*
# You Save $767
#
# $22,539 Retail Price
# - $767 Dealer Discount/Manufacturer Rebate
# 				= $767 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5fa4eb62e51a1f3d8efca5fc.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21772"
# 		},
# 		"sku": "21FR071",
# 		"itemCondition": "new",
# 		"color": "Black",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "0",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF24ADXME282917",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 23 Photos
#
#
# in stock
# 2021 Kia Forte
# LX
# Details
#
# Odometer
# 18 KMS
# Color
# Gravity Grey
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 21FR028
# VIN
# 3KPF24AD5ME281464
#
#
#
# Was $22,539
#
# $21,772*
# You Save $767
#
# $22,539 Retail Price
# - $767 Dealer Discount/Manufacturer Rebate
# 				= $767 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f9e536157ad893dc469b4da.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21772"
# 		},
# 		"sku": "21FR028",
# 		"itemCondition": "new",
# 		"color": "Grey",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "18",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF24AD5ME281464",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 21 Photos
#
#
# in stock
# 2021 Kia Forte
# LX
# Details
#
# Color
# Snow White Pearl
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 21FR068
# VIN
# 3KPF24AD3ME283276
#
#
#
# Was $22,539
#
# $21,772*
# You Save $767
#
# $22,539 Retail Price
# - $767 Dealer Discount/Manufacturer Rebate
# 				= $767 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5fa4eb646d721321aeaa8eea.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21772"
# 		},
# 		"sku": "21FR068",
# 		"itemCondition": "new",
# 		"color": "White",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "0",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF24AD3ME283276",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 21 Photos
#
#
# in stock
# 2021 Kia Forte
# LX
# Details
#
# Color
# Snow White Pearl
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 21FR069
# VIN
# 3KPF24AD8ME282270
#
#
#
# Was $22,539
#
# $21,772*
# You Save $767
#
# $22,539 Retail Price
# - $767 Dealer Discount/Manufacturer Rebate
# 				= $767 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5fa4eb65d5b91b1adb102fe9.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21772"
# 		},
# 		"sku": "21FR069",
# 		"itemCondition": "new",
# 		"color": "White",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "0",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF24AD8ME282270",
# 		"vehicleSeatingCapacity": ""
# }
#
#
#
# On special
#
#
#
# View 21 Photos
#
#
# in stock
# 2021 Kia Forte
# LX
# Details
#
# Odometer
# 15 KMS
# Color
# Snow White Pearl
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 21FR001
# VIN
# 3KPF24ADXME276129
#
#
#
# Was $22,539
#
# $21,772*
# You Save $767
#
# $22,539 Retail Price
# - $767 Dealer Discount/Manufacturer Rebate
# 				= $767 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f8546d8dc5f496d8fb4895c.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21772"
# 		},
# 		"sku": "21FR001",
# 		"itemCondition": "new",
# 		"color": "White",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "15",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF24ADXME276129",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 23 Photos
#
#
# in stock
# 2021 Kia Forte
# LX
# Details
#
# Odometer
# 15 KMS
# Color
# Urban Grey
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 21FR996
# VIN
# 3KPF24AD1ME265844
#
#
#
# Was $22,539
#
# $21,772*
# You Save $767
#
# $22,539 Retail Price
# - $767 Dealer Discount/Manufacturer Rebate
# 				= $767 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f702f3792bd3c0da6f798a3.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21772"
# 		},
# 		"sku": "21FR996",
# 		"itemCondition": "new",
# 		"color": "Grey",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "15",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF24AD1ME265844",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 23 Photos
#
#
# in stock
# 2021 Kia Forte
# LX
# Details
#
# Odometer
# 15 KMS
# Color
# Gravity Grey
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 21FR029
# VIN
# 3KPF24ADXME281816
#
#
#
# Was $22,539
#
# $21,772*
# You Save $767
#
# $22,539 Retail Price
# - $767 Dealer Discount/Manufacturer Rebate
# 				= $767 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f9e5380d6469b22c0454cea.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21772"
# 		},
# 		"sku": "21FR029",
# 		"itemCondition": "new",
# 		"color": "Grey",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "15",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF24ADXME281816",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 23 Photos
#
#
# in stock
# 2021 Kia Forte
# LX
# Details
#
# Odometer
# 5 KMS
# Color
# Urban Grey
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 21FR006
# VIN
# 3KPF24AD0ME276284
#
#
#
# Was $22,539
#
# $21,772*
# You Save $767
#
# $22,539 Retail Price
# - $767 Dealer Discount/Manufacturer Rebate
# 				= $767 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f87ea3decd536766d00c5cf.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21772"
# 		},
# 		"sku": "21FR006",
# 		"itemCondition": "new",
# 		"color": "Grey",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "5",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF24AD0ME276284",
# 		"vehicleSeatingCapacity": ""
# }
#
#
#
# On special
#
#
#
# View 23 Photos
#
#
# in stock
# 2021 Kia Forte
# LX
# Details
#
# Odometer
# 15 KMS
# Color
# Gravity Grey
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 21FR999
# VIN
# 3KPF24AD5ME275549
#
#
#
# Was $22,539
#
# $21,772*
# You Save $767
#
# $22,539 Retail Price
# - $767 Dealer Discount/Manufacturer Rebate
# 				= $767 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f702f36e99a941f2bffac38.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21772"
# 		},
# 		"sku": "21FR999",
# 		"itemCondition": "new",
# 		"color": "Grey",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "15",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF24AD5ME275549",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 23 Photos
#
#
# in stock
# 2021 Kia Forte
# LX
# Details
#
# Odometer
# 15 KMS
# Color
# Aurora Black
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 21FR971
# VIN
# 3KPF24AD7ME265895
#
#
#
# Was $22,539
#
# $21,772*
# You Save $767
#
# $22,539 Retail Price
# - $767 Dealer Discount/Manufacturer Rebate
# 				= $767 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f702f2d1bd7bb7706de0ab8.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21772"
# 		},
# 		"sku": "21FR971",
# 		"itemCondition": "new",
# 		"color": "Black",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# ...
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f702f3b554752244472bc5d.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21772"
# 		},
# 		"sku": "21FR997",
# 		"itemCondition": "new",
# 		"color": "White",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "15",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF24AD2ME265822",
# 		"vehicleSeatingCapacity": ""
# }
#
#
#
# On special
#
#
#
# View 23 Photos
#
#
# in stock
# 2021 Kia Forte
# LX
# Details
#
# Odometer
# 15 KMS
# Color
# Hyper Blue
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 21FR998
# VIN
# 3KPF24AD4ME266020
#
#
#
# Was $22,539
#
# $21,772*
# You Save $767
#
# $22,539 Retail Price
# - $767 Dealer Discount/Manufacturer Rebate
# 				= $767 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f702f397813be095fd0ffad.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21772"
# 		},
# 		"sku": "21FR998",
# 		"itemCondition": "new",
# 		"color": "Blue",
# 		"model": "Forte",
# 		"vehicleConfiguration": "LX LX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "15",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF24AD4ME266020",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 21 Photos
#
#
# in stock
# 2019 Kia Forte
# EX *Demo - Reduced To Sell Fast!*
# Details
#
# Odometer
# 26 KMS
# Color
# AURORA BLACK
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 19FR255
# VIN
# 3KPF54AD8KE088732
#
#
#
# Was $23,779
#
# $21,999*
# You Save $1,780
#
# $23,779 Retail Price
# - $1,780 Dealer Discount/Manufacturer Rebate
# 				= $1,780 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2019 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p style=&quot;margin-top: 0px;margin-bottom: 1rem;font-family: KiaFont, Tahoma, sans-serif;color: #7e8083;font-size: 16px&quot;&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Low mileage with massive savings! This Forte is the fun sedan you need, that doesn&#x27;t skimp on features, functionality or safety. Features include blind spot detection, 16&quot; alloy wheels, wireless cell phone charger, back up camera and much more. Plus one of the best warranties in the industry - remaining 5 year/100,000 km comprehensive warranty covering virtually the entire vehicle! &lt;/span&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Contact us for full details.*&lt;/span&gt;&lt;/p&gt; &lt;p style=&quot;margin-top: 0px;margin-bottom: 1rem;font-family: KiaFont, Tahoma, sans-serif;color: #7e8083;font-size: 16px&quot;&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are the #1 volume Kia dealership in the Prairie&#x27;s for 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall. Live chat with our sales team is also available on our website!&lt;/span&gt;&lt;/p&gt; &lt;p style=&quot;margin-top: 0px;margin-bottom: 1rem;font-family: KiaFont, Tahoma, sans-serif;color: #7e8083;font-size: 16px&quot;&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Vehicle pricing is plus GST and PST and may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5eb5703dfaacaf373483a213.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "21999"
# 		},
# 		"sku": "19FR255",
# 		"itemCondition": "new",
# 		"color": "Black",
# 		"model": "Forte",
# 		"vehicleConfiguration": "EX *Demo - Reduced To Sell Fast!* EX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "26",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF54AD8KE088732",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 22 Photos
#
#
# in stock
# 2020 Kia Forte
# EX Premium
# Details
#
# Odometer
# 5 KMS
# Color
# Snow White Pearl
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 20FR798
# VIN
# 3KPF54AD8LE244348
#
#
#
# Was $27,339
#
# $24,339*
# You Save $3,000
#
# $27,339 Retail Price
# - $3,000 Dealer Discount/Manufacturer Rebate
# 				= $3,000 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2020 Kia Forte",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/5f13e6f7bc303f4fca73f721.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "24339"
# 		},
# 		"sku": "20FR798",
# 		"itemCondition": "new",
# 		"color": "White",
# 		"model": "Forte",
# 		"vehicleConfiguration": "EX Premium EX Premium",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Sedan",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "5",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "3KPF54AD8LE244348",
# 		"vehicleSeatingCapacity": ""
# }
#
#
# On special
#
#
#
# View 3 Photos
#
#
# in stock
# 2021 Kia Soul
# EX
# Details
#
# Odometer
# 5 KMS
# Color
# Snow White Pearl
# Engine
# 2L I-4
# Transmission
# CVT
# Drivetrain
# FWD
# Stock #
# 21SO050
# VIN
# KNDJ33AU6M7753575
#
#
#
# Was $26,189
#
# $24,422*
# You Save $1,767
#
# $26,189 Retail Price
# - $1,767 Dealer Discount/Manufacturer Rebate
# 				= $1,767 Total Savings
#
#
#
#
#
#
#
# View Vehicle
#
#
#
#
# {
# 		"@context": "http://schema.org/",
# 		"@type": "Vehicle",
# 		"name": "2021 Kia Soul",
# 		"brand": "Kia",
# 		"description": "&lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;*Unwrap a deal with us this month and save thousands! You could win up to $10,000 in holiday bonuses on our most popular models. Plus finance your new Kia purchase for as low as 0% for up to 84 months (O.A.C.) and receive up to $1,500 in holiday credits on select models! Already a Kia owner? Receive a 1% finance or lease rate reduction with your eligible new Kia purchase! Call, click or come in for complete details!*&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;We believe it is essential to continue our constant support for those needing to stay mobile. Whether it is sales, service or parts that you need - we are open and here for you. &lt;/span&gt;&lt;span style=&quot;color: #7e8083&quot;&gt;Shop from home with ease - view our entire current inventory, live chat with our sales team, view current promotions, operating hours and much more on our website.&lt;/span&gt;&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;We are your #1 volume Kia dealership in the Prairie&#x27;s, selling the most new Kia vehicles out of all the Kia dealers in our region, in 2019! Let our locally owned and family run dealership show you the Winnipeg Kia difference - contact us today or visit us in the Waverley Auto Mall.&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Kia Canada offers one of the best warranties in the industry, a worry-free comprehensive warranty covering virtually the entire vehicle for 5 years/100,000 km, accompanied with free roadside assistance during the warranty period!&lt;/span&gt;&lt;/p&gt;
# &lt;p&gt;&lt;span style=&quot;font-size: medium&quot;&gt;Due to a constantly changing market, our vehicle prices are reviewed and adjusted on a regular basis to ensure correct market values. Cash vehicle purchase price includes freight, pre-delivery inspection, colour charge (if applicable) and all current incentives. Vehicle price is plus GST and PST. Vehicle price may already reflect this months Kia Canada promotional incentives. Please contact us to confirm this vehicles pricing, availability, incentives and eligibility. Dealer Permit #10011.&lt;/span&gt;&lt;/p&gt;",
# 		"image": "https:https://photos.strathcom.com/image/show/1200x_/CAD10KIC101G0_01_SWP.jpg",
# 		"offers":{
# 			"@type": "Offer",
# 			"priceCurrency": "CAD",
# 			"price": "24422"
# 		},
# 		"sku": "21SO050",
# 		"itemCondition": "new",
# 		"color": "White",
# 		"model": "Soul",
# 		"vehicleConfiguration": "EX EX",
# 		"driveWheelConfiguration": "FWD",
# 		"vehicleTransmission": "CVT",
# 		"disambiguatingDescription": "4dr FWD Hatchback",
# 		"vehicleInteriorColor": "Black",
# 		"fuelType": "Gasoline Fuel",
# 		"mileageFromOdometer": "5",
# 		"numberOfDoors": "",
# 		"vehicleEngine": "I-4",
# 		"vehicleIdentificationNumber": "KNDJ33AU6M7753575",
# 		"vehicleSeatingCapacity": ""
# }
#
#
#
# 1
#
# 2
#
# 3
#
# 4

# %%
#Finding the titles of cars using find_all
#All the titles are present in h4 itemprop : name
car_titles = []
a=soup.findAll('h4',{"itemprop":"name"})
for i in a :
    print(i.text)
    car_titles.append(i.text)#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# 2020 Kia Forte
# 2020 Kia Rio 5-door
# 2020 Kia Rio 5-door
# 2021 Kia Forte
# 2021 Kia Forte
# 2021 Kia Forte
# 2021 Kia Forte
# 2021 Kia Forte
# 2021 Kia Forte
# 2021 Kia Forte
# 2021 Kia Forte
# 2021 Kia Forte
# 2021 Kia Forte
# 2021 Kia Forte
# 2021 Kia Forte
# 2021 Kia Forte
# 2021 Kia Forte
# 2019 Kia Forte
# 2020 Kia Forte
# 2021 Kia Soul
# ['2020 Kia Forte', '2020 Kia Rio 5-door', '2020 Kia Rio 5-door', '2021 Kia Forte', '2021 Kia Forte', '2021 Kia Forte', '2021 Kia Forte', '2021 Kia Forte', '2021 Kia Forte', '2021 Kia Forte', '2021 Kia Forte', '2021 Kia Forte', '2021 Kia Forte', '2021 Kia Forte', '2021 Kia Forte', '2021 Kia Forte', '2021 Kia Forte', '2019 Kia Forte', '2020 Kia Forte', '2021 Kia Soul']
# 20

# %%
#Finding the price of cars using find_all
#All the priceare present in strong class : price _bpcolor
car_price = []
a=soup.findAll('strong',{"class":"price _bpcolor"})
for i in a :
    print(i.text)
    car_price.append(i.text.strip())#appending values
print(car_price)#printing price
len(car_price)#printing length of list
# Out:
# $18,739*
#
# $18,972*
#
# $18,972*
#
# $21,772*
#
# $21,772*
#
# $21,772*
#
# $21,772*
#
# $21,772*
#
# $21,772*
#
# $21,772*
#
# $21,772*
#
# $21,772*
#
# $21,772*
#
# $21,772*
#
# $21,772*
#
# $21,772*
#
# $21,772*
#
# $21,999*
#
# $24,339*
#
# $24,422*
# ['$18,739*', '$18,972*', '$18,972*', '$21,772*', '$21,772*', '$21,772*', '$21,772*', '$21,772*', '$21,772*', '$21,772*', '$21,772*', '$21,772*', '$21,772*', '$21,772*', '$21,772*', '$21,772*', '$21,772*', '$21,999*', '$24,339*', '$24,422*']
# 20

# %%
car_description = []#taking empty list
a = soup.findAll('div',{"class":"used-description product-description"})#scrapping description
for i in a:
    s = i.find('h5')
    car_description.append(s.text)#appending in a list
print(car_description)#printing list
# Out:
# []

# %%
mileage = []#taking empty list
a = soup.findAll('dd',{"class":"srp-odometer"})#scrapping mileage
for i in a:
    print(i.text)
    mileage.append(i.text)#appending in a list
print(mileage)#printing list
# Out:
# 5 KMS
# 15 KMS
# 15 KMS
# 18 KMS
# 15 KMS
# 15 KMS
# 15 KMS
# 5 KMS
# 15 KMS
# 15 KMS
# 5 KMS
# 15 KMS
# 15 KMS
# 26 KMS
# 5 KMS
# 5 KMS
# ['5 KMS', '15 KMS', '15 KMS', '18 KMS', '15 KMS', '15 KMS', '15 KMS', '5 KMS', '15 KMS', '15 KMS', '5 KMS', '15 KMS', '15 KMS', '26 KMS', '5 KMS', '5 KMS']

# %%
exterior = []#taking empty list
a = soup.findAll('dd',{"class":"srp-color-exterior"})#scrapping exterior
for i in a:
    print(i.text)
    exterior.append(i.text)#appending in a list
print(exterior)#printing list
# Out:
# Urban Grey
# Radiant Red
# Radiant Red
# Urban Grey
# Aurora Black
# Gravity Grey
# Snow White Pearl
# Snow White Pearl
# Snow White Pearl
# Urban Grey
# Gravity Grey
# Urban Grey
# Gravity Grey
# Aurora Black
# Hyper Blue
# Snow White Pearl
# Hyper Blue
# AURORA BLACK
# Snow White Pearl
# Snow White Pearl
# ['Urban Grey', 'Radiant Red', 'Radiant Red', 'Urban Grey', 'Aurora Black', 'Gravity Grey', 'Snow White Pearl', 'Snow White Pearl', 'Snow White Pearl', 'Urban Grey', 'Gravity Grey', 'Urban Grey', 'Gravity Grey', 'Aurora Black', 'Hyper Blue', 'Snow White Pearl', 'Hyper Blue', 'AURORA BLACK', 'Snow White Pearl', 'Snow White Pearl']

# %%
engine = []#taking empty list
a = soup.findAll('dd',{"class":"srp-engine-combined"}) #scrapping engine
for i in a:
    print(i.text)
    engine.append(i.text)#appending in a list
print(engine)#printing list
# Out:
# 2L I-4
# 1.6L I-4
# 1.6L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# 2L I-4
# ['2L I-4', '1.6L I-4', '1.6L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4', '2L I-4']

# %%
transmission = []#taking empty list
a = soup.findAll('dd',{"class":"srp-transmission"})#scrappping transmission
for i in a:
    print(i.text)
    transmission.append(i.text)#appending in a list
print(transmission)#printing list
# Out:
# 6 Spd Manual
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# CVT
# ['6 Spd Manual', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT', 'CVT']

# %%
drive_train = []#taking empty list
a = soup.findAll('dd',{"class":"srp-driveType"})#scrapping drive_Train
for i in a:
    print(i.text)
    drive_train.append(i.text)#appending in a list
print(drive_train)#printing list
# Out:
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# FWD
# ['FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD', 'FWD']

# %%
stock = []#taking empty list
a = soup.findAll('dd',{"class":"srp-stock-number"})#wscrapping stock
for i in a:
    print(i.text)
    stock.append(i.text)#appending in a list
print(stock)#printing list
# Out:
# 20FR834
# 20RI067
# 20RI969
# 21FR070
# 21FR071
# 21FR028
# 21FR068
# 21FR069
# 21FR001
# 21FR996
# 21FR029
# 21FR006
# 21FR999
# 21FR971
# 21FR019
# 21FR997
# 21FR998
# 19FR255
# 20FR798
# 21SO050
# ['20FR834', '20RI067', '20RI969', '21FR070', '21FR071', '21FR028', '21FR068', '21FR069', '21FR001', '21FR996', '21FR029', '21FR006', '21FR999', '21FR971', '21FR019', '21FR997', '21FR998', '19FR255', '20FR798', '21SO050']

# %%
vin = []#taking empty list
a = soup.findAll('dd',{"class":"srp-vin"}) #scrapping vin
for i in a:
    print(i.text)
    vin.append(i.text)#appending in a list
print(vin)#printing list
# Out:
# 3KPF24AD3LE182270
# 3KPA25AD5LE345792
# 3KPA25ADXLE337221
# 3KPF24ADXME282710
# 3KPF24ADXME282917
# 3KPF24AD5ME281464
# 3KPF24AD3ME283276
# 3KPF24AD8ME282270
# 3KPF24ADXME276129
# 3KPF24AD1ME265844
# 3KPF24ADXME281816
# 3KPF24AD0ME276284
# 3KPF24AD5ME275549
# 3KPF24AD7ME265895
# 3KPF24ADXME279578
# 3KPF24AD2ME265822
# 3KPF24AD4ME266020
# 3KPF54AD8KE088732
# 3KPF54AD8LE244348
# KNDJ33AU6M7753575
# ['3KPF24AD3LE182270', '3KPA25AD5LE345792', '3KPA25ADXLE337221', '3KPF24ADXME282710', '3KPF24ADXME282917', '3KPF24AD5ME281464', '3KPF24AD3ME283276', '3KPF24AD8ME282270', '3KPF24ADXME276129', '3KPF24AD1ME265844', '3KPF24ADXME281816', '3KPF24AD0ME276284', '3KPF24AD5ME275549', '3KPF24AD7ME265895', '3KPF24ADXME279578', '3KPF24AD2ME265822', '3KPF24AD4ME266020', '3KPF54AD8KE088732', '3KPF54AD8LE244348', 'KNDJ33AU6M7753575']

# %%
#creating a dict of scrapped data
dict = {
        'Title' : car_titles ,
        'Mileage':mileage,
        'Exterior':exterior,
        'Transmission':transmission,
        'Engine':engine,
        'Drive Train':drive_train,
        'Stock':stock,
        'VIN':vin,
        'Price':car_price
}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                   Title Mileage          Exterior  Transmission    Engine  \
# 0        2020 Kia Forte   5 KMS        Urban Grey  6 Spd Manual    2L I-4
# 1   2020 Kia Rio 5-door  15 KMS       Radiant Red           CVT  1.6L I-4
# 2   2020 Kia Rio 5-door  15 KMS       Radiant Red           CVT  1.6L I-4
# 3        2021 Kia Forte  18 KMS        Urban Grey           CVT    2L I-4
# 4        2021 Kia Forte  15 KMS      Aurora Black           CVT    2L I-4
# 5        2021 Kia Forte  15 KMS      Gravity Grey           CVT    2L I-4
# 6        2021 Kia Forte  15 KMS  Snow White Pearl           CVT    2L I-4
# 7        2021 Kia Forte   5 KMS  Snow White Pearl           CVT    2L I-4
# 8        2021 Kia Forte  15 KMS  Snow White Pearl           CVT    2L I-4
# 9        2021 Kia Forte  15 KMS        Urban Grey           CVT    2L I-4
# 10       2021 Kia Forte   5 KMS      Gravity Grey           CVT    2L I-4
# 11       2021 Kia Forte  15 KMS        Urban Grey           CVT    2L I-4
# 12       2021 Kia Forte  15 KMS      Gravity Grey           CVT    2L I-4
# 13       2021 Kia Forte  26 KMS      Aurora Black           CVT    2L I-4
# 14       2021 Kia Forte   5 KMS        Hyper Blue           CVT    2L I-4
# 15       2021 Kia Forte   5 KMS  Snow White Pearl           CVT    2L I-4
# 16       2021 Kia Forte    None        Hyper Blue           CVT    2L I-4
# 17       2019 Kia Forte    None      AURORA BLACK           CVT    2L I-4
# 18       2020 Kia Forte    None  Snow White Pearl           CVT    2L I-4
# 19        2021 Kia Soul    None  Snow White Pearl           CVT    2L I-4
#
#    Drive Train    Stock                VIN     Price
# 0          FWD  20FR834  3KPF24AD3LE182270  $18,739*
# 1          FWD  20RI067  3KPA25AD5LE345792  $18,972*
# 2          FWD  20RI969  3KPA25ADXLE337221  $18,972*
# 3          FWD  21FR070  3KPF24ADXME282710  $21,772*
# 4          FWD  21FR071  3KPF24ADXME282917  $21,772*
# 5          FWD  21FR028  3KPF24AD5ME281464  $21,772*
# 6          FWD  21FR068  3KPF24AD3ME283276  $21,772*
# 7          FWD  21FR069  3KPF24AD8ME282270  $21,772*
# 8          FWD  21FR001  3KPF24ADXME276129  $21,772*
# 9          FWD  21FR996  3KPF24AD1ME265844  $21,772*
# 10         FWD  21FR029  3KPF24ADXME281816  $21,772*
# 11         FWD  21FR006  3KPF24AD0ME276284  $21,772*
# 12         FWD  21FR999  3KPF24AD5ME275549  $21,772*
# 13         FWD  21FR971  3KPF24AD7ME265895  $21,772*
# 14         FWD  21FR019  3KPF24ADXME279578  $21,772*
# 15         FWD  21FR997  3KPF24AD2ME265822  $21,772*
# 16         FWD  21FR998  3KPF24AD4ME266020  $21,772*
# 17         FWD  19FR255  3KPF54AD8KE088732  $21,999*
# 18         FWD  20FR798  3KPF54AD8LE244348  $24,339*
# 19         FWD  21SO050  KNDJ33AU6M7753575  $24,422*

# %%
df['Dealer'] = 'winniepegkia'
df['Condition'] = 'New'

# %%
split_title = df["Title"].str.split(" ", n = 2, expand = True) 
# splitting Tile column 
df["Make Year"]= split_title[0] 
df["Make"]= split_title[1] 
df["Model"]= split_title[2] 
df
# Out:
#                   Title Mileage          Exterior  Transmission    Engine  \
# 0        2020 Kia Forte   5 KMS        Urban Grey  6 Spd Manual    2L I-4
# 1   2020 Kia Rio 5-door  15 KMS       Radiant Red           CVT  1.6L I-4
# 2   2020 Kia Rio 5-door  15 KMS       Radiant Red           CVT  1.6L I-4
# 3        2021 Kia Forte  18 KMS        Urban Grey           CVT    2L I-4
# 4        2021 Kia Forte  15 KMS      Aurora Black           CVT    2L I-4
# 5        2021 Kia Forte  15 KMS      Gravity Grey           CVT    2L I-4
# 6        2021 Kia Forte  15 KMS  Snow White Pearl           CVT    2L I-4
# 7        2021 Kia Forte   5 KMS  Snow White Pearl           CVT    2L I-4
# 8        2021 Kia Forte  15 KMS  Snow White Pearl           CVT    2L I-4
# 9        2021 Kia Forte  15 KMS        Urban Grey           CVT    2L I-4
# 10       2021 Kia Forte   5 KMS      Gravity Grey           CVT    2L I-4
# 11       2021 Kia Forte  15 KMS        Urban Grey           CVT    2L I-4
# 12       2021 Kia Forte  15 KMS      Gravity Grey           CVT    2L I-4
# 13       2021 Kia Forte  26 KMS      Aurora Black           CVT    2L I-4
# 14       2021 Kia Forte   5 KMS        Hyper Blue           CVT    2L I-4
# 15       2021 Kia Forte   5 KMS  Snow White Pearl           CVT    2L I-4
# 16       2021 Kia Forte    None        Hyper Blue           CVT    2L I-4
# 17       2019 Kia Forte    None      AURORA BLACK           CVT    2L I-4
# 18       2020 Kia Forte    None  Snow White Pearl           CVT    2L I-4
# 19        2021 Kia Soul    None  Snow White Pearl           CVT    2L I-4
#
#    Drive Train    Stock                VIN     Price        Dealer Condition  \
# 0          FWD  20FR834  3KPF24AD3LE182270  $18,739*  winniepegkia       New
# 1          FWD  20RI067  3KPA25AD5LE345792  $18,972*  winniepegkia       New
# 2          FWD  20RI969  3KPA25ADXLE337221  $18,972*  winniepegkia       New
# 3          FWD  21FR070  3KPF24ADXME282710  $21,772*  winniepegkia       New
# 4          FWD  21FR071  3KPF24ADXME282917  $21,772*  winniepegkia       New
# 5          FWD  21FR028  3KPF24AD5ME281464  $21,772*  winniepegkia       New
# 6          FWD  21FR068  3KPF24AD3ME283276  $21,772*  winniepegkia       New
# 7          FWD  21FR069  3KPF24AD8ME282270  $21,772*  winniepegkia       New
# 8          FWD  21FR001  3KPF24ADXME276129  $21,772*  winniepegkia       New
# 9          FWD  21FR996  3KPF24AD1ME265844  $21,772*  winniepegkia       New
# 10         FWD  21FR029  3KPF24ADXME281816  $21,772*  winniepegkia       New
# 11         FWD  21FR006  3KPF24AD0ME276284  $21,772*  winniepegkia       New
# 12         FWD  21FR999  3KPF24AD5ME275549  $21,772*  winniepegkia       New
# 13         FWD  21FR971  3KPF24AD7ME265895  $21,772*  winniepegkia       New
# 14         FWD  21FR019  3KPF24ADXME279578  $21,772*  winniepegkia       New
# 15         FWD  21FR997  3KPF24AD2ME265822  $21,772*  winniepegkia       New
# 16         FWD  21FR998  3KPF24AD4ME266020  $21,772*  winniepegkia       New
# 17         FWD  19FR255  3KPF54AD8KE088732  $21,999*  winniepegkia       New
# 18         FWD  20FR798  3KPF54AD8LE244348  $24,339*  winniepegkia       New
# 19         FWD  21SO050  KNDJ33AU6M7753575  $24,422*  winniepegkia       New
#
#    Make Year Make       Model
# 0       2020  Kia       Forte
# 1       2020  Kia  Rio 5-door
# 2       2020  Kia  Rio 5-door
# 3       2021  Kia       Forte
# 4       2021  Kia       Forte
# 5       2021  Kia       Forte
# 6       2021  Kia       Forte
# 7       2021  Kia       Forte
# 8       2021  Kia       Forte
# 9       2021  Kia       Forte
# 10      2021  Kia       Forte
# 11      2021  Kia       Forte
# 12      2021  Kia       Forte
# 13      2021  Kia       Forte
# 14      2021  Kia       Forte
# 15      2021  Kia       Forte
# 16      2021  Kia       Forte
# 17      2019  Kia       Forte
# 18      2020  Kia       Forte
# 19      2021  Kia        Soul

# %%
df.drop(columns =["Title"], inplace = True)
df
# Out:
#    Mileage          Exterior  Transmission    Engine Drive Train    Stock  \
# 0    5 KMS        Urban Grey  6 Spd Manual    2L I-4         FWD  20FR834
# 1   15 KMS       Radiant Red           CVT  1.6L I-4         FWD  20RI067
# 2   15 KMS       Radiant Red           CVT  1.6L I-4         FWD  20RI969
# 3   18 KMS        Urban Grey           CVT    2L I-4         FWD  21FR070
# 4   15 KMS      Aurora Black           CVT    2L I-4         FWD  21FR071
# 5   15 KMS      Gravity Grey           CVT    2L I-4         FWD  21FR028
# 6   15 KMS  Snow White Pearl           CVT    2L I-4         FWD  21FR068
# 7    5 KMS  Snow White Pearl           CVT    2L I-4         FWD  21FR069
# 8   15 KMS  Snow White Pearl           CVT    2L I-4         FWD  21FR001
# 9   15 KMS        Urban Grey           CVT    2L I-4         FWD  21FR996
# 10   5 KMS      Gravity Grey           CVT    2L I-4         FWD  21FR029
# 11  15 KMS        Urban Grey           CVT    2L I-4         FWD  21FR006
# 12  15 KMS      Gravity Grey           CVT    2L I-4         FWD  21FR999
# 13  26 KMS      Aurora Black           CVT    2L I-4         FWD  21FR971
# 14   5 KMS        Hyper Blue           CVT    2L I-4         FWD  21FR019
# 15   5 KMS  Snow White Pearl           CVT    2L I-4         FWD  21FR997
# 16    None        Hyper Blue           CVT    2L I-4         FWD  21FR998
# 17    None      AURORA BLACK           CVT    2L I-4         FWD  19FR255
# 18    None  Snow White Pearl           CVT    2L I-4         FWD  20FR798
# 19    None  Snow White Pearl           CVT    2L I-4         FWD  21SO050
#
#                   VIN     Price        Dealer Condition Make Year Make  \
# 0   3KPF24AD3LE182270  $18,739*  winniepegkia       New      2020  Kia
# 1   3KPA25AD5LE345792  $18,972*  winniepegkia       New      2020  Kia
# 2   3KPA25ADXLE337221  $18,972*  winniepegkia       New      2020  Kia
# 3   3KPF24ADXME282710  $21,772*  winniepegkia       New      2021  Kia
# 4   3KPF24ADXME282917  $21,772*  winniepegkia       New      2021  Kia
# 5   3KPF24AD5ME281464  $21,772*  winniepegkia       New      2021  Kia
# 6   3KPF24AD3ME283276  $21,772*  winniepegkia       New      2021  Kia
# 7   3KPF24AD8ME282270  $21,772*  winniepegkia       New      2021  Kia
# 8   3KPF24ADXME276129  $21,772*  winniepegkia       New      2021  Kia
# 9   3KPF24AD1ME265844  $21,772*  winniepegkia       New      2021  Kia
# 10  3KPF24ADXME281816  $21,772*  winniepegkia       New      2021  Kia
# 11  3KPF24AD0ME276284  $21,772*  winniepegkia       New      2021  Kia
# 12  3KPF24AD5ME275549  $21,772*  winniepegkia       New      2021  Kia
# 13  3KPF24AD7ME265895  $21,772*  winniepegkia       New      2021  Kia
# 14  3KPF24ADXME279578  $21,772*  winniepegkia       New      2021  Kia
# 15  3KPF24AD2ME265822  $21,772*  winniepegkia       New      2021  Kia
# 16  3KPF24AD4ME266020  $21,772*  winniepegkia       New      2021  Kia
# 17  3KPF54AD8KE088732  $21,999*  winniepegkia       New      2019  Kia
# 18  3KPF54AD8LE244348  $24,339*  winniepegkia       New      2020  Kia
# 19  KNDJ33AU6M7753575  $24,422*  winniepegkia       New      2021  Kia
#
#          Model
# 0        Forte
# 1   Rio 5-door
# 2   Rio 5-door
# 3        Forte
# 4        Forte
# 5        Forte
# 6        Forte
# 7        Forte
# 8        Forte
# 9        Forte
# 10       Forte
# 11       Forte
# 12       Forte
# 13       Forte
# 14       Forte
# 15       Forte
# 16       Forte
# 17       Forte
# 18       Forte
# 19        Soul

# %%
#Dataframe to csv
df.to_csv('winnipegkia.csv')
