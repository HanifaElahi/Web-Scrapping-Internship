# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = input(("Enter url : "))
# "https://www.northlandford.mb.ca/new/new-vehicle-inventory.html"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#Finding the titles of cars using find_all
#All the titles are present in h2 class : centered
car_titles = []
a=soup.findAll('h2',{"class":"centered"})
for i in a :
    print(i.text.strip())#printing titles
    car_titles.append(i.text.strip())#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# 2020 Ford Escape S
# 2020 Ford Fusion SE
# 2020 Ford Fusion SE
# 2020 Ford Fusion SE
# 2020 Ford Escape S
# 2020 Ford Fusion SE
# 2020 Ford Fusion SE
# 2020 Ford Escape S
# 2020 Ford Fusion SE
# 2020 Ford Escape S
# 2020 Ford Fusion SE
# 2020 Ford Fusion SE
# 2020 Ford Fusion SE
# 2020 Ford Fusion SE
# 2020 Ford Fusion SE
# 2020 Ford Fusion SE
# 2020 Ford EcoSport SE
# 2020 Ford Fusion SE
# 2020 Ford Fusion SE
# 2020 Ford EcoSport SE
# 2020 Ford Escape S
# 2020 Ford Fusion SE
# 2020 Ford Fusion SE
# 2020 Ford EcoSport SE
# 2020 Ford Fusion SE
# 2020 Ford EcoSport SE
# 2020 Ford Escape S
# 2020 Ford Fusion SE
# 2020 Ford Escape SE
# 2020 Ford Escape S
# 2020 Ford Fusion SE
# 2020 Ford Escape S
# 2020 Ford Fusion SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# 2020 Ford Escape SE
# ['2020 Ford Escape S', '2020 Ford Fusion SE', '2020 Ford Fusion SE', '2020 Ford Fusion SE', '2020 Ford Escape S', '2020 Ford Fusion SE', '2020 Ford Fusion SE', '2020 Ford Escape S', '2020 Ford Fusion SE', '2020 Ford Escape S', '2020 Ford Fusion SE', '2020 Ford Fusion SE', '2020 Ford Fusion SE', '2020 Ford Fusion SE', '2020 Ford Fusion SE', '2020 Ford Fusion SE', '2020 Ford EcoSport SE', '2020 Ford Fusion SE', '2020 Ford Fusion SE', '2020 Ford EcoSport SE', '2020 Ford Escape S', '2020 Ford Fusion SE', '2020 Ford Fusion SE', '2020 Ford EcoSport SE', '2020 Ford Fusion SE', '2020 Ford EcoSport SE', '2020 Ford Escape S', '2020 Ford Fusion SE', '2020 Ford Escape SE', '2020 Ford Escape S', '2020 Ford Fusion SE', '2020 Ford Escape S', '2020 Ford Fusion SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE', '2020 Ford Escape SE']
# 64

# %%
mileage = []
exterior = []
drive_type = []
vin = []
inventory_status = []
# taking empty lists

spec= soup.findAll('div',{"class":"bulletwrap"}) # all the specs are inside class: bulletwrap
for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('li')#finding all li
    for li in lis:
        
        if 'Mileage' in li.text: #if present
            mileage.append(li.text.replace("Mileage:",""))#then append
        if 'Exterior' in li.text:#if present
            exterior.append(li.text.replace("Exterior:",""))#then append
        if 'Drivetrain' in li.text: #if present
            drive_type.append(li.text.replace("Drivetrain:","")) #then append
      
        if 'VIN' in li.text: #if present
            vin.append(li.text.replace("VIN:","")) #then append
       
        if 'Inventory Status' in li.text: #if present
            inventory_status.append(li.text.replace("Inventory Status:","")) #then append
            

#printing individual lists        
print(mileage)
print(exterior)
print(drive_type)
print(vin)
print(inventory_status)
# Out:
# [' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  km', ' 0  
# ['$30,835 ', '$31,535 ', '$31,535 ', '$30,835 ', '$31,535 ', '$30,835 ', '$30,835 ', '$31,535 ', '$31,535 ', '$31,535 ', '$31,535 ', '$31,535 ', '$31,749 ', '$31,535 ', '$31,535 ', '$31,749 ', '$32,085 ', '$31,535 ', '$31,749 ', '$31,535 ', '$31,749 ', '$32,085 ', '$32,085 ', '$32,085 ']

# %%
discount = []#taking an empty list
a = soup.findAll('div',{"class":"fee-row allowance"})#scrapping
for i in a:
    print(i.text)
    discount.append(i.text.replace("Delivery Allowance 29 ",""))#appending in a list
print(discount)
len(discount)#printing list
# Out:
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$1,000
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$1,000
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$1,000
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$1,000
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# Delivery Allowance 29 -$500
# ['-$500 ', '-$500 ', '-$500 ', '-$500 ', '-$500 ', '-$500 ', '-$500 ', '-$500 ', '-$500 ', '-$500 ', '-$500 ', '-$500 ', '-$1,000 ', '-$500 ', '-$500 ', '-$1,000 ', '-$500 ', '-$500 ', '-$1,000 ', '-$500 ', '-$1,000 ', '-$500 ', '-$500 ', '-$500 ']
# 24

# %%
dealer_price = []#taking an empty list
a = soup.findAll('div',{"class":"fee-row dealerPrice"})#scrapping
for i in a:
    print(i.text)
    dealer_price.append(i.text.replace("Dealer Price:",""))#appending in a list
print(dealer_price)#printing list
len(dealer_price)#length of list
# Out:
# Dealer Price:$30,335
# Dealer Price:$31,035
# Dealer Price:$31,035
# Dealer Price:$30,335
# Dealer Price:$31,035
# Dealer Price:$30,335
# Dealer Price:$30,335
# Dealer Price:$31,035
# Dealer Price:$31,035
# Dealer Price:$31,035
# Dealer Price:$31,035
# Dealer Price:$31,035
# Dealer Price:$30,749
# Dealer Price:$31,035
# Dealer Price:$31,035
# Dealer Price:$30,749
# Dealer Price:$31,585
# Dealer Price:$31,035
# Dealer Price:$30,749
# Dealer Price:$31,035
# Dealer Price:$30,749
# Dealer Price:$31,585
# Dealer Price:$31,585
# Dealer Price:$31,585
# ['$30,335 ', '$31,035 ', '$31,035 ', '$30,335 ', '$31,035 ', '$30,335 ', '$30,335 ', '$31,035 ', '$31,035 ', '$31,035 ', '$31,035 ', '$31,035 ', '$30,749 ', '$31,035 ', '$31,035 ', '$30,749 ', '$31,585 ', '$31,035 ', '$30,749 ', '$31,035 ', '$30,749 ', '$31,585 ', '$31,585 ', '$31,585 ']
# 24

# %%
car_price = []#taking an empty list
a = soup.findAll('span',{"class":"centered price-header showField vehicleResultsSelectedPrice highlight-secondary-text"})#scrapping
for i in a:
    print(i.text)
    car_price.append(i.text)#appending in a list
print(car_price)#printing list
len(car_price)#length of list
# Out:
# $30,699
# $30,335
# $31,035
# $31,035
# $30,699
# $30,335
# $31,035
# $30,699
# $30,335
# $30,699
# $30,335
# $31,035
# $31,035
# $31,035
# $31,035
# $31,035
# $30,749
# $31,035
# $31,035
# $30,749
# $32,049
# $31,585
# $31,035
# $30,749
# $31,035
# $30,749
# $32,049
# $31,585
# $32,499
# $32,049
# $31,585
# $32,049
# $31,585
# $32,499
# $34,049
# $34,049
# $34,449
# $32,499
# $34,049
# $32,499
# $34,049
# $34,049
# $34,449
# $34,049
# $34,049
# $34,449
# $34,049
# $34,449
# $35,049
# $35,049
# $36,649
# $36,649
# $35,049
# $35,049
# $36,649
# $35,049
# $35,049
# $35,049
# $35,049
# $36,649
# $36,649
# $36,649
# $36,649
# $36,649
# ['$30,699 ', '$30,335 ', '$31,035 ', '$31,035 ', '$30,699 ', '$30,335 ', '$31,035 ', '$30,699 ', '$30,335 ', '$30,699 ', '$30,335 ', '$31,035 ', '$31,035 ', '$31,035 ', '$31,035 ', '$31,035 ', '$30,749 ', '$31,035 ', '$31,035 ', '$30,749 ', '$32,049 ', '$31,585 ', '$31,035 ', '$30,749 ', '$31,035 ', '$30,749 ', '$32,049 ', '$31,585 ', '$32,499 ', '$32,049 ', '$31,585 ', '$32,049 ', '$31,585 ', '$32,499 ', '$34,049 ', '$34,049 ', '$34,449 ', '$32,499 ', '$34,049 ', '$32,499 ', '$34,049 ', '$34,049 ', '$34,449 ', '$34,049 ', '$34,049 ', '$34,449 ', '$34,049 ', '$34,449 ', '$35,049 ', '$35,049 ', '$36,649 ', '$36,649 ', '$35,049 ', '$35,049 ', '$36,649 ', '$35,049 ', '$35,049 ', '$35,049 ', '$35,049 ', '$36,649 ', '$36,649 ', '$36,649 ', '$36,649 ', '$36,649 ']
# 64

# %%
#creating dict of scrapped data
dict = {
    'Title' : car_titles,
    'Price' : car_price,
    'Mileage':mileage,
    'Exterior':exterior,
    'Drive Type':drive_type,
    'VIN':vin,
    'Inventory Status':inventory_status,
    'MSRP':msrp,
    'Dealer price':dealer_price,
    'Discount':discount

}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                     Title     Price Mileage             Exterior  \
# 0      2020 Ford Escape S  $30,699    0  km        Blue Metallic
# 1     2020 Ford Fusion SE  $30,335    0  km          Agate Black
# 2     2020 Ford Fusion SE  $31,035    0  km          Agate Black
# 3     2020 Ford Fusion SE  $31,035    0  km        Velocity Blue
# 4      2020 Ford Escape S  $30,699    0  km        Blue Metallic
# 5     2020 Ford Fusion SE  $30,335    0  km          Agate Black
# 6     2020 Ford Fusion SE  $31,035    0  km          Agate Black
# 7      2020 Ford Escape S  $30,699    0  km        Blue Metallic
# 8     2020 Ford Fusion SE  $30,335    0  km          Agate Black
# 9      2020 Ford Escape S  $30,699    0  km        Blue Metallic
# 10    2020 Ford Fusion SE  $30,335    0  km          Agate Black
# 11    2020 Ford Fusion SE  $31,035    0  km          Agate Black
# 12    2020 Ford Fusion SE  $31,035    0  km        Velocity Blue
# 13    2020 Ford Fusion SE  $31,035    0  km          Agate Black
# 14    2020 Ford Fusion SE  $31,035    0  km        Velocity Blue
# 15    2020 Ford Fusion SE  $31,035    0  km             Magnetic
# 16  2020 Ford EcoSport SE  $30,749    0  km        Diamond White
# 17    2020 Ford Fusion SE  $31,035    0  km        Velocity Blue
# 18    2020 Ford Fusion SE  $31,035    0  km             Magnetic
# 19  2020 Ford EcoSport SE  $30,749    0  km        Diamond White
# 20     2020 Ford Escape S  $32,049    0  km   Dark Persian Green
# 21    2020 Ford Fusion SE  $31,585    0  km            Alto Blue
# 22    2020 Ford Fusion SE  $31,035    0  km             Magnetic
# 23  2020 Ford EcoSport SE  $30,749    0  km        Diamond White
# 24    2020 Ford Fusion SE  $31,035    0  km             Magnetic
# 25  2020 Ford EcoSport SE  $30,749    0  km        Diamond White
# 26     2020 Ford Escape S  $32,049    0  km   Dark Persian Green
# 27    2020 Ford Fusion SE  $31,585    0  km            Alto Blue
# 28    2020 Ford Escape SE  $32,499    0  km         Ingot Silver
# 29     2020 Ford Escape S  $32,049    0  km   Dark Persian Green
# ..                    ...       ...     ...                  ...
# 34    2020 Ford Escape SE  $34,049    0  km         Oxford White
# 35    2020 Ford Escape SE  $34,049    0  km   Dark Persian Green
# 36    2020 Ford Escape SE  $34,449    0  km            Rapid Red
# 37    2020 Ford Escape SE  $32,499    0  km         Ingot Silver
# 38    2020 Ford Escape SE  $34,049    0  km         Oxford White
# 39    2020 Ford Escape SE  $32,499    0  km         Ingot Silver
# 40    2020 Ford Escape SE  $34,049    0  km         Oxford White
# 41    2020 Ford Escape SE  $34,049    0  km   Dark Persian Green
# 42    2020 Ford Escape SE  $34,449    0  km            Rapid Red
# 43    2020 Ford Escape SE  $34,049    0  km         Oxford White
# 44    2020 Ford Escape SE  $34,049    0  km   Dark Persian Green
# 45    2020 Ford Escape SE  $34,449    0  km            Rapid Red
# 46    2020 Ford Escape SE  $34,049    0  km   Dark Persian Green
# 47    2020 Ford Escape SE  $34,449    0  km            Rapid Red
# 48    2020 Ford Escape SE  $35,049    0  km         Ingot Silver
# 49    2020 Ford Escape SE  $35,049    0  km        Velocity Blue
# 50    2020 Ford Escape SE  $36,649    0  km        Blue Metallic
# 51    2020 Ford Escape SE  $36,649    0  km             Magnetic
# 52    2020 Ford Escape SE  $35,049    0  km         Ingot Silver
# 53    2020 Ford Escape SE  $35,049    0  km        Velocity Blue
# 54    2020 Ford Escape SE  $36,649    0  km        Blue Metallic
# 55    2020 Ford Escape SE  $35,049    0  km         Ingot Silver
# 56    2020 Ford Escape SE  $35,049    0  km        Velocity Blue
# 57    2020 Ford Escape SE  $35,049    0  km         Ingot Silver
# 58    2020 Ford Escape SE  $35,049    0  km        Velocity Blue
# 59    2020 Ford Escape SE  $36,649    0  km        Blue Metallic
# 60    2020 Ford Escape SE  $36,649    0  km             Magnetic
# 61    2020 Ford Escape SE  $36,649    0  km        Blue Metallic
# 62    2020 Ford Escape SE  $36,649    0  km             Magnetic
# 63    2020 Ford Escape SE  $36,649    0  km             Magnetic
#
#                           Drive Type                 VIN Inventory Status  \
# 0            Front-Wheel Drive (FWD)   1FMCU0F63LUC39936   Dealer Ordered
# 1            Front-Wheel Drive (FWD)   3FA6P0HD4LR226873         In Stock
# 2            Front-Wheel Drive (FWD)   3FA6P0HD3LR141992         In Stock
# 3            Front-Wheel Drive (FWD)   3FA6P0HD5LR262037         In Stock
# 4            Front-Wheel Drive (FWD)   1FMCU0F63LUC39936   Dealer Ordered
# 5            Front-Wheel Drive (FWD)   3FA6P0HD4LR226873         In Stock
# 6            Front-Wheel Drive (FWD)   3FA6P0HD3LR141992         In Stock
# 7            Front-Wheel Drive (FWD)   1FMCU0F63LUC39936   Dealer Ordered
# 8            Front-Wheel Drive (FWD)   3FA6P0HD4LR226873         In Stock
# 9            Front-Wheel Drive (FWD)   1FMCU0F63LUC39936   Dealer Ordered
# 10           Front-Wheel Drive (FWD)   3FA6P0HD4LR226873         In Stock
# 11           Front-Wheel Drive (FWD)   3FA6P0HD3LR141992         In Stock
# 12           Front-Wheel Drive (FWD)   3FA6P0HD5LR262037         In Stock
# 13           Front-Wheel Drive (FWD)   3FA6P0HD3LR141992         In Stock
# 14           Front-Wheel Drive (FWD)   3FA6P0HD5LR262037         In Stock
# 15           Front-Wheel Drive (FWD)   3FA6P0HD3LR120852         In Stock
# 16   Intelligent 4 Wheel Drive (4WD)   MAJ6S3GLXLC385758   Dealer Ordered
# 17           Front-Wheel Drive (FWD)   3FA6P0HD5LR262037         In Stock
# 18           Front-Wheel Drive (FWD)   3FA6P0HD3LR120852         In Stock
# 19   Intelligent 4 Wheel Drive (4WD)   MAJ6S3GLXLC385758   Dealer Ordered
# 20             All-Wheel Drive (AWD)   1FMCU9F61LUC46128   Dealer Ordered
# 21           Front-Wheel Drive (FWD)   3FA6P0HD9LR226402         In Stock
# 22           Front-Wheel Drive (FWD)   3FA6P0HD3LR120852         In Stock
# 23   Intelligent 4 Wheel Drive (4WD)   MAJ6S3GLXLC385758   Dealer Ordered
# 24           Front-Wheel Drive (FWD)   3FA6P0HD3LR120852         In Stock
# 25   Intelligent 4 Wheel Drive (4WD)   MAJ6S3GLXLC385758   Dealer Ordered
# 26             All-Wheel Drive (AWD)   1FMCU9F61LUC46128   Dealer Ordered
# 27           Front-Wheel Drive (FWD)   3FA6P0HD9LR226402         In Stock
# 28           Front-Wheel Drive (FWD)   1FMCU0G62LUB52088         In Stock
# 29             All-Wheel Drive (AWD)   1FMCU9F61LUC46128   Dealer Ordered
# ..                               ...                 ...              ...
# 34             All-Wheel Drive (AWD)   1FMCU9G60LUC12163         In Stock
# 35             All-Wheel Drive (AWD)   1FMCU9G60LUC12194         In Stock
# 36             All-Wheel Drive (AWD)   1FMCU9G60LUB34886         In Stock
# 37           Front-Wheel Drive (FWD)   1FMCU0G62LUB52088         In Stock
# 38             All-Wheel Drive (AWD)   1FMCU9G60LUC12163         In Stock
# 39           Front-Wheel Drive (FWD)   1FMCU0G62LUB52088         In Stock
# 40             All-Wheel Drive (AWD)   1FMCU9G60LUC12163         In Stock
# 41             All-Wheel Drive (AWD)   1FMCU9G60LUC12194         In Stock
# 42             All-Wheel Drive (AWD)   1FMCU9G60LUB34886         In Stock
# 43             All-Wheel Drive (AWD)   1FMCU9G60LUC12163         In Stock
# 44             All-Wheel Drive (AWD)   1FMCU9G60LUC12194         In Stock
# 45             All-Wheel Drive (AWD)   1FMCU9G60LUB34886         In Stock
# 46             All-Wheel Drive (AWD)   1FMCU9G60LUC12194         In Stock
# 47             All-Wheel Drive (AWD)   1FMCU9G60LUB34886         In Stock
# 48             All-Wheel Drive (AWD)   1FMCU9G61LUC42353   Dealer Ordered
# 49             All-Wheel Drive (AWD)   1FMCU9G60LUC46491   Dealer Ordered
# 50             All-Wheel Drive (AWD)   1FMCU9G67LUC37626   Dealer Ordered
# 51             All-Wheel Drive (AWD)   1FMCU9G66LUC46074   Dealer Ordered
# 52             All-Wheel Drive (AWD)   1FMCU9G61LUC42353   Dealer Ordered
# 53             All-Wheel Drive (AWD)   1FMCU9G60LUC46491   Dealer Ordered
# 54             All-Wheel Drive (AWD)   1FMCU9G67LUC37626   Dealer Ordered
# 55             All-Wheel Drive (AWD)   1FMCU9G61LUC42353   Dealer Ordered
# 56             All-Wheel Drive (AWD)   1FMCU9G60LUC46491   Dealer Ordered
# 57             All-Wheel Drive (AWD)   1FMCU9G61LUC42353   Dealer Ordered
# 58             All-Wheel Drive (AWD)   1FMCU9G60LUC46491   Dealer Ordered
# 59             All-Wheel Drive (AWD)   1FMCU9G67LUC37626   Dealer Ordered
# 60             All-Wheel Drive (AWD)   1FMCU9G66LUC46074   Dealer Ordered
# 61             All-Wheel Drive (AWD)   1FMCU9G67LUC37626   Dealer Ordered
# 62             All-Wheel Drive (AWD)   1FMCU9G66LUC46074   Dealer Ordered
# 63             All-Wheel Drive (AWD)   1FMCU9G66LUC46074   Dealer Ordered
#
#         MSRP Dealer price  Discount
# 0   $30,835      $30,335     -$500
# 1   $31,535      $31,035     -$500
# 2   $31,535      $31,035     -$500
# 3   $30,835      $30,335     -$500
# 4   $31,535      $31,035     -$500
# 5   $30,835      $30,335     -$500
# 6   $30,835      $30,335     -$500
# 7   $31,535      $31,035     -$500
# 8   $31,535      $31,035     -$500
# 9   $31,535      $31,035     -$500
# 10  $31,535      $31,035     -$500
# 11  $31,535      $31,035     -$500
# 12  $31,749      $30,749   -$1,000
# 13  $31,535      $31,035     -$500
# 14  $31,535      $31,035     -$500
# 15  $31,749      $30,749   -$1,000
# 16  $32,085      $31,585     -$500
# 17  $31,535      $31,035     -$500
# 18  $31,749      $30,749   -$1,000
# 19  $31,535      $31,035     -$500
# 20  $31,749      $30,749   -$1,000
# 21  $32,085      $31,585     -$500
# 22  $32,085      $31,585     -$500
# 23  $32,085      $31,585     -$500
# 24      None         None      None
# 25      None         None      None
# 26      None         None      None
# 27      None         None      None
# 28      None         None      None
# 29      None         None      None
# ..       ...          ...       ...
# 34      None         None      None
# 35      None         None      None
# 36      None         None      None
# 37      None         None      None
# 38      None         None      None
# 39      None         None      None
# 40      None         None      None
# 41      None         None      None
# 42      None         None      None
# 43      None         None      None
# 44      None         None      None
# 45      None         None      None
# 46      None         None      None
# 47      None         None      None
# 48      None         None      None
# 49      None         None      None
# 50      None         None      None
# 51      None         None      None
# 52      None         None      None
# 53      None         None      None
# 54      None         None      None
# 55      None         None      None
# 56      None         None      None
# 57      None         None      None
# 58      None         None      None
# 59      None         None      None
# 60      None         None      None
# 61      None         None      None
# 62      None         None      None
# 63      None         None      None
#
# [64 rows x 10 columns]

# %%
#Dataframe to csv
df.to_csv('northlandofrd_mb_ca.csv')
