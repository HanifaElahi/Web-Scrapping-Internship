# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = "https://www.vickarford.ca/vehicles/?fn=&pr=&mk=&md=&tr=&bs=&od=&yr=&v1=Passenger%20Vehicles&view=grid"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class: row grid-row
data = soup.findAll('div',{"class":"row grid-row"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
#     Watch Video Watch Video  Save This Vehicle  Get Price Alerts 2019 Ford Mustang COUPE ECOBOOST       Vickar Sale Price  $30,807  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FA6P8TH2K5113594Kilometres: 30Condition: NewBody Style: CoupeEngine: 4 Cylinder Engine
# 				View More Details
# 			  Compare         Save This Vehicle  Get Price Alerts 2019 Ford F-650 DIESEL F650 CHASSIS CAB       Vickar Sale Price  $99,215  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FDNF6DC3KDF08949Kilometres: 30Condition: NewBody Style: OtherEngine: V-8 cyl
# 				View More Details
# 			  Compare         Save This Vehicle  Get Price Alerts 2020 Ford Explorer PLATINUM   Sale Price  $68,557
# 								+ Tax							  Incentives  $-3,000  Hover for details.  Dealer Discount$3,000    Vickar Sale Price  $65,557  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FM5K8HC5LGA73899Kilometres: 884Condition: NewBody Style: SUVEngine: V-6 cyl
# 				View More Details
# 			  Compare         Save This Vehicle  Get Price Alerts 2019 Ford F-650 GAS F650 CHASSIS CAB       Vickar Sale Price  $83,729  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FDNF6AY2KDF12930Kilometres: 30Condition: NewBody Style: OtherEngine: V-10 cyl
# 				View More Details
# 			  Compare      Watch Video Watch Video  Save This Vehicle  Get Price Alerts 2020 Ford Escape TITANIUM - AWD   Sale Price  $45,557
# 								+ Tax							  Incentives  $-4,500  Hover for details.  Dealer Discount$4,500    Vickar Sale Price  $41,057  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FMCU9J92LUA02506Kilometres: 30Condition: NewBody Style: SUVEngine: I-4 cyl
# 				View More Details
# 			  Compare      Watch Video Watch Video  Save This Vehicle  Get Price Alerts 2019 Ford F-750 F750 CHASSIS CAB       Vickar Sale Price  $227,000  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FDPX7DE7KDF13892Kilometres: 30Condition: NewBody Style: Cab and ChassisEngine: V-8 cyl
# 				View More Details
# 			  Compare         Save This Vehicle  Get Price Alerts 2020 Ford Escape SE - FWD   Sale Price  $33,307
# 								+ Tax							  Incentives  $-4,500  Hover for details.  Dealer Discount$4,500    Vickar Sale Price  $28,807  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FMCU0G68LUA17455Kilometres: 30Condition: NewBody Style: SUVEngine: I-3 cyl
# 				View More Details
# 			  Compare         Save This Vehicle  Get Price Alerts 2019 Ford F-650 DIESEL F650 CHASSIS CAB       Vickar Sale Price  $111,608  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FDPX6DE5KDF14713Kilometres: 30Condition: NewBody Style: OtherEngine: 6.7L
# 				View More Details
# 			  Compare   We analyzed similar vehicles in your area and calculated that this vehicle is priced a bit lower than the average making it a Good Price.     Watch Video Watch Video  Save This Vehicle  Get Price Alerts 2017 Ford Edge SEL AWD LEATHER & NAVIGATION & PANOROOF      Est. Finance Payment  $143
# 									/bw
# 								  Click to open payment calculator
# 								5.99% for 84 Months							  Final Price  $21,177  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 2FMPK4J95HBB65528Kilometres: 104,002Condition: UsedBody Style: SUVEngine: 4 Cylinder Engine 2.0L
# 				View More Details
# 			  Compare         Save This Vehicle  Get Price Alerts 2020 Ford F-550 4X4 - CHASSIS REG CAB 169 WB - DRW XL       Vickar Sale Price  $133,022  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FDUF5HN5LEC34120Kilometres: 30Condition: NewBody Style: Cab and ChassisEngine: 8 Cylinder Engine
# 				View More Details
# 			  Compare      Watch Video Watch Video  Save This Vehicle  Get Price Alerts 2020 Ford F-150 4X4 - SUPERCREW LARIAT - 145 WB   Sale Price  $77,999
# 								+ Tax							  Incentives  $-11,000  Hover for details.  Dealer Discount$11,000    Vickar Sale Price  $66,999  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FTEW1EP6LFB11024Kilometres: 30Condition: NewBody Style: Crew CabEngine: V6 Cylinder Engine
# 				View More Details
# 			  Compare         Save This Vehicle  Get Price Alerts 2020 Ford F-150 4X4 - SUPERCREW XLT - 145 WB   Sale Price  $53,177
# 								+ Tax							  Incentives  $-11,000  Hover for details.  Dealer Discount$11,000    Vickar Sale Price  $42,177  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FTEW1EB8LFB16827Kilometres: 30Condition: NewBody Style: Crew CabEngine: V6 Cylinder Engine
# 				View More Details
# 			  Compare         Save This Vehicle  Get Price Alerts 2020 Ford Ranger 4X4 SUPERCREW XLT 126WB   Sale Price  $43,657
# 								+ Tax							  Incentives  $-4,500  Hover for details.  Dealer Discount$4,500    Vickar Sale Price  $39,157  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FTER4FH6LLA18134Kilometres: 30Condition: NewBody Style: Crew CabEngine: 4 Cylinder Engine
# 				View More Details
# 			  Compare      Watch Video Watch Video  Save This Vehicle  Get Price Alerts 2020 Ford Escape SEL AWD POWERFUL 2.0L ECO & PANOROOF      Est. Finance Payment  $212
# 									/bw
# 								  Click to open payment calculator
# 								5.99% for 96 Months							  Final Price  $34,954  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FMCU9H99LUA87849Kilometres: 6,189Condition: UsedBody Style: SUVEngine: 4 Cylinder Engine
# 				View More Details
# 			  Compare         Save This Vehicle  Get Price Alerts 2020 Ford Ranger 4X4 SUPERCREW XLT 126WB   Sale Price  $58,087
# 								+ Tax							  Incentives  $-4,500  Hover for details.  Dealer Discount$4,500    Vickar Sale Price  $53,587  Pricing excludes licensing and tax.
# 								+ Tax							   Compare     VIN: 1FTER4FH8LLA22394Kilometres: 30Condition: NewBody Style: Crew CabEngine: 4 Cylinder Engine
# 				View More Details
# 			  Compare

# %%
#Finding the titles of cars using find_all
#All the titles are present in div class : vehicle-card__details
car_titles = []
a=soup.findAll('div',{"class":"vehicle-card__details"})
for i in a :
    titles=i.find('h4',{"class":"vehicle-card__title"}).text.strip()#all the titles are inside h4 class
    print(titles)#printing titles
    car_titles.append(titles)#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# 2019 Ford Mustang COUPE ECOBOOST
# 2019 Ford F-650 DIESEL F650 CHASSIS CAB
# 2020 Ford Explorer PLATINUM
# 2019 Ford F-650 GAS F650 CHASSIS CAB
# 2020 Ford Escape TITANIUM - AWD
# 2019 Ford F-750 F750 CHASSIS CAB
# 2020 Ford Escape SE - FWD
# 2019 Ford F-650 DIESEL F650 CHASSIS CAB
# 2017 Ford Edge SEL AWD LEATHER & NAVIGATION & PANOROOF
# 2020 Ford F-550 4X4 - CHASSIS REG CAB 169 WB - DRW XL
# 2020 Ford F-150 4X4 - SUPERCREW LARIAT - 145 WB
# 2020 Ford F-150 4X4 - SUPERCREW XLT - 145 WB
# 2020 Ford Ranger 4X4 SUPERCREW XLT 126WB
# 2020 Ford Escape SEL AWD POWERFUL 2.0L ECO & PANOROOF
# 2020 Ford Ranger 4X4 SUPERCREW XLT 126WB
# ['2019 Ford Mustang COUPE ECOBOOST', '2019 Ford F-650 DIESEL F650 CHASSIS CAB', '2020 Ford Explorer PLATINUM', '2019 Ford F-650 GAS F650 CHASSIS CAB', '2020 Ford Escape TITANIUM - AWD', '2019 Ford F-750 F750 CHASSIS CAB', '2020 Ford Escape SE - FWD', '2019 Ford F-650 DIESEL F650 CHASSIS CAB', '2017 Ford Edge SEL AWD LEATHER & NAVIGATION & PANOROOF', '2020 Ford F-550 4X4 - CHASSIS REG CAB 169 WB - DRW XL', '2020 Ford F-150 4X4 - SUPERCREW LARIAT - 145 WB', '2020 Ford F-150 4X4 - SUPERCREW XLT - 145 WB', '2020 Ford Ranger 4X4 SUPERCREW XLT 126WB', '2020 Ford Escape SEL AWD POWERFUL 2.0L ECO & PANOROOF', '2020 Ford Ranger 4X4 SUPERCREW XLT 126WB']
# 15

# %%
#Finding the prices of cars using find_all
#All the prices are present in div class : vehicle-card__price-wrap
car_price = []
c = soup.findAll('div',{"class":"vehicle-card__price-wrap"})
for i in c :
    sp=i.findAll('div',{"class":"price-block__price price-block__price--lg price-block__price--primary"})#digging further
    for j in sp:
        s=j.find('span',{"class":"df aifs"}).text.split("df aifs")[0]#actual values are inside span class :df aifs
        print(s)#printing prices
        car_price.append(s)#appending in a list
print(car_price)#printing list
len(car_price)#length oflist
# Out:
# $30,807
# $99,215
# $65,557
# $83,729
# $41,057
# $227,000
# $28,807
# $111,608
# $21,177
# $133,022
# $66,999
# $42,177
# $39,157
# $34,954
# $53,587
# ['$30,807', '$99,215', '$65,557', '$83,729', '$41,057', '$227,000', '$28,807', '$111,608', '$21,177', '$133,022', '$66,999', '$42,177', '$39,157', '$34,954', '$53,587']
# 15

# %%
Vinlist = []
Kmlist = []
condition = []
body_style = []
engine = []
# taking empty lists

#All the specifications are inside ul class: detailed-specs inline-view
spec= soup.find_all("ul",{"class": "detailed-specs inline-view"})

for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('li')#finding all li inside ul
    for li in lis:
        if 'VIN' in li.text: # if present 
            Vinlist.append(li.text.replace("VIN:","")) # then append
        if 'Kilometres' in li.text:# if present
            Kmlist.append(li.text.replace("Kilometres:",""))# then append
        if 'Condition' in li.text:# if present
            condition.append(li.text.replace("Condition:",""))# then append# then append
        if 'Body Style' in li.text:# if present
            body_style.append(li.text.replace("Body Style:",""))# then append
        if 'Engine' in li.text:# if present
            engine.append(li.text.replace("Engine:",""))
            
#priniting individual lists
print(Vinlist)
print(Kmlist)
print(condition)
print(body_style)
print(engine)
# Out:
# [' 1FA6P8TH2K5113594', ' 1FDNF6DC3KDF08949', ' 1FM5K8HC5LGA73899', ' 1FDNF6AY2KDF12930', ' 1FMCU9J92LUA02506', ' 1FDPX7DE7KDF13892', ' 1FMCU0G68LUA17455', ' 1FDPX6DE5KDF14713', ' 2FMPK4J95HBB65528', ' 1FDUF5HN5LEC34120', ' 1FTEW1EP6LFB11024', ' 1FTEW1EB8LFB16827', ' 1FTER4FH6LLA18134', ' 1FMCU9H99LUA87849', ' 1FTER4FH8LLA22394']
# [' 30', ' 30', ' 884', ' 30', ' 30', ' 30', ' 30', ' 30', ' 104,002', ' 30', ' 30', ' 30', ' 30', ' 6,189', ' 30']
# [' New', ' New', ' New', ' New', ' New', ' New', ' New', ' New', ' Used', ' New', ' New', ' New', ' New', ' Used', ' New']
# [' Coupe', ' Other', ' SUV', ' Other', ' SUV', ' Cab and Chassis', ' SUV', ' Other', ' SUV', ' Cab and Chassis', ' Crew Cab', ' Crew Cab', ' Crew Cab', ' SUV', ' Crew Cab']
# [' 4 Cylinder Engine', ' V-8 cyl', ' V-6 cyl', ' V-10 cyl', ' I-4 cyl', ' V-8 cyl', ' I-3 cyl', ' 6.7L', ' 4 Cylinder Engine 2.0L', ' 8 Cylinder Engine', ' V6 Cylinder Engine', ' V6 Cylinder Engine', ' 4 Cylinder Engine', ' 4 Cylinder Engine', ' 4 Cylinder Engine']

# %%
#creating dict of scrapped data
dict = {
    'Title' : car_titles ,
    'Mileage' : Kmlist , 
    'Price': car_price ,
    'VIN' : Vinlist ,
    'Engine' : engine ,
    'Body Style' : body_style ,
    'Condition' : condition
}

# %%
#creating dataframe from dict
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                                                 Title   Mileage     Price  \
# 0                    2019 Ford Mustang COUPE ECOBOOST        30   $30,807
# 1             2019 Ford F-650 DIESEL F650 CHASSIS CAB        30   $99,215
# 2                         2020 Ford Explorer PLATINUM       884   $65,557
# 3                2019 Ford F-650 GAS F650 CHASSIS CAB        30   $83,729
# 4                     2020 Ford Escape TITANIUM - AWD        30   $41,057
# 5                    2019 Ford F-750 F750 CHASSIS CAB        30  $227,000
# 6                           2020 Ford Escape SE - FWD        30   $28,807
# 7             2019 Ford F-650 DIESEL F650 CHASSIS CAB        30  $111,608
# 8   2017 Ford Edge SEL AWD LEATHER & NAVIGATION & ...   104,002   $21,177
# 9   2020 Ford F-550 4X4 - CHASSIS REG CAB 169 WB -...        30  $133,022
# 10    2020 Ford F-150 4X4 - SUPERCREW LARIAT - 145 WB        30   $66,999
# 11       2020 Ford F-150 4X4 - SUPERCREW XLT - 145 WB        30   $42,177
# 12           2020 Ford Ranger 4X4 SUPERCREW XLT 126WB        30   $39,157
# 13  2020 Ford Escape SEL AWD POWERFUL 2.0L ECO & P...     6,189   $34,954
# 14           2020 Ford Ranger 4X4 SUPERCREW XLT 126WB        30   $53,587
#
#                    VIN                   Engine        Body Style Condition
# 0    1FA6P8TH2K5113594        4 Cylinder Engine             Coupe       New
# 1    1FDNF6DC3KDF08949                  V-8 cyl             Other       New
# 2    1FM5K8HC5LGA73899                  V-6 cyl               SUV       New
# 3    1FDNF6AY2KDF12930                 V-10 cyl             Other       New
# 4    1FMCU9J92LUA02506                  I-4 cyl               SUV       New
# 5    1FDPX7DE7KDF13892                  V-8 cyl   Cab and Chassis       New
# 6    1FMCU0G68LUA17455                  I-3 cyl               SUV       New
# 7    1FDPX6DE5KDF14713                     6.7L             Other       New
# 8    2FMPK4J95HBB65528   4 Cylinder Engine 2.0L               SUV      Used
# 9    1FDUF5HN5LEC34120        8 Cylinder Engine   Cab and Chassis       New
# 10   1FTEW1EP6LFB11024       V6 Cylinder Engine          Crew Cab       New
# 11   1FTEW1EB8LFB16827       V6 Cylinder Engine          Crew Cab       New
# 12   1FTER4FH6LLA18134        4 Cylinder Engine          Crew Cab       New
# 13   1FMCU9H99LUA87849        4 Cylinder Engine               SUV      Used
# 14   1FTER4FH8LLA22394        4 Cylinder Engine          Crew Cab       New

# %%
df['Dealer'] = 'vickarford'

# %%
split_title = df["Title"].str.split(" ", n = 4, expand = True) 
# splitting Tile column

# %%
df["Make Year"]= split_title[0]

# %%
df["Make"]= split_title[1]

# %%
df["Model"]= split_title[2]

# %%
df.drop(columns =["Title"], inplace = True)

# %%
df
# Out:
#      Mileage     Price                 VIN                   Engine  \
# 0         30   $30,807   1FA6P8TH2K5113594        4 Cylinder Engine
# 1         30   $99,215   1FDNF6DC3KDF08949                  V-8 cyl
# 2        884   $65,557   1FM5K8HC5LGA73899                  V-6 cyl
# 3         30   $83,729   1FDNF6AY2KDF12930                 V-10 cyl
# 4         30   $41,057   1FMCU9J92LUA02506                  I-4 cyl
# 5         30  $227,000   1FDPX7DE7KDF13892                  V-8 cyl
# 6         30   $28,807   1FMCU0G68LUA17455                  I-3 cyl
# 7         30  $111,608   1FDPX6DE5KDF14713                     6.7L
# 8    104,002   $21,177   2FMPK4J95HBB65528   4 Cylinder Engine 2.0L
# 9         30  $133,022   1FDUF5HN5LEC34120        8 Cylinder Engine
# 10        30   $66,999   1FTEW1EP6LFB11024       V6 Cylinder Engine
# 11        30   $42,177   1FTEW1EB8LFB16827       V6 Cylinder Engine
# 12        30   $39,157   1FTER4FH6LLA18134        4 Cylinder Engine
# 13     6,189   $34,954   1FMCU9H99LUA87849        4 Cylinder Engine
# 14        30   $53,587   1FTER4FH8LLA22394        4 Cylinder Engine
#
#           Body Style Condition      Dealer Make Year  Make     Model
# 0              Coupe       New  vickarford      2019  Ford   Mustang
# 1              Other       New  vickarford      2019  Ford     F-650
# 2                SUV       New  vickarford      2020  Ford  Explorer
# 3              Other       New  vickarford      2019  Ford     F-650
# 4                SUV       New  vickarford      2020  Ford    Escape
# 5    Cab and Chassis       New  vickarford      2019  Ford     F-750
# 6                SUV       New  vickarford      2020  Ford    Escape
# 7              Other       New  vickarford      2019  Ford     F-650
# 8                SUV      Used  vickarford      2017  Ford      Edge
# 9    Cab and Chassis       New  vickarford      2020  Ford     F-550
# 10          Crew Cab       New  vickarford      2020  Ford     F-150
# 11          Crew Cab       New  vickarford      2020  Ford     F-150
# 12          Crew Cab       New  vickarford      2020  Ford    Ranger
# 13               SUV      Used  vickarford      2020  Ford    Escape
# 14          Crew Cab       New  vickarford      2020  Ford    Ranger

# %%
#Dataframe to csv
df.to_csv('vickar.csv')
