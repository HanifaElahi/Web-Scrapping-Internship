# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time
from matplotlib import pyplot as plt

# %%
urla = input(("Enter url : "))
# "https://www.jandjautosales.ca/used/"

# %%
driver=webdriver.Firefox(executable_path="C:/Users/DELL/Downloads/geckodriver.exe")
#set the value of executable path
driver.get(urla)

# %%
page_source=driver.page_source

# %%
#parsing the page
soup=BeautifulSoup(page_source,'html.parser')

# %%
#All the data present in a page is present in class col-xs-12 col-sm-12 col-md-12
data=soup.findAll('div',{"class":"col-xs-12 col-sm-12 col-md-12"})
#printing the extracted data of a single page
for info in data:
    print(info.text)
# Out:
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2020-mitsubishi-eclipse-cross-se-id10240246.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/83513518.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513518.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513521.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513521.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513524.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513524.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513526.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513526.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513530.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513530.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513533.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513533.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513536.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513536.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513537.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513537.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513538.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513538.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513540.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513540.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513541.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513541.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513542.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513542.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513543.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513543.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513544.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513544.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513545.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513545.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513546.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513546.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513547.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513547.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513548.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513548.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513549.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513549.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513550.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513550.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513551.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513551.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513552.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513552.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513553.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513553.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513555.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513555.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513557.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513557.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513559.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513559.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513562.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513562.jpeg"}]}
#                     jQuery("#carousel-example-generic-10240246").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# Apply for FinancingBook a Test DriveValue My Trade2020 Mitsubishi Eclipse Cross SESuper AWC,Auto,Factory WarrantyPrice:$29,950 $28,777Mileage:27,399 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SUVEngine:1.5L 4cylExterior Colour:Dark Grey
#
#
#
#
# Transmission:AutomaticDrivetrain:4x4Stock #:J2068City:Brandon
#
# .....Read LessThis 2020 Mitsubishi Eclipse Cross SE is ready to impress! With factory warranty, low kms, heated front seats, leather shift knob, split folding rear seats, exterior parking camera, blind spot sensor, external temperature display, rain sensing wipers, rear collision .....Read More.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2020-mitsubishi-outlander-es-id10281927.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/83513208.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513208.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513209.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513209.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513210.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513210.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513211.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513211.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513213.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513213.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513214.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513214.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513216.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513216.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513217.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513217.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513218.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513218.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513219.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513219.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513220.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513220.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513221.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513221.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513222.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513222.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513224.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513224.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513225.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513225.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513227.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513227.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513229.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513229.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513231.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513231.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513233.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513233.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513235.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513235.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513237.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513237.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513238.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513238.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513240.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513240.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513242.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513242.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513245.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513245.jpeg"}]}
#                     jQuery("#carousel-example-generic-10281927").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# Apply for FinancingBook a Test DriveValue My Trade2020 Mitsubishi Outlander ESAWCPrice:$30,950 $29,888Mileage:32,995 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SUVEngine:2.4L 4cylExterior Colour:White
#
#
#
#
# Transmission:AutomaticDrivetrain:4x4Stock #:J2076City:Brandon
#
# .....Read LessThe Outlander ES offers 4X4, low km’s, heated front seats, power 2-way lumbar support, split folding rear seats, overhead console, remote keyless entry, telescoping steering wheel, tilt steering wheel, automatic temperature control, exterior parking camera, external .....Read More.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2019-dodge-grand-caravan-gt-id10266761.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/83513583.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513583.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513585.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513585.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513587.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513587.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513590.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513590.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513592.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513592.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513594.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513594.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513596.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513596.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513598.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513598.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513601.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513601.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513603.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513603.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513605.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513605.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513607.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513607.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513608.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513608.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513610.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513610.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513612.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513612.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513614.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513614.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513617.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513617.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513618.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513618.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513620.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513620.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513622.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513622.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513624.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513624.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513625.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513625.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513627.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513627.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83513629.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83513629.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83
km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SedanEngine:3.5L 6cylExterior Colour:White
#
#
#
#
# Transmission:AutomaticDrivetrain:Front Wheel DriveStock #:J2094City:Brandon
#
# .....Read LessThe Nissan Maxima SL is fully loaded and ready to impress! With all leather interior, heated front seats, power 2-way lumbar support, sport steering wheel, exterior parking camera, navigation system, overhead console, power moonroof, remote keyless entry, telescoping .....Read More.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2017-chevrolet-impala-1lt-id10402400.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/83877099.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83877099.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83877100.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83877100.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83877101.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83877101.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83877102.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83877102.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83877103.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83877103.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83877104.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83877104.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83877105.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83877105.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83877106.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83877106.jpeg"}]}
#                     jQuery("#carousel-example-generic-10402400").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# Apply for FinancingBook a Test DriveValue My Trade2017 Chevrolet Impala 1LTCloth,Bluetooth,CruisePrice:$17,950 $16,888Mileage:143,468 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SedanEngine:2.5L 4cylExterior Colour:Blue
#
#
#
#
# Transmission:AutomaticDrivetrain:Front Wheel DriveStock #:J2103City:Brandon
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2017-chevrolet-silverado-1500-high-country-id10393922.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/83697381.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83697381.jpeg"}]}
#
#
#
# Apply for FinancingBook a Test DriveValue My Trade2017 Chevrolet Silverado 1500 High Country 4x4 Crew Cab 5.75 ft. boxFully Loaded,4WD,C.Start,S/RPrice:$40,950 $39,888Mileage:132,977 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:PickupEngine:6.2L 8cylExterior Colour:Blue
#
#
#
#
# Transmission:AutomaticDrivetrain:4x4Stock #:J2101City:Brandon
#
# .....Read LessChevrolet Silverado High Country is made to impress all consumers! This 1500 is fully loaded with 4WD, command start, sunroof, heated and cooled front seats, leather interior, power 4-way lumbar support, chrome wheels, rear step bumper, trailer sway control, adjustable .....Read More.maincontent .description{padding-left: 15px;}.maincontent .description li{list-style-type: disc;margin-left: 15px;}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http://schema.org","@type":"ImageGallery", "url":"/used/vehicle/2017-ford-explorer-xlt-id10399883.htm", "associatedMedia":[{"text":"","contentUrl":"https://images.edealer.ca/2/83820870.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83820870.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83820890.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83820890.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83820891.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83820891.jpeg"},{"text":"","contentUrl":"https://images.edealer.ca/2/83820893.jpeg","thumbnailUrl":"https://images.edealer.ca/4/83820893.jpeg"}]}
#                     jQuery("#carousel-example-generic-10399883").on("slide.bs.carousel", function(e) {
#
#                         var dataAltSrc = jQuery(e.relatedTarget).find("img").attr("data-alt-src");
#                         jQuery(e.relatedTarget).find("img").attr("src", dataAltSrc);
#
#             });View More Photos
#
#
#
# Apply for FinancingBook a Test DriveValue My Trade2017 Ford Explorer XLTXLT, Fully LoadedPrice:$28,950 $26,888Mileage:131,399 km
#
# View DetailsAdd to Compare
#
#
#
#
#
#
# Body Style:SUVEngine:3.5L 6cylExterior Colour:Black
#
#
#
#
# Transmission:AutomaticDrivetrain:4x4Stock #:J2092City:Brandon

# %%
#Finding the titles of cars using find_all
#All the titles are present in p class : vehicle-year-make-model
car_titles = []
a=soup.findAll('p',{"class":"vehicle-year-make-model"})
for i in a :
    print(i.text)#printing titles
    car_titles.append(i.text)#appending values
print(car_titles)#printing titles
len(car_titles)#printing length of list
# Out:
# 2020 Mitsubishi Eclipse Cross SE
# 2020 Mitsubishi Outlander ES
# 2019 Dodge Grand Caravan GT
# 2019 Hyundai Sonata ESSENTIAL
# 2018 GMC Sierra 1500 4x4 Double Cab 6.6 ft. box
# 2018 Nissan Maxima SL
# 2017 Chevrolet Impala 1LT
# 2017 Chevrolet Silverado 1500 High Country 4x4 Crew Cab 5.75 ft. box
# 2017 Ford Explorer XLT
# ['2020 Mitsubishi Eclipse Cross SE', '2020 Mitsubishi Outlander ES', '2019 Dodge Grand Caravan GT', '2019 Hyundai Sonata ESSENTIAL', '2018 GMC Sierra 1500 4x4 Double Cab 6.6 ft. box', '2018 Nissan Maxima SL', '2017 Chevrolet Impala 1LT', '2017 Chevrolet Silverado 1500 High Country 4x4 Crew Cab 5.75 ft. box', '2017 Ford Explorer XLT']
# 9

# %%
#Finding the msrp  of cars using find_all
#All the msrp are present in strike class : old-price
msrp = []
a=soup.findAll('strike',{"class":"old-price"})
for i in a :
    print(i.text)#printing msrp
    msrp.append(i.text)#appending values
print(msrp)#printing msrp
len(msrp)#printing length of list
# Out:
# $29,950
# $30,950
# $30,950
# $23,950
# $34,950
# $29,950
# $17,950
# $40,950
# $28,950
# ['$29,950', '$30,950', '$30,950', '$23,950', '$34,950', '$29,950', '$17,950', '$40,950', '$28,950']
# 9

# %%
#Finding the car  price   using find_all
#All the car price are present in span itemprop : price
car_price = []
a=soup.findAll('span',{"itemprop":"price"})
for i in a :
    print(i.text)#printing  price
    car_price .append(i.text)#appending values
print(car_price)#printing  price
len(car_price)#printing length of list
# Out:
# $28,777
# $29,888
# $29,888
# $22,777
# $33,888
# $28,777
# $16,888
# $39,888
# $26,888
# ['$28,777', '$29,888', '$29,888', '$22,777', '$33,888', '$28,777', '$16,888', '$39,888', '$26,888']
# 9

# %%
transmission = []
body_style = []
exterior = []
stock = []
# taking empty lists

spec= soup.findAll('table',{"class":"table"}) #scrapping details
for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('tr',{"class":"tr-even"})#finding all tr inside table wit class tr-even
    for li in lis:
        
        if 'Transmission' in li.text: #if present
            transmission.append(li.text.replace("Transmission:",""))#then append
        if 'Exterior Colour' in li.text:#if present
            exterior.append(li.text.replace("Exterior Colour:",""))#then append
        if 'Body Style' in li.text:#if present
            body_style.append(li.text.replace("Body Style:",""))#then append
        if 'Stock' in li.text: #if present
            stock.append(li.text.replace("Stock #:","")) #then append

#printing individual lists        
print(transmission)
print(exterior)
print(body_style)
print(stock)
# Out:
# ['Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic', 'Automatic']
# ['Dark Grey', 'White', 'Grey', 'Black', 'Black', 'White', 'Blue', 'Blue', 'Black']
# ['SUV', 'SUV', 'Vans', 'Sedan', 'Pickup', 'Sedan', 'Sedan', 'Pickup', 'SUV']
# ['J2068', 'J2076', 'J2071', 'J2087', 'J2102', 'J2094', 'J2103', 'J2101', 'J2092']

# %%
engine = []
drive_train = []
location = []
# taking empty lists

spec= soup.findAll('table',{"class":"table"})#scrapping details
for i in spec:
    newsoup = BeautifulSoup(str(i),'html.parser')#using parser for scrapping inside details
    lis = newsoup.find_all('tr',{"class":"tr-odd"})#finding all tr inside table wit class tr-odd
    for li in lis:
       
        if 'Engine' in li.text: #if present
            engine.append(li.text.replace("Engine:",""))#then append
        if 'Drivetrain' in li.text:#if present
            drive_train.append(li.text.replace("Drivetrain:",""))#then append
        if 'City' in li.text:#if present
            location.append(li.text.replace("City:",""))#then append
       #printing individual lists        
print(engine)
print(drive_train)
print(location)
# Out:
# ['1.5L 4cyl', '2.4L 4cyl', '3.6L 6cyl', '2.4L 4cyl', '4.3L 6cyl', '3.5L 6cyl', '2.5L 4cyl', '6.2L 8cyl', '3.5L 6cyl']
# ['4x4', '4x4', 'Front Wheel Drive', 'Front Wheel Drive', '4x4', 'Front Wheel Drive', 'Front Wheel Drive', '4x4', '4x4']
# ['Brandon', 'Brandon', 'Brandon', 'Brandon', 'Brandon', 'Brandon', 'Brandon', 'Brandon', 'Brandon']

# %%
car_mileage = [] #taking an empty list
mileage = soup.findAll('span',{"class":"mileage-used-list"})#scrapping mileage
for i in mileage:
    print(i.text)
    car_mileage.append(i.text)#appending in an empty list
print(car_mileage)#printing list
# Out:
# 27,399 km
# 32,995 km
# 52,877 km
# 65,177 km
# 74,881 km
# 68,499 km
# 143,468 km
# 132,977 km
# 131,399 km
# ['27,399 km', '32,995 km', '52,877 km', '65,177 km', '74,881 km', '68,499 km', '143,468 km', '132,977 km', '131,399 km']

# %%
#creating dict of scrapped data
dict = {
    'Title' : car_titles,
    'MSRP':msrp,
    'Price' : car_price,
    'Transmission' : transmission,
    'Exterior':exterior,
    'Body Style':body_style,
    'Stock' : stock,
    'Engine' : engine ,
    'Drive Train':drive_train,
    'Location':location,
    'Mileage':car_mileage
}

# %%
df = pd.DataFrame.from_dict(dict,orient = 'index').T
df
# Out:
#                                                Title     MSRP    Price  \
# 0                   2020 Mitsubishi Eclipse Cross SE  $29,950  $28,777
# 1                       2020 Mitsubishi Outlander ES  $30,950  $29,888
# 2                        2019 Dodge Grand Caravan GT  $30,950  $29,888
# 3                      2019 Hyundai Sonata ESSENTIAL  $23,950  $22,777
# 4    2018 GMC Sierra 1500 4x4 Double Cab 6.6 ft. box  $34,950  $33,888
# 5                              2018 Nissan Maxima SL  $29,950  $28,777
# 6                          2017 Chevrolet Impala 1LT  $17,950  $16,888
# 7  2017 Chevrolet Silverado 1500 High Country 4x4...  $40,950  $39,888
# 8                             2017 Ford Explorer XLT  $28,950  $26,888
#
#   Transmission   Exterior Body Style  Stock     Engine        Drive Train  \
# 0    Automatic  Dark Grey        SUV  J2068  1.5L 4cyl                4x4
# 1    Automatic      White        SUV  J2076  2.4L 4cyl                4x4
# 2    Automatic       Grey       Vans  J2071  3.6L 6cyl  Front Wheel Drive
# 3    Automatic      Black      Sedan  J2087  2.4L 4cyl  Front Wheel Drive
# 4    Automatic      Black     Pickup  J2102  4.3L 6cyl                4x4
# 5    Automatic      White      Sedan  J2094  3.5L 6cyl  Front Wheel Drive
# 6    Automatic       Blue      Sedan  J2103  2.5L 4cyl  Front Wheel Drive
# 7    Automatic       Blue     Pickup  J2101  6.2L 8cyl                4x4
# 8    Automatic      Black        SUV  J2092  3.5L 6cyl                4x4
#
#   Location     Mileage
# 0  Brandon   27,399 km
# 1  Brandon   32,995 km
# 2  Brandon   52,877 km
# 3  Brandon   65,177 km
# 4  Brandon   74,881 km
# 5  Brandon   68,499 km
# 6  Brandon  143,468 km
# 7  Brandon  132,977 km
# 8  Brandon  131,399 km

# %%
#Dataframe to csv
df.to_csv('jandjautosales.csv')
